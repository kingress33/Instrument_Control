# %%
#引入需要的包裝

import pyvisa
import pandas as pd
import time
import math

# %% [markdown]
# ### AFG31101
#
# ===============Function List=================
#
# * Set weveform type
# * Set frequency
# * Set amplitude
# * Set output state
# * Set amplitude limit
#
# 若要串接其他儀器 一樣使用class 定義其他儀器的function

# %%
class AFG_31101():
    def __init__(self, resource_address, visa_dll=None):
        """
        初始化儀器控制器。
        :param resource_address: 儀器的資源地址。
        :param visa_dll: 使用的 VISA DLL 路徑。如果為 None，則使用系統預設空白。
        """
        self.resource_address = resource_address
        self.visa_dll = visa_dll if visa_dll is not None else ''
        self.rm = pyvisa.ResourceManager(self.visa_dll)
        self.instrument = None
        self.connect_to_instrument()
        
    def connect_to_instrument(self):
        # 建立與儀器的連接
        self.instrument = self.rm.open_resource(self.resource_address)
        print("Connected to AFG_31101.")
        print(self.query_identity())

    def query_identity(self):
         # 查詢並返回儀器的身份識別信息
        if self.instrument:
             return self.instrument.query("*IDN?")
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def close_instrument(self):
        if self.instrument:
            self.instrument.close()
            print("AFG_31101 connection closed.")
        else:
            print("No instrument to close.")

    def set_waveform(self, shape):
        if self.instrument:
            self.instrument.write(f"SOURce1:FUNCtion {shape}")
            time.sleep(0.05)
            print(f"set excitation form be {shape}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_frequency(self, freq_amplitude, freq_unit):
        if self.instrument:
            self.instrument.write(f"SOURce1:FREQuency:FIXed {freq_amplitude} {freq_unit}")
            time.sleep(0.05)
            print(f"set excitation frequency be {freq_amplitude}{freq_unit}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def query_frequency(self):
        if self.instrument:
            self.instrument.write(f"SOURce1:FREQuency:FIXed?")
            time.sleep(0.05)
            return self.instrument.read()
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_amplitude(self, amp_magnitude, amp_unit):
        if self.instrument:
            self.instrument.write(f"SOURce1:VOLTage:LEVel:IMMediate:AMPLitude {amp_magnitude}{amp_unit}")
            time.sleep(0.05)
            print(f"set excitation amplitude be {amp_magnitude}{amp_unit}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def query_amplitude(self):
        if self.instrument:
            self.instrument.write(f"SOURce1:VOLTage:LEVel:IMMediate:AMPLitude?")
            time.sleep(0.05)
            return self.instrument.read()
        else:
            raise Exception("Instrument not connected. Please connect first.")
    
    def output_on(self):
        if self.instrument:
            self.instrument.write(f"OUTPut1:STATe ON")
            time.sleep(0.05)
            print(f"turn AFG31101 output on")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def output_off(self):
        if self.instrument:
            self.instrument.write(f"OUTPut1:STATe OFF")
            time.sleep(0.05)
            print(f"turn AFG31101 output off")
        else:
            raise Exception("Instrument not connected. Please connect first.")

# %%
def check_output_state(afg, output_state):
    if output_state == 'ON': #判斷輸出狀態，選擇要操作在哪一個輸出狀態DEF
        afg.output_on()
    else:
        afg.output_off()

# %%
def check_amp_limit(afg, amplitude_limit):
    query_amp = afg.query_amplitude()  # 回傳波形振幅大小
    amp_num = float(query_amp)  # 將回傳振幅大小的字串型態轉為數字型態
    if amp_num >= amplitude_limit:  # 判斷振幅是否大於AMPLITUDE_LIMIT
        print(f'Magnitude of amplitude cannot exceed {amplitude_limit} voltage')
        afg.output_off()  # 將OUTPUT關閉

# %% [markdown]
# ### RF-150A_100D
#
# ===============Function List=================
#
# * Set power state
# * Set gain
#
# 若要串接其他儀器 一樣使用class 定義其他儀器的function

# %%
class RF_150A100D():
    def __init__(self, resource_address, visa_dll=None):
        """
        初始化儀器控制器。
        :param resource_address: 儀器的資源地址。
        :param visa_dll: 使用的 VISA DLL 路徑。如果為 None，則使用系統預設空白。
        """
        self.resource_address = resource_address
        self.visa_dll = visa_dll if visa_dll is not None else ''
        self.rm = pyvisa.ResourceManager(self.visa_dll)
        self.instrument = None
        self.connect_to_instrument()
        
    def connect_to_instrument(self):
        # 建立與儀器的連接
        self.instrument = self.rm.open_resource(self.resource_address)
        print("Connected to RF_150A100D.")
        print(self.query_identity())

    def query_identity(self):
         # 查詢並返回儀器的身份識別信息
        if self.instrument:
             return self.instrument.query("*IDN?")
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def close_instrument(self):
        if self.instrument:
            self.instrument.close()
            print(f"RF_150A100D connection closed.")
        else:
            print(f"No instrument to close.")

    def power_on(self):
        if self.instrument:
            self.instrument.write(f"P1")
            print(f"turn RF150A100D power on")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def power_off(self):
        if self.instrument:
            self.instrument.write(f"P0")
            print(f"turn RF150A100D power off")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_gain(self,gain ,gain_set):
        if self.instrument:
            self.instrument.write(f"G{gain_set}")
            print(f"set power gain be {gain}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def reset(self):
        if self.instrument:
            self.instrument.write(f"R")
            print(f"clear faults")
        else:
            raise Exception("Instrument not connected. Please connect first.")

# %%
def check_power_state(rf, power_state):
    if power_state == 'ON': #判斷書出狀態，選擇def
        rf.power_on()
    else:
        rf.power_off()

# %%
def calculate_gain_set(gain):
    """
    計算並返回設置增益的值
    透過設定的gain去計算給儀器的gain_set該為多少
    """
    ratio = 4095 / 100  # MAX和MIN的比例
    gain_set = math.ceil(ratio * gain)  # 使用 math函數進行無條件進位
    gain_set = min(gain_set, 4095)  # 限制 gain_set 最大值為 4095
    gain_set = str(gain_set).zfill(4)  # 保持四個字元
    #print(f"CMD of gain set be G{ratio * gain}")
    return gain_set

# %% [markdown]
# ### MSO64B
#
# ===============Function List=================
#
# * Set channel
# * Auto set horizontal scale
# * Auto set Gating type
# * Auto set cursor positon
# * Auto set bandwidth limit
# * Auto set Acquistion mode & numbers of waveform
# * Set measurements[AMP、MEAN、DELAY]
# * Set math function
#
# 若要串接其他儀器 一樣使用class 定義其他儀器的function

# %%
class MSO_64B():
    def __init__(self, resource_address, visa_dll=None):
        """
        初始化儀器控制器。
        :param resource_address: 儀器的資源地址。
        :param visa_dll: 使用的 VISA DLL 路徑。如果為 None，則使用系統預設空白。
        """
        self.resource_address = resource_address
        self.visa_dll = visa_dll if visa_dll is not None else ''
        self.rm = pyvisa.ResourceManager(self.visa_dll)
        self.instrument = None
        self.connect_to_instrument()
        
    def connect_to_instrument(self):
        # 建立與儀器的連接
        self.instrument = self.rm.open_resource(self.resource_address)
        print("Connected to MSO64B.")
        print(self.query_identity())

    def query_identity(self):
         # 查詢並返回儀器的身份識別信息
        if self.instrument:
             return self.instrument.query("*IDN?")
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def close_instrument(self):
        #關閉與儀器的連接
        if self.instrument:
            self.instrument.close()
            print("MSO64B connection closed.")
        else:
            print("No instrument to close.")

    def clear(self):
        #執行示波器上的clear鍵，讓計算、測量項重新運算
        if self.instrument:
            self.instrument.write(f':CLEAR')
            time.sleep(0.3)  # 在命令之間暫停0.5
            print(f"clear acquistions, measurements, and waveforms")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_gating_type(self):
        if self.instrument:
            #設定measurement中Gating type
            self.instrument.write(f'MEASUrement:GATing CURSor')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"take measurements on the portion of the waveform between the cursor")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def cursor_control(self, cursor_A_position, cursor_B_position):
        if self.instrument:
            #設定cursor範圍為三個波形週期
            self.instrument.write(f':DISplay:WAVEView1:CURSor:CURSOR1:STATE ON')
            self.instrument.write(f':DISplay:WAVEView1:CURSor:CURSOR1:WAVEform:APOSition {cursor_A_position}')
            self.instrument.write(f':DISplay:WAVEView1:CURSor:CURSOR1:WAVEform:BPOSition {cursor_B_position}')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"set cursor range be {cursor_A_position} to {cursor_B_position}")
        else:
            raise Exception("Instrument not connected. Please connect first.")
            
    def result_table(self):
        #打開resulit table
        if self.instrument:
            self.instrument.write(f':MEASTABle:ADDNew "TABLE1"')
            time.sleep(0.05)  # 在命令之間暫停0.5
            print(f"add measurent result table")
        else:
            raise Exception("Instrument not connected. Please connect first.")
            
    def add_measurement(self,meas,channel):
        if self.instrument:       #新增CH1、CH2、CH3的MEAN測量值
            source_CMD = f":DISplay:SELect:WAVEView1:SOUrce {channel}" #測量訊號源CMD
            type_CMD = f":MEASUREMENT:ADDMEAS {meas}" #測量類型CMD
            command = f"{source_CMD};{type_CMD}"
            self.instrument.write(command)
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"add measurent {meas} of {channel}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_horizon_scale(self, horizon_scale):
        if self.instrument:
            self.instrument.write(f':HORIZONTAL:MODE:SCALE {horizon_scale}')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"set Horizontal Scale to {horizon_scale}s/div")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def detect_clip(self,clip_check):
        if self.instrument:
            #查看是否有波形clipping?
            return self.instrument.query(f":{clip_check}:CLIPping?")
            time.sleep(0.05)  # 在命令之間暫停0.5秒
        else:
            raise Exception("Instrument not connected. Please connect first.")
            
    def query_vertical_scale(self,clip_check):
        if self.instrument:
            #回傳當下有clipping之通道的vertical scale為多少?
            return self.instrument.query(f":{clip_check}:SCAle?")
            time.sleep(0.05)  # 在命令之間暫停0.5秒
        else:
            raise Exception("Instrument not connected. Please connect first.")
    
    def set_vertical_scale(self, clip_channel, new_vertical_value):
        if self.instrument:
            #重新對通道設定vertical scale
            self.instrument.write(f":{clip_channel}:SCAle {new_vertical_value}")
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"set {clip_channel} vertical scale be {new_vertical_value}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def math_add(self, math_num, math_function):
        if self.instrument:
            #新增math formula
            self.instrument.write(f':MATH:ADDNew "{math_num}"')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            self.instrument.write(f':MATH:{math_num}:DEFine "{math_function}"')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"Add {math_num} to calculate {math_function}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def off_display(self, off_channel, off_math):  
        if self.instrument:
            #將不必要的波形關閉
            self.instrument.write(f':DIS:WAVEVIEW1:{off_channel}:STATE OFF')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"turn {off_channel} display off")
            self.instrument.write(f':DISplay:WAVEView1:MATH:{off_math}:STATE OFF')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"turn {off_math} display off")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def measure_delta_B(self):
        if self.instrument:
            #新增測量磁通最大值及最小值的measurement
            self.instrument.write(f':MEASUREMENT:MEAS9:TYPE MAXIMUM; SOUrce MATH5') #新增math5的最大值
            time.sleep(0.05)  # 在命令之間暫停0.5秒           
            self.instrument.write(f':MEASUREMENT:MEAS10:TYPE MINIMUM; SOUrce MATH5') #新增math5的最小值
            time.sleep(0.05)  # 在命令之間暫停0.5
            print(f"add measurent maximum of math5")
            print(f"add measurent minimum of math5")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def power_function(self,num,voltage,current):
        if self.instrument:
            self.instrument.write(f':POWer:POWer{num}:POWERQUALITY:VSOURce {voltage}') #新增math5的最小值
            time.sleep(0.05)  # 在命令之間暫停0.5
            self.instrument.write(f':POWer:POWer{num}:POWERQUALITY:ISOURce {current}') #新增math5的最小值
            time.sleep(0.05)  # 在命令之間暫停0.5
            print(f"add measurent maximum of math5")
            print(f"add measurent minimum of math5")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_deskew(self, deskew_ch1):
        if self.instrument:
            self.instrument.write(f'CH1:DESKEW {deskew_ch1}')
            print(f"CH1 deskew set to {deskew_ch1}")
            time.sleep(0.05)
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_deskew_zero(self):
        if self.instrument:
            self.instrument.write(f'CH1:DESKEW 0')
            print(f"CH1 deskew set to 0")
            time.sleep(0.05)
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def query_mean_value(self, meas):
        if self.instrument:                  
            self.instrument.write(f'MEASUrement:{meas}:RESUlts:ALLAcqs:MEAN?')
            time.sleep(0.05)
            return float(self.instrument.read())
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def query_true_power(self, power_num):
        if self.instrument:
            self.instrument.write(f'POWer:POWer{power_num}:RESUlts:CURRentacq:MEAN? "TruePWR"')
            time.sleep(0.05)
            return float(self.instrument.read())
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def query_population(self):
        if self.instrument:
            self.instrument.write(f'MEASUrement:MEAS3:RESUlts:ALLAcqs:POPUlation?')
            time.sleep(0.05)
            return int(self.instrument.read())
        else:
            raise Exception("Instrument not connected. Please connect first.")

# %%
def wait_for_population(mso, threshold=100):
    while True: #重複查詢採樣次數(population)
        pop_num = mso.query_population() 
        print(f"Current population: {pop_num}") #列出每0.5秒的pop次數
        if pop_num >= threshold: #當pop次數大於等於100，結束while迴圈
            print(f"Poplution採樣數量已超過 {threshold}") 
            break #跳脫迴圈
        time.sleep(2)  # 防止過於頻繁的查詢，調整每0.5秒查詢一次

# %%
def set_horizon_scale(afg, mso):
    """
    設置示波器的horizon scale
    [因為如果一開始示波器的horizon scale沒有調好，抓到的freq值會過大，調整錯誤，因此直接從AFG訊號產生器抓值]
    """
    freq = float(afg.query_frequency()) #從afg抓頻率值
    print(f"the frequency of excitaton is {freq}")
    
    horizon_scale = (1 / freq) * (4 / 10)
    mso.set_horizon_scale(horizon_scale) #自動調整horizon scale

# %%
def set_cursor_range(afg, mso):
    """
    設置示波器的cursor range
    [因為如果一開始示波器的horizon scale沒有調好，抓到的freq值會過大，調整錯誤，因此直接從AFG訊號產生器抓值]
    """
    freq = float(afg.query_frequency()) #從afg抓頻率值
    print(f"the frequency of excitaton is {freq}")
    
    cursor_A_position = -1.5 * (1 / freq)  # 設cursor_A為負1.5波形週期sec
    cursor_B_position = 1.5 * (1 / freq)  # 設cursor_B為正1.5波形週期sec
    mso.cursor_control(cursor_A_position, cursor_B_position)

# %%
def set_vertical_scale(mso):
    clip_channels = ['CH1','CH2','CH3']#分別測試ch1、ch2、ch3是否clipping?

    channel_meas = {'CH1': 'MEAS3','CH2': 'MEAS4','CH3': 'MEAS5'}
    
    for clip_channel in clip_channels:
        while True: #重複測試到最後沒通道clipping & vertical scale都設定到80%
            clip_result = float(mso.detect_clip(clip_channel)) 
            print(f"clipping state:{clip_result}") #顯示1代表有clipping，0代表沒有clipping
            if clip_result == 1: #clipping時
                clip_vertical_scale = float(mso.query_vertical_scale(clip_channel))
                new_clip_vertical_scale = clip_vertical_scale + 40e-3 #將當下的vertical scale以20mV/div為step加上去
                mso.set_vertical_scale(clip_channel, new_clip_vertical_scale) #設定新的vertical scale
                time.sleep(0.5) #最後調整到沒有clipping等待久一點，讓下面程序執行正常
                print(f"{clip_channel} is clipping, auto set vertical scale from {clip_vertical_scale} to {new_clip_vertical_scale}")
            elif clip_result == 0: # 當channel沒有clipping時
                time.sleep(1)
                meas = channel_meas[clip_channel] #當下的clip_channel對應的meas是什麼?
                clip_amplitude = float(mso.query_mean_value(meas)) # 看該通道的amplitude大小
                print(f"amplitude of {clip_channel} is {clip_amplitude}")
                new_vertical_scale = clip_amplitude / 7  #將amplitude大小除以8即為理想的80% vertical scale
                mso.set_vertical_scale(clip_channel, new_vertical_scale) # 設定新的vertical scale
                print(f"{clip_channel} no clipping, auto set vertical scale to {new_vertical_scale}")
                break

# %%
def save_mso_query_values(mso, sequence, core_effective_area, turn):
    """
    用來儲存向儀器(示波器)查詢之值的包裝
    """
    B_max = mso.query_mean_value('MEAS9')
    B_min = mso.query_mean_value('MEAS10')
    calculate_delta_B = (B_max - B_min) / (core_effective_area * turn)
    
    time.sleep(0.05)
    print(f"The maximum B value is {B_max} T")
    print(f"The minimum B value is {B_min} T")
    print(f"The delta of B is {calculate_delta_B} T")
    
    return B_max, B_min, calculate_delta_B

# %%
def save_mso_power_values(mso, sequence):
    """
    用來儲存向儀器(示波器)查詢之值的包裝
    """
    power1_value = float(mso.query_true_power('1'))
    power2_value = float(mso.query_true_power('2'))
    
    time.sleep(0.05)
    print(f"The true power of 1 is {power1_value} W")
    print(f"The true power of 2 is {power2_value} W")
    
    return power1_value, power2_value

# %%
def set_vref_deskew(afg, mso, deskew_vref):
    freq = float(afg.query_frequency())
    deskew_ch1 = (deskew_vref)/(360 * freq)
    print(f"Deskew time of CH1 = {deskew_ch1}")
    mso.set_deskew(deskew_ch1)

# %%
def acquire_measurement(mso, i, core_effective_area, turn, max_B, min_B, delta_B, Pcore_true_power, PL_true_power, deskew=False):
    B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
        
    # 更新 max_B 和 min_B 字典
    if deskew:
        if 'MEAS9' not in max_B:
            max_B['MEAS9'] = []
        max_B['MEAS9'].append((i, B_max))
        # print("max_B_deskew:", max_B)

        if 'MEAS10' not in min_B:
            min_B['MEAS10'] = []
        min_B['MEAS10'].append((i, B_min))
        # print("min_B_deskew:", min_B)
        
        delta_B[i] = calculate_delta_B
        # print("delta_B_deskew:", delta_B)
    else:
        if 'MEAS9' not in max_B:
            max_B['MEAS9'] = []
        max_B['MEAS9'].append((i, B_max))
        # print("max_B:", max_B)

        if 'MEAS10' not in min_B:
            min_B['MEAS10'] = []
        min_B['MEAS10'].append((i, B_min))
        # print("min_B:", min_B)
        
        delta_B[i] = calculate_delta_B
        # print("delta_B:", delta_B)

    # 量測損耗功率
    power1_value, power2_value = save_mso_power_values(mso, i)

    if deskew:
        if '1' not in Pcore_true_power:
            Pcore_true_power['1'] = []
        Pcore_true_power['1'].append((i, power1_value))
        # print("Pcore true power_deskew:", Pcore_true_power)
        
        if '2' not in PL_true_power:
            PL_true_power['2'] = []
        PL_true_power['2'].append((i, power2_value))
        # print("PL true power_deskew:", PL_true_power)
    else:
        if '1' not in Pcore_true_power:
            Pcore_true_power['1'] = []
        Pcore_true_power['1'].append((i, power1_value))
        #print("Pcore true power:", Pcore_true_power)
        
        if '2' not in PL_true_power:
            PL_true_power['2'] = []
        PL_true_power['2'].append((i, power2_value))
        #print("PL true power:", PL_true_power)

# %%
def calculate_core_parameters(sequence, Pcore_true_power, PL_true_power, Pcore_true_power_deskew, PL_true_power_deskew, core_effective_volume):
    """
    套公式計算 k_factor, Pcore 和 Pcore_cv
    """
    k_factor = (PL_true_power_deskew['2'][sequence-1][1] - PL_true_power['2'][sequence-1][1]) / (Pcore_true_power_deskew['1'][sequence-1][1] - Pcore_true_power['1'][sequence-1][1])
    print(f"k factor:{k_factor}")
    Pcore = (Pcore_true_power['1'][sequence-1][1] - (k_factor * PL_true_power['2'][sequence-1][1]))
    print(f"Core Real power loss:{Pcore}")
    Pcore_cv = Pcore / core_effective_volume
    print(f"Every volume of Core Real power loss:{Pcore_cv}")

    return k_factor, Pcore, Pcore_cv

# %%
def adjust_rf_afg(mso, rf, afg, i, core_effective_area, turn, target_deltaB, gain, amplitude, amplitude_limit):
    """
    調整 RF 增益以達到目標 delta B 值
    """
    tolerance_max = 0.01
    tolerance_mid = 0.006
    tolerance_min = 0.003
    tolerance_final = 0.0005 #磁通密度抓得較精準
    
    # 查詢初始的 delta B 值
    B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
    
    while abs(target_deltaB - calculate_delta_B) > tolerance_final:
        if calculate_delta_B > 0.07:
            print("delta B 大於70 mT")
            tolerance_final = 0.0015 #磁通密度較高，抓得精準範圍越鬆
            step_rf_max = 3
            step_rf_mid = 2
            step_rf_mean = 1
            step_rf_min = 1
            step_afg_increase = 1
            step_afg_decrease = 5
        elif calculate_delta_B > 0.05:
            print("delta B 大於50 mT")
            tolerance_final = 0.001 #磁通密度較高，抓得精準範圍越鬆
            step_rf_max = 4
            step_rf_mid = 3
            step_rf_mean = 2
            step_rf_min = 1
            step_afg_increase = 2
            step_afg_decrease = 3
        else:
            print("delta B 小於50 mT")
            tolerance_max = 0.012
            step_rf_max = 10
            step_rf_mid = 5
            step_rf_mean = 3
            step_rf_min = 1
            step_afg_increase = 3
            step_afg_decrease = 2
            
        tolerance = target_deltaB - calculate_delta_B
        print(f"實際 delta B: {calculate_delta_B} 與預期 delta B: {target_deltaB} 差了 {tolerance}T")

        if tolerance < -tolerance_final:
            print(f"實際deltaB大於預期deltaB {tolerance_final}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) - step_afg_decrease  # 移除 'E-3' 並減少 1mV
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已減少 {step_afg_decrease}V， 設為{amplitude['magnitude']} {amplitude['unit']}")
            gain -= step_rf_mean
            print(f"增益減少 {step_rf_mean}")
        elif tolerance > tolerance_max:
            print(f"delta B 誤差大於 {tolerance_max}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg_increase  # 移除 'E-3' 並增加 3mV
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已增加 {step_afg_increase}V，設為{amplitude['magnitude']} {amplitude['unit']}")
            gain += step_rf_max
            print(f"增益增加 {step_rf_max}")
        elif tolerance > tolerance_mid:
            print(f"delta B 誤差介於 {tolerance_mid} ~ {tolerance_max}")
            gain += step_rf_mid
            print(f"增益增加 {step_rf_mid}")
        elif tolerance > tolerance_min:
            print(f"delta B 誤差介於 {tolerance_min} ~ {tolerance_mid}")
            gain += step_rf_mean
            print(f"增益增加 {step_rf_mean}")
        else:
            print(f"delta B 誤差介於 {tolerance_final} ~ {tolerance_min}")
            gain += step_rf_min
            print(f"增益增加 {step_rf_min}")

        afg.set_amplitude(amplitude['magnitude'], amplitude['unit'])
        check_amp_limit(afg, amplitude_limit)  # 檢查振幅是否超過限制

        gain_set = calculate_gain_set(gain)
        rf.set_gain(gain, gain_set)
        
        mso.clear()
        wait_for_population(mso, threshold=5)
        set_vertical_scale(mso)

        wait_for_population(mso, threshold=5)

        print(f"設定 Vin amplitude為:{amplitude}")
        print(f"設定 RF Gain為: {gain}")
        B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
        print(f"調整後的 delta B: {calculate_delta_B}")

    
    print(f"delta B已達預期的{target_deltaB}")
    return amplitude, gain

# %% [markdown]
# #### 從較小的激勵源開始
#
# * 設定expect deltaB：[0.02,0.04,0.06](T)
# * 查看calculate deltaB
# * 計算兩者誤差tolerance
#
# * tolerance為負的:RF的Gain:不變/AFG振幅:-5mV
#
# * 相差0.01以上：RF的Gain:+10/AFG振幅：不變
#
# * 相差0.005~0.01：RF的:Gain+5/AFG振幅:不變
#
# * 相差0.003~0.005：RF的:Gain+3/AFG振幅：不變
#
# * 相差0.001~0.003：RF的:Gain+1/AFG振幅：不變
#
# * 相差0.001內:不變/AFG振幅：不變

# %%
def main():
    
    # =========================Parmeters===============================
    #=====MSO64B parameter=====
    """
    channel:{CH1 | CH2 | CH3 | CH4 }[page:2-541]
    measure type:{AMPLITUDE | FREQUENCY | MAXIMUM | MEAN | MINIMUM | PERIOD | PHASE 
    | PK2PK | RMS } [page:2-717]
    math_num:{MATH1 | MATH2 | MATH3 | MATH4 | ...}[page:2-672]
    math_function:{first letter should be capital then calculate}[page:2-677]
    gating_type:{NONE | SCREEN | CURSor | LOGic | SEARch | TIMe }[page:2-754]
    """

    #針對display的通道新增測量項
    measurements = [
        {'channel': 'CH1','measurement': 'MEAN'},
        {'channel': 'CH2','measurement': 'MEAN'},
        {'channel': 'CH3','measurement': 'MEAN'}
    ]    
    
    #設定欲增加計算及公式
    mso_maths = [
        {'math_num': 'MATH1', 'math_function': 'Ch1-Meas6'},
        {'math_num': 'MATH2', 'math_function': 'Ch2-Meas7'},
        {'math_num': 'MATH3', 'math_function': 'Ch3-Meas8'},
        {'math_num': 'MATH4', 'math_function': 'Math1/10'},
        {'math_num': 'MATH5', 'math_function': 'Intg(Math2)'}
    ]
    
    #設定powerfunction內容 done
    powers = [
        {'Power_num': '1','Voltage_Source': 'MATH2', 'Current_Source': 'MATH4'},
        {'Power_num': '2','Voltage_Source': 'MATH3', 'Current_Source': 'MATH4'}
    ]

    #將特定通道停止顯示(display off)，可控制channel&math
    off_displays = [
        {'channel': 'NONE','math': 'MATH1'},
        {'channel': 'NONE','math': 'MATH2'},
        {'channel': 'NONE','math': 'MATH3'},
        {'channel': 'NONE','math': 'MATH6'},
        {'channel': 'NONE','math': 'MATH7'},
        {'channel': 'NONE','math': 'MATH8'},
        {'channel': 'NONE','math': 'MATH9'}
    ]

    #=====AFG_31101 parameter=====
    """
    shape:{SINusoid|SQUare|PULSe|RAMP|PRNoise|DC|SINC|GAUSsian|LORentz|ERISe|EDECay|HAVersine
     |EMEMory[1]|EMEMory2|EFILe} 
    amplitude:
        magnitude:output amplitude
        <units>::=[VPP | VRMS | DBM]
    frequency:
        magnitude:output frequency
        <units>::=[Hz | kHz | MHz]
    output_state:{ON|OFF}
    """
    #設置輸入源訊號參數
    shape = 'SINusoid'
    frequency = {'magnitude': '500','unit': 'KHz'}
    amplitude = {'magnitude': '280E-3','unit': 'VPP'}
    output_state = "ON"
    amplitude_limit = 0.5

    #=======RF_150A_100D parameter======
    """
    Gain : 0~100
    Power state : { ON | OFF }
    """
    #設置射極功率放大器參數
    gain = 5
    power_state = 'ON'
    
    #====================Instrument Connect Test===========================
    #=====MSO64B connection===
    MSO_instrument_address = 'USB0::0x0699::0x0530::C048992::INSTR'
    mso = MSO_64B(MSO_instrument_address)
    
    #=====AFG_31101 connection=====
    AFG_instrument_address = 'USB0::0x0699::0x0359::C016504::INSTR'
    afg = AFG_31101(AFG_instrument_address)

    #=====RF_150A_100D connection=====
    RF_instrument_address = 'USB0::0x0547::0x1B58::0358752::INSTR'
    rf = RF_150A100D(RF_instrument_address)
    #若有其他儀器串接下去...
    
    #============================Auto Test================================= 
    # # TO DO: 這邊給你寫For迴圈自動測量的區域
    
    #=====MSO64B control=====
    mso.result_table()#新增measurement result table的介面
    
    # #===新增測量項目及功率測量項==    
    # for measurement in measurements:
    #     channel = measurement['channel']
    #     meas = measurement['measurement']
    #     mso.add_measurement(meas,channel)  

    set_cursor_range(afg, mso)
    
    # #回傳math部分需要的公式
    # for mso_math in mso_maths:
    #     math_num = mso_math['math_num']
    #     math_function = mso_math['math_function']
    #     mso.math_add(math_num, math_function)
            
    # mso.set_gating_type() #調整measurement的gating type
    # mso.measure_delta_B() #執行測量Bmax&Bmin
    
    # for power in powers:
    #     num = power['Power_num']
    #     voltage = power['Voltage_Source']
    #     current = power['Current_Source']
    #     mso.power_function(num,voltage, current)

    # for off_display in off_displays:
    #     off_channel = off_display['channel']
    #     off_math = off_display['math']
    #     mso.off_display(off_channel,off_math)

    #=====RF_150A_100D control=====
    gain_set = calculate_gain_set(gain)  # 計算增益設置值
    rf.set_gain(gain, gain_set)

    check_power_state(rf, power_state) #判斷放大power狀態，是開或關
    
    #=====AFG_31101 control=====
    afg.set_waveform(shape) #設置訊號類
    afg.set_frequency(frequency['magnitude'],frequency['unit']) #設置訊號頻率
    afg.set_amplitude(amplitude['magnitude'],amplitude['unit']) #設置訊號振幅

    check_output_state(afg, output_state) #判斷輸出狀態，是開或關
    check_amp_limit(afg, amplitude_limit)  # 檢查振幅是否超過限制
    
    #===Autoset horizon & vertical scale===
    mso.clear()
    wait_for_population(mso, threshold=5) #先等待pop到10再抓數值
    set_horizon_scale(afg, mso)

    mso.clear()
    wait_for_population(mso, threshold=5)
    set_vertical_scale(mso)
        
    #=====start measure & save data to Excel by pandas======
    #=====core parameter=====
    #記錄待測鐵心知各樣參數
    core_type = 'ML95S'
    core_effective_length = 0.0304 #unit:m
    core_effective_area = 1.68e-5 #unit:m^2
    core_effective_volume = 5.1265e-7 #unit:m^3
    turn = 3 #unit:turn
    
    #===開始量測===
    # 設定測量順序、目標 delta B 值及desekw Vref的角度
    sequences = [1, 2, 3, 4, 5, 6]
    expect_deltaB = [0.02, 0.04, 0.06, 0.08, 0.1, 0.12]
    deskew_vref = 1
    
    # 將這個值的字典先重製歸零
    vin_amplitude = {}
    power_gain ={}
    max_B = {}
    min_B = {}
    delta_B ={}
    Pcore_true_power = {}
    PL_true_power = {}
    max_B_deskew = {}
    min_B_deskew = {}
    delta_B_deskew ={}
    Pcore_true_power_deskew = {}
    PL_true_power_deskew = {}
    k_factor = {}
    Pcore = {}
    Pcore_cv = {}
    
    #===第一次測量===
    for i in sequences:
        print(f"[第{i}次測量]")
    
        #===自動調整激勵源===
        target_deltaB = expect_deltaB[i-1] #從expect deltaB抓出當下對應預期要達到的deltaB
        wait_for_population(mso, threshold=5) #讓最測量的最一開始先等待一下再抓delta B
        amplitude, gain = adjust_rf_afg(mso, rf, afg, i, core_effective_area, turn, target_deltaB, gain, amplitude, amplitude_limit)
    
        vin_amplitude[i] = amplitude['magnitude']
        print(vin_amplitude)
        power_gain[i] = gain
        print(power_gain)
    
        #===開始抓值===
        mso.set_deskew_zero() #將channel1(Vref)的Deskew歸零
    
        wait_for_population(mso) #先等待pop到一定次數再抓數值
        
        acquire_measurement(mso, i, core_effective_area, turn, max_B, min_B, delta_B, Pcore_true_power, PL_true_power)
        
        set_vref_deskew(afg, mso, deskew_vref) #設定Vref deskew
        print("對Vref Deskew")
    
        mso.clear()
        wait_for_population(mso) #先等待pop到一定次數再抓數值
    
        acquire_measurement(mso, i, core_effective_area, turn, max_B_deskew, min_B_deskew, delta_B_deskew, Pcore_true_power_deskew, PL_true_power_deskew, deskew=True)
    
        # 計算 k_factor, Pcore, Pcore_cv
        k_factor[i], Pcore[i], Pcore_cv[i] = calculate_core_parameters(i, Pcore_true_power, PL_true_power, Pcore_true_power_deskew, PL_true_power_deskew, core_effective_volume)
    
    #=====測量完畢，關閉儀器====
    print("已經測量完畢")
    afg.output_off() #資料儲存完畢，關閉AFG
    rf.power_off() #資料儲存完畢，關閉RF
    
    #=====將所有資料丟到data最後建立成DataFrame=====
    data = {
        ("core parameter","type of core"): [core_type] * len(sequences),
        ("core parameter","effective length of core"): [core_effective_length] * len(sequences),
        ("core parameter","effective area of core"): [core_effective_area] * len(sequences),
        ("core parameter","effective volume of core"): [core_effective_volume] * len(sequences),
        ("core parameter","turns of wire on the core"): [turn] * len(sequences),
        ("Test environment (R=10)", "Sequence"): sequences,
        ("Test environment (R=10)", "Vin(Vpp)"): [vin_amplitude[seq] for seq in sequences], #每次調整都要重新記錄
        ("Test environment (R=10)", "Gain"): [power_gain[seq] for seq in sequences], #每次調整都要記錄
        ("Test environment (R=10)", "deltaB(T)"): expect_deltaB,
        ("flux density (DS=0)", "Max"): [v for seq, v in max_B['MEAS9']],
        ("flux density (DS=0)", "Min"): [v for seq, v in min_B['MEAS10']],
        ("flux density (DS=0)", "delta B(T)"): [delta_B[seq] for seq in sequences],
        ("L(DS=0 degree)", "P(W)"): [v for seq, v in Pcore_true_power['1']],
        ("CL(DS=0 degree)", "P(W)"): [v for seq, v in PL_true_power['2']],
        ("flux density (DS=1)", "Max"): [v for seq, v in max_B_deskew['MEAS9']],
        ("flux density (DS=1)", "Min"): [v for seq, v in min_B_deskew['MEAS10']],
        ("flux density (DS=1)", "delta B(T)"): [delta_B_deskew[seq] for seq in sequences],
        ("L(DS=1 degree)", "P(W)"): [v for seq, v in Pcore_true_power_deskew['1']],
        ("CL(DS=1 degree)", "P(W)"): [v for seq, v in PL_true_power_deskew['2']],
        ("Final calculate","K"):[k_factor[seq] for seq in sequences],
        ("Final calculate","Real Pcore(W)"):[Pcore[seq] for seq in sequences],
        ("Final calculate","Real Pcv(W/m^3)"):[Pcore_cv[seq] for seq in sequences]
    }

    # 建立MultiIndex
    index = pd.MultiIndex.from_tuples(data.keys())

    #建立DataFrame
    df = pd.DataFrame(data) #用一代號表示整個二維資料
    df.columns = index

    #顯示DataFrame
    print(df) #列出來

    #儲存為Excel文件
    df.to_csv('instruments_measurement_results.csv', index=False) #將資料弄成一個CSV檔
    
    # ============================ Close Instrument =================================
    afg.close_instrument()
    mso.close_instrument()
    rf.close_instrument()
    
if __name__ == "__main__":
    main()
# Out:
# Connected to MSO64B.
# TEKTRONIX,MSO64B,C048992,CF:91.1CT FV:1.44.3.433
#
# Connected to AFG_31101.
# TEKTRONIX,AFG31101,C016504,SCPI:99.0 FV:1.6.1
#
# Connected to RF_150A100D.
# AR-RF/MICROWAVE-INST,150A100D,1.0
#
# add measurent result table
# the frequency of excitaton is 500000.0
# set cursor range be -3e-06 to 3e-06
# set power gain be 5
# turn RF150A100D power on
# set excitation form be SINusoid
# set excitation frequency be 500KHz
# set excitation amplitude be 280E-3VPP
# turn AFG31101 output on
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 15
# Poplution採樣數量已超過 5
# the frequency of excitaton is 500000.0
# set Horizontal Scale to 8e-07s/div
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 20
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 1.39928817151
# set CH1 vertical scale be 0.1998983102157143
# CH1 no clipping, auto set vertical scale to 0.1998983102157143
# clipping state:0.0
# amplitude of CH2 is 3.392382891477
# set CH2 vertical scale be 0.48462612735385713
# CH2 no clipping, auto set vertical scale to 0.48462612735385713
# clipping state:0.0
# amplitude of CH3 is 1.0892290115083
# set CH3 vertical scale be 0.15560414450118573
# CH3 no clipping, auto set vertical scale to 0.15560414450118573
# [第1次測量]
# Current population: 7
# Poplution採樣數量已超過 5
# The maximum B value is 5.083626319901668e-07 T
# The minimum B value is -5.842212758011556e-07 T
# The delta of B is 0.021678252138716717 T
# delta B 小於50 mT
# 實際 delta B: 0.021678252138716717 與預期 delta B: 0.02 差了 -0.0016782521387167168T
# 實際deltaB大於預期deltaB 0.0005
# AFG 振幅已減少 2V， 設為278.0E-3 VPP
# 增益減少 3
# set excitation amplitude be 278.0E-3VPP
# set power gain be 2
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 20
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 1.3126148688506
# set CH1 vertical scale be 0.1875164098358
# CH1 no clipping, auto set vertical scale to 0.1875164098358
# clipping state:0.0
# amplitude of CH2 is 3.173900624752
# set CH2 vertical scale be 0.45341437496457143
# CH2 no clipping, auto set vertical scale to 0.45341437496457143
# clipping state:0.0
# amplitude of CH3 is 1.0168144011087
# set CH3 vertical scale be 0.1452592001583857
# CH3 no clipping, auto set vertical scale to 0.1452592001583857
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '278.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 2
# The maximum B value is 4.696991204866663e-07 T
# The minimum B value is -5.521410741948785e-07 T
# The delta of B is 0.02027460703733224 T
# 調整後的 delta B: 0.02027460703733224
# delta B已達預期的0.02
# {1: '278.0E-3'}
# {1: 2}
# CH1 deskew set to 0
# Current population: 8
# Current population: 19
# Current population: 39
# Current population: 59
# Current population: 79
# Current population: 98
# Current population: 119
# Poplution採樣數量已超過 100
# The maximum B value is 4.829720938102707e-07 T
# The minimum B value is -5.404442385762803e-07 T
# The delta of B is 0.020305879610844266 T
# The true power of 1 is 0.0008636843073732852 W
# The true power of 2 is 7.78435677620801e-05 W
# Deskew time of CH1 = 5.555555555555556e-09
# CH1 deskew set to 5.555555555555556e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 15
# Current population: 35
# Current population: 54
# Current population: 74
# Current population: 94
# Current population: 114
# Poplution採樣數量已超過 100
# The maximum B value is 4.748829754537821e-07 T
# The minimum B value is -5.486742902180795e-07 T
# The delta of B is 0.020308675906187734 T
# The true power of 1 is 0.0017208639654392 W
# The true power of 2 is 0.0003948269575038796 W
# k factor:0.36979807763639716
# Core Real power loss:0.0008348979056585094
# Every volume of Core Real power loss:1628.5924230147457
# [第2次測量]
# Current population: 118
# Poplution採樣數量已超過 5
# The maximum B value is 4.750057026556823e-07 T
# The minimum B value is -5.485626909357046e-07 T
# The delta of B is 0.020308896698241805 T
# delta B 小於50 mT
# 實際 delta B: 0.020308896698241805 與預期 delta B: 0.04 差了 0.019691103301758196T
# delta B 誤差大於 0.012
# AFG 振幅已增加 3V，設為281.0E-3 VPP
# 增益增加 10
# set excitation amplitude be 281.0E-3VPP
# set power gain be 12
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 16
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 1.6300378669419
# set CH1 vertical scale be 0.23286255242027143
# CH1 no clipping, auto set vertical scale to 0.23286255242027143
# clipping state:0.0
# amplitude of CH2 is 3.93858323564
# set CH2 vertical scale be 0.5626547479485714
# CH2 no clipping, auto set vertical scale to 0.5626547479485714
# clipping state:1.0
# set CH3 vertical scale be 0.185259
# CH3 is clipping, auto set vertical scale from 0.145259 to 0.185259
# clipping state:0.0
# amplitude of CH3 is 1.2572025708437
# set CH3 vertical scale be 0.1796003672633857
# CH3 no clipping, auto set vertical scale to 0.1796003672633857
# Current population: 11
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '281.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 12
# The maximum B value is 5.916498414156498e-07 T
# The minimum B value is -6.910532732717911e-07 T
# The delta of B is 0.02545045862475082 T
# 調整後的 delta B: 0.02545045862475082
# delta B 小於50 mT
# 實際 delta B: 0.02545045862475082 與預期 delta B: 0.04 差了 0.014549541375249182T
# delta B 誤差大於 0.012
# AFG 振幅已增加 3V，設為284.0E-3 VPP
# 增益增加 10
# set excitation amplitude be 284.0E-3VPP
# set power gain be 22
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 19
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 2.0917639023409
# set CH1 vertical scale be 0.29882341462012857
# CH1 no clipping, auto set vertical scale to 0.29882341462012857
# clipping state:0.0
# amplitude of CH2 is 5.1069287314253
# set CH2 vertical scale be 0.7295612473464714
# CH2 no clipping, auto set vertical scale to 0.7295612473464714
# clipping state:1.0
# set CH3 vertical scale be 0.21960000000000002
# CH3 is clipping, auto set vertical scale from 0.1796 to 0.21960000000000002
# clipping state:0.0
# amplitude of CH3 is 1.6185809567977
# set CH3 vertical scale be 0.23122585097110002
# CH3 no clipping, auto set vertical scale to 0.23122585097110002
# Current population: 12
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '284.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 22
# The maximum B value is 7.750298541745556e-07 T
# The minimum B value is -8.790441064285495e-07 T
# The delta of B is 0.03281892778974416 T
# 調整後的 delta B: 0.03281892778974416
# delta B 小於50 mT
# 實際 delta B: 0.03281892778974416 與預期 delta B: 0.04 差了 0.007181072210255844T
# delta B 誤差介於 0.006 ~ 0.012
# 增益增加 5
# set excitation amplitude be 284.0E-3VPP
# set power gain be 27
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 16
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 2.3856294968421
# set CH1 vertical scale be 0.34080421383458576
# CH1 no clipping, auto set vertical scale to 0.34080421383458576
# clipping state:0.0
# amplitude of CH2 is 5.869895272927
# set CH2 vertical scale be 0.838556467561
# CH2 no clipping, auto set vertical scale to 0.838556467561
# clipping state:0.0
# amplitude of CH3 is 1.8468948426862
# set CH3 vertical scale be 0.26384212038374283
# CH3 no clipping, auto set vertical scale to 0.26384212038374283
# Current population: 7
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '284.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 27
# The maximum B value is 8.92590463763554e-07 T
# The minimum B value is -1.0093390727661e-06 T
# The delta of B is 0.03773669715336616 T
# 調整後的 delta B: 0.03773669715336616
# delta B 小於50 mT
# 實際 delta B: 0.03773669715336616 與預期 delta B: 0.04 差了 0.002263302846633841T
# delta B 誤差介於 0.0005 ~ 0.003
# 增益增加 1
# set excitation amplitude be 284.0E-3VPP
# set power gain be 28
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 20
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 2.4537639479315
# set CH1 vertical scale be 0.35053770684735713
# CH1 no clipping, auto set vertical scale to 0.35053770684735713
# clipping state:0.0
# amplitude of CH2 is 6.039371120342
# set CH2 vertical scale be 0.862767302906
# CH2 no clipping, auto set vertical scale to 0.862767302906
# clipping state:0.0
# amplitude of CH3 is 1.9120251773507
# set CH3 vertical scale be 0.27314645390724285
# CH3 no clipping, auto set vertical scale to 0.27314645390724285
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '284.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 28
# The maximum B value is 9.1603887852898e-07 T
# The minimum B value is -1.0396934015944e-06 T
# The delta of B is 0.03880421190720993 T
# 調整後的 delta B: 0.03880421190720993
# delta B 小於50 mT
# 實際 delta B: 0.03880421190720993 與預期 delta B: 0.04 差了 0.0011957880927900705T
# delta B 誤差介於 0.0005 ~ 0.003
# 增益增加 1
# set excitation amplitude be 284.0E-3VPP
# set power gain be 29
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 20
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 2.5215348636548
# set CH1 vertical scale be 0.3602192662364
# CH1 no clipping, auto set vertical scale to 0.3602192662364
# clipping state:0.0
# amplitude of CH2 is 6.2032962336426
# set CH2 vertical scale be 0.8861851762346572
# CH2 no clipping, auto set vertical scale to 0.8861851762346572
# clipping state:0.0
# amplitude of CH3 is 1.962903614567
# set CH3 vertical scale be 0.280414802081
# CH3 no clipping, auto set vertical scale to 0.280414802081
# Current population: 9
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '284.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 29
# The maximum B value is 9.469989789876207e-07 T
# The minimum B value is -1.0658763913954e-06 T
# The delta of B is 0.0399380033806155 T
# 調整後的 delta B: 0.0399380033806155
# delta B已達預期的0.04
# {1: '278.0E-3', 2: '284.0E-3'}
# {1: 2, 2: 29}
# CH1 deskew set to 0
# Current population: 9
# Current population: 18
# Current population: 38
# Current population: 58
# Current population: 78
# Current population: 98
# Current population: 118
# Poplution採樣數量已超過 100
# The maximum B value is 9.6121294216003e-07 T
# The minimum B value is -1.0509432461983e-06 T
# The delta of B is 0.039923733895998625 T
# The true power of 1 is 0.0054093721096712 W
# The true power of 2 is 0.0004323620806821902 W
# Deskew time of CH1 = 5.555555555555556e-09
# CH1 deskew set to 5.555555555555556e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 19
# Current population: 39
# Current population: 59
# Current population: 78
# Current population: 98
# Current population: 118
# Poplution採樣數量已超過 100
# The maximum B value is 9.462743861615859e-07 T
# The minimum B value is -1.065105706624e-06 T
# The delta of B is 0.03990833517431719 T
# The true power of 1 is 0.0086014825967766 W
# The true power of 2 is 0.0014321290034234 W
# k factor:0.31319934782326314
# Core Real power loss:0.005273956587978029
# Every volume of Core Real power loss:10287.635985522344
# [第3次測量]
# Current population: 122
# Poplution採樣數量已超過 5
# The maximum B value is 9.462926517536415e-07 T
# The minimum B value is -1.0651251124165e-06 T
# The delta of B is 0.039909082622423445 T
# delta B 小於50 mT
# 實際 delta B: 0.039909082622423445 與預期 delta B: 0.06 差了 0.020090917377576553T
# delta B 誤差大於 0.012
# AFG 振幅已增加 3V，設為287.0E-3 VPP
# 增益增加 10
# set excitation amplitude be 287.0E-3VPP
# set power gain be 39
# clear acquistions, measurements, and waveforms
# Current population: 126
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 3.4219689527351
# set CH1 vertical scale be 0.4888527075335857
# CH1 no clipping, auto set vertical scale to 0.4888527075335857
# clipping state:1.0
# set CH2 vertical scale be 0.926185
# CH2 is clipping, auto set vertical scale from 0.886185 to 0.926185
# clipping state:0.0
# amplitude of CH2 is 8.4999392225517
# set CH2 vertical scale be 1.2142770317931
# CH2 no clipping, auto set vertical scale to 1.2142770317931
# clipping state:1.0
# set CH3 vertical scale be 0.320415
# CH3 is clipping, auto set vertical scale from 0.280415 to 0.320415
# clipping state:0.0
# amplitude of CH3 is 2.6761257501213
# set CH3 vertical scale be 0.38230367858875713
# CH3 no clipping, auto set vertical scale to 0.38230367858875713
# Current population: 11
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '287.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 39
# The maximum B value is 1.3109965845036e-06 T
# The minimum B value is -1.4555577391465e-06 T
# The delta of B is 0.054891950866073416 T
# 調整後的 delta B: 0.054891950866073416
# delta B 大於50 mT
# 實際 delta B: 0.054891950866073416 與預期 delta B: 0.06 差了 0.0051080491339265816T
# delta B 誤差介於 0.003 ~ 0.006
# 增益增加 2
# set excitation amplitude be 287.0E-3VPP
# set power gain be 41
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 20
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 3.6360334814294
# set CH1 vertical scale be 0.5194333544899143
# CH1 no clipping, auto set vertical scale to 0.5194333544899143
# clipping state:0.0
# amplitude of CH2 is 9.0687597503309
# set CH2 vertical scale be 1.2955371071901285
# CH2 no clipping, auto set vertical scale to 1.2955371071901285
# clipping state:0.0
# amplitude of CH3 is 2.8310230275442
# set CH3 vertical scale be 0.4044318610777428
# CH3 no clipping, auto set vertical scale to 0.4044318610777428
# Current population: 7
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '287.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 41
# The maximum B value is 1.40445804675e-06 T
# The minimum B value is -1.5462976250546e-06 T
# The delta of B is 0.05854673951993255 T
# 調整後的 delta B: 0.05854673951993255
# delta B 大於50 mT
# 實際 delta B: 0.05854673951993255 與預期 delta B: 0.06 差了 0.001453260480067449T
# delta B 誤差介於 0.001 ~ 0.003
# 增益增加 1
# set excitation amplitude be 287.0E-3VPP
# set power gain be 42
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 20
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 3.7408624357582
# set CH1 vertical scale be 0.5344089193940286
# CH1 no clipping, auto set vertical scale to 0.5344089193940286
# clipping state:0.0
# amplitude of CH2 is 9.3718083118362
# set CH2 vertical scale be 1.3388297588337428
# CH2 no clipping, auto set vertical scale to 1.3388297588337428
# clipping state:0.0
# amplitude of CH3 is 2.935328105498
# set CH3 vertical scale be 0.4193325864997143
# CH3 no clipping, auto set vertical scale to 0.4193325864997143
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '287.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 42
# The maximum B value is 1.4485083031306e-06 T
# The minimum B value is -1.5951944886991e-06 T
# The delta of B is 0.06039092840931945 T
# 調整後的 delta B: 0.06039092840931945
# delta B已達預期的0.06
# {1: '278.0E-3', 2: '284.0E-3', 3: '287.0E-3'}
# {1: 2, 2: 29, 3: 42}
# CH1 deskew set to 0
# Current population: 9
# Current population: 18
# Current population: 38
# Current population: 58
# Current population: 78
# Current population: 97
# Current population: 117
# Poplution採樣數量已超過 100
# The maximum B value is 1.4763060955559e-06 T
# The minimum B value is -1.57088304874e-06 T
# The delta of B is 0.0604601020693631 T
# The true power of 1 is 0.0144648116072814 W
# The true power of 2 is 0.0003434267163213232 W
# Deskew time of CH1 = 5.555555555555556e-09
# CH1 deskew set to 5.555555555555556e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 20
# Current population: 40
# Current population: 60
# Current population: 80
# Current population: 100
# Poplution採樣數量已超過 100
# The maximum B value is 1.4479874490723e-06 T
# The minimum B value is -1.5974091677053e-06 T
# The delta of B is 0.06042453604717461 T
# The true power of 1 is 0.0220531221829232 W
# The true power of 2 is 0.0029996723009213 W
# k factor:0.3500443950101922
# Core Real power loss:0.014344597010136365
# Every volume of Core Real power loss:27981.267941356415
# [第4次測量]
# Current population: 104
# Poplution採樣數量已超過 5
# The maximum B value is 1.4479776826279e-06 T
# The minimum B value is -1.5973393168506e-06 T
# The delta of B is 0.060422956338859135 T
# delta B 大於50 mT
# 實際 delta B: 0.060422956338859135 與預期 delta B: 0.08 差了 0.019577043661140867T
# delta B 誤差大於 0.01
# AFG 振幅已增加 2V，設為289.0E-3 VPP
# 增益增加 4
# set excitation amplitude be 289.0E-3VPP
# set power gain be 46
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 20
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 4.3092170239883
# set CH1 vertical scale be 0.6156024319983285
# CH1 no clipping, auto set vertical scale to 0.6156024319983285
# clipping state:0.0
# amplitude of CH2 is 10.8536913793477
# set CH2 vertical scale be 1.5505273399068142
# CH2 no clipping, auto set vertical scale to 1.5505273399068142
# clipping state:0.0
# amplitude of CH3 is 3.37366868066
# set CH3 vertical scale be 0.48195266866571423
# CH3 no clipping, auto set vertical scale to 0.48195266866571423
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '289.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 46
# The maximum B value is 1.6837065572872e-06 T
# The minimum B value is -1.847590922921e-06 T
# The delta of B is 0.07006542619460715 T
# 調整後的 delta B: 0.07006542619460715
# delta B 大於70 mT
# 實際 delta B: 0.07006542619460715 與預期 delta B: 0.08 差了 0.009934573805392852T
# delta B 誤差介於 0.006 ~ 0.01
# 增益增加 2
# set excitation amplitude be 289.0E-3VPP
# set power gain be 48
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 18
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 4.5979288857437
# set CH1 vertical scale be 0.6568469836776715
# CH1 no clipping, auto set vertical scale to 0.6568469836776715
# clipping state:0.0
# amplitude of CH2 is 11.6049486962819
# set CH2 vertical scale be 1.6578498137545572
# CH2 no clipping, auto set vertical scale to 1.6578498137545572
# clipping state:0.0
# amplitude of CH3 is 3.5955321768326
# set CH3 vertical scale be 0.5136474538332286
# CH3 no clipping, auto set vertical scale to 0.5136474538332286
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '289.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 48
# The maximum B value is 1.8128221057623e-06 T
# The minimum B value is -1.9746637462958e-06 T
# The delta of B is 0.0751485288106766 T
# 調整後的 delta B: 0.0751485288106766
# delta B 大於70 mT
# 實際 delta B: 0.0751485288106766 與預期 delta B: 0.08 差了 0.0048514711893234T
# delta B 誤差介於 0.003 ~ 0.006
# 增益增加 1
# set excitation amplitude be 289.0E-3VPP
# set power gain be 49
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 18
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 4.7520705621763
# set CH1 vertical scale be 0.6788672231680428
# CH1 no clipping, auto set vertical scale to 0.6788672231680428
# clipping state:0.0
# amplitude of CH2 is 12.0615272643907
# set CH2 vertical scale be 1.7230753234843856
# CH2 no clipping, auto set vertical scale to 1.7230753234843856
# clipping state:0.0
# amplitude of CH3 is 3.7221109101068
# set CH3 vertical scale be 0.5317301300152572
# CH3 no clipping, auto set vertical scale to 0.5317301300152572
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '289.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 49
# The maximum B value is 1.8723935934557e-06 T
# The minimum B value is -2.0515133201116e-06 T
# The delta of B is 0.07785529590411311 T
# 調整後的 delta B: 0.07785529590411311
# delta B 大於70 mT
# 實際 delta B: 0.07785529590411311 與預期 delta B: 0.08 差了 0.002144704095886893T
# delta B 誤差介於 0.0015 ~ 0.003
# 增益增加 1
# set excitation amplitude be 289.0E-3VPP
# set power gain be 50
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 16
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 4.9214281508813
# set CH1 vertical scale be 0.7030611644116143
# CH1 no clipping, auto set vertical scale to 0.7030611644116143
# clipping state:0.0
# amplitude of CH2 is 12.4761467363742
# set CH2 vertical scale be 1.7823066766248858
# CH2 no clipping, auto set vertical scale to 1.7823066766248858
# clipping state:0.0
# amplitude of CH3 is 3.8948334168541
# set CH3 vertical scale be 0.5564047738362999
# CH3 no clipping, auto set vertical scale to 0.5564047738362999
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '289.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 50
# The maximum B value is 1.94040890733e-06 T
# The minimum B value is -2.1361016706578e-06 T
# The delta of B is 0.08088314638864684 T
# 調整後的 delta B: 0.08088314638864684
# delta B已達預期的0.08
# {1: '278.0E-3', 2: '284.0E-3', 3: '287.0E-3', 4: '289.0E-3'}
# {1: 2, 2: 29, 3: 42, 4: 50}
# CH1 deskew set to 0
# Current population: 8
# Current population: 19
# Current population: 39
# Current population: 59
# Current population: 79
# Current population: 98
# Current population: 118
# Poplution採樣數量已超過 100
# The maximum B value is 1.9803432139782e-06 T
# The minimum B value is -2.0947524446165e-06 T
# The delta of B is 0.0808550725911647 T
# The true power of 1 is 0.030226072182491 W
# The true power of 2 is 0.0015042823067 W
# Deskew time of CH1 = 5.555555555555556e-09
# CH1 deskew set to 5.555555555555556e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 21
# Current population: 40
# Current population: 60
# Current population: 80
# Current population: 100
# Poplution採樣數量已超過 100
# The maximum B value is 1.9455799427323e-06 T
# The minimum B value is -2.1292682126076e-06 T
# The delta of B is 0.0808501618122996 T
# The true power of 1 is 0.0452323769170648 W
# The true power of 2 is 0.0059870049235207 W
# k factor:0.29872261666742816
# Core Real power loss:0.029776709035627062
# Every volume of Core Real power loss:58083.89551473142
# [第5次測量]
# Current population: 104
# Poplution採樣數量已超過 5
# The maximum B value is 1.9455008333309e-06 T
# The minimum B value is -2.1293476493156e-06 T
# The delta of B is 0.08085016830647819 T
# delta B 大於70 mT
# 實際 delta B: 0.08085016830647819 與預期 delta B: 0.1 差了 0.019149831693521815T
# delta B 誤差大於 0.01
# AFG 振幅已增加 1V，設為290.0E-3 VPP
# 增益增加 3
# set excitation amplitude be 290.0E-3VPP
# set power gain be 53
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 19
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 5.4661846553809
# set CH1 vertical scale be 0.7808835221972714
# CH1 no clipping, auto set vertical scale to 0.7808835221972714
# clipping state:0.0
# amplitude of CH2 is 14.0476456462097
# set CH2 vertical scale be 2.0068065208871
# CH2 no clipping, auto set vertical scale to 2.0068065208871
# clipping state:0.0
# amplitude of CH3 is 4.3259557330576
# set CH3 vertical scale be 0.6179936761510857
# CH3 no clipping, auto set vertical scale to 0.6179936761510857
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '290.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 53
# The maximum B value is 2.1833291441453e-06 T
# The minimum B value is -2.3964466038251e-06 T
# The delta of B is 0.09086856642798415 T
# 調整後的 delta B: 0.09086856642798415
# delta B 大於70 mT
# 實際 delta B: 0.09086856642798415 與預期 delta B: 0.1 差了 0.00913143357201586T
# delta B 誤差介於 0.006 ~ 0.01
# 增益增加 2
# set excitation amplitude be 290.0E-3VPP
# set power gain be 55
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 21
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 5.8573258999959
# set CH1 vertical scale be 0.8367608428565572
# CH1 no clipping, auto set vertical scale to 0.8367608428565572
# clipping state:0.0
# amplitude of CH2 is 15.1715173656319
# set CH2 vertical scale be 2.1673596236617
# CH2 no clipping, auto set vertical scale to 2.1673596236617
# clipping state:0.0
# amplitude of CH3 is 4.6121215666023
# set CH3 vertical scale be 0.6588745095146143
# CH3 no clipping, auto set vertical scale to 0.6588745095146143
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '290.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 55
# The maximum B value is 2.3491091067424e-06 T
# The minimum B value is -2.6017891438338e-06 T
# The delta of B is 0.09823210814635319 T
# 調整後的 delta B: 0.09823210814635319
# delta B 大於70 mT
# 實際 delta B: 0.09823210814635319 與預期 delta B: 0.1 差了 0.0017678918536468136T
# delta B 誤差介於 0.0015 ~ 0.003
# 增益增加 1
# set excitation amplitude be 290.0E-3VPP
# set power gain be 56
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 20
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 6.0653762967464
# set CH1 vertical scale be 0.8664823281066286
# CH1 no clipping, auto set vertical scale to 0.8664823281066286
# clipping state:0.0
# amplitude of CH2 is 15.7546063399542
# set CH2 vertical scale be 2.250658048564886
# CH2 no clipping, auto set vertical scale to 2.250658048564886
# clipping state:0.0
# amplitude of CH3 is 4.8350451699747
# set CH3 vertical scale be 0.6907207385678144
# CH3 no clipping, auto set vertical scale to 0.6907207385678144
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '290.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 56
# The maximum B value is 2.4600017241028e-06 T
# The minimum B value is -2.6845668799069e-06 T
# The delta of B is 0.10207477388908137 T
# 調整後的 delta B: 0.10207477388908137
# delta B 大於70 mT
# 實際 delta B: 0.10207477388908137 與預期 delta B: 0.1 差了 -0.002074773889081366T
# 實際deltaB大於預期deltaB 0.0015
# AFG 振幅已減少 5V， 設為285.0E-3 VPP
# 增益減少 1
# set excitation amplitude be 285.0E-3VPP
# set power gain be 55
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 16
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 5.7500373691511
# set CH1 vertical scale be 0.8214339098787286
# CH1 no clipping, auto set vertical scale to 0.8214339098787286
# clipping state:0.0
# amplitude of CH2 is 14.8536127663461
# set CH2 vertical scale be 2.121944680906586
# CH2 no clipping, auto set vertical scale to 2.121944680906586
# clipping state:0.0
# amplitude of CH3 is 4.5742999459665
# set CH3 vertical scale be 0.6534714208523571
# CH3 no clipping, auto set vertical scale to 0.6534714208523571
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '285.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 55
# The maximum B value is 2.3166038545241e-06 T
# The minimum B value is -2.5323270165245e-06 T
# The delta of B is 0.09620894585413892 T
# 調整後的 delta B: 0.09620894585413892
# delta B 大於70 mT
# 實際 delta B: 0.09620894585413892 與預期 delta B: 0.1 差了 0.003791054145861089T
# delta B 誤差介於 0.003 ~ 0.006
# 增益增加 1
# set excitation amplitude be 285.0E-3VPP
# set power gain be 56
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 18
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 5.9552961634715
# set CH1 vertical scale be 0.8507565947816429
# CH1 no clipping, auto set vertical scale to 0.8507565947816429
# clipping state:0.0
# amplitude of CH2 is 15.4927658025443
# set CH2 vertical scale be 2.2132522575063285
# CH2 no clipping, auto set vertical scale to 2.2132522575063285
# clipping state:0.0
# amplitude of CH3 is 4.7223898040508
# set CH3 vertical scale be 0.6746271148644
# CH3 no clipping, auto set vertical scale to 0.6746271148644
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '285.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 56
# The maximum B value is 2.4084119161216e-06 T
# The minimum B value is -2.6409021529616e-06 T
# The delta of B is 0.10018480295800002 T
# 調整後的 delta B: 0.10018480295800002
# delta B已達預期的0.1
# {1: '278.0E-3', 2: '284.0E-3', 3: '287.0E-3', 4: '289.0E-3', 5: '285.0E-3'}
# {1: 2, 2: 29, 3: 42, 4: 50, 5: 56}
# CH1 deskew set to 0
# Current population: 8
# Current population: 17
# Current population: 36
# Current population: 56
# Current population: 76
# Current population: 96
# Current population: 116
# Poplution採樣數量已超過 100
# The maximum B value is 2.4523288857381e-06 T
# The minimum B value is -2.5990115295243e-06 T
# The delta of B is 0.10022500823933335 T
# The true power of 1 is 0.0591771418966713 W
# The true power of 2 is 0.0035539686374714 W
# Deskew time of CH1 = 5.555555555555556e-09
# CH1 deskew set to 5.555555555555556e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 19
# Current population: 39
# Current population: 59
# Current population: 79
# Current population: 99
# Current population: 119
# Poplution採樣數量已超過 100
# The maximum B value is 2.40775392656e-06 T
# The minimum B value is -2.6446227271511e-06 T
# The delta of B is 0.1002455685260139 T
# The true power of 1 is 0.0803350883072193 W
# The true power of 2 is 0.0086981857633583 W
# k factor:0.24313404647448783
# Core Real power loss:0.05831305112079946
# Every volume of Core Real power loss:113748.27098566169
# [第6次測量]
# Current population: 123
# Poplution採樣數量已超過 5
# The maximum B value is 2.4077283645359e-06 T
# The minimum B value is -2.6447616230672e-06 T
# The delta of B is 0.10024781721434725 T
# delta B 大於70 mT
# 實際 delta B: 0.10024781721434725 與預期 delta B: 0.12 差了 0.019752182785652744T
# delta B 誤差大於 0.01
# AFG 振幅已增加 1V，設為286.0E-3 VPP
# 增益增加 3
# set excitation amplitude be 286.0E-3VPP
# set power gain be 59
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 15
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 6.6500977833873
# set CH1 vertical scale be 0.9500139690553285
# CH1 no clipping, auto set vertical scale to 0.9500139690553285
# clipping state:0.0
# amplitude of CH2 is 17.602313825135
# set CH2 vertical scale be 2.5146162607335714
# CH2 no clipping, auto set vertical scale to 2.5146162607335714
# clipping state:0.0
# amplitude of CH3 is 5.2997194994441
# set CH3 vertical scale be 0.7571027856348714
# CH3 no clipping, auto set vertical scale to 0.7571027856348714
# Current population: 9
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '286.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 59
# The maximum B value is 2.7361649396577e-06 T
# The minimum B value is -3.0007748945435e-06 T
# The delta of B is 0.1138281713135159 T
# 調整後的 delta B: 0.1138281713135159
# delta B 大於70 mT
# 實際 delta B: 0.1138281713135159 與預期 delta B: 0.12 差了 0.006171828686484096T
# delta B 誤差介於 0.006 ~ 0.01
# 增益增加 2
# set excitation amplitude be 286.0E-3VPP
# set power gain be 61
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 17
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 7.1335209573909
# set CH1 vertical scale be 1.0190744224844142
# CH1 no clipping, auto set vertical scale to 1.0190744224844142
# clipping state:0.0
# amplitude of CH2 is 19.0836747959908
# set CH2 vertical scale be 2.726239256570114
# CH2 no clipping, auto set vertical scale to 2.726239256570114
# clipping state:0.0
# amplitude of CH3 is 5.6957108784084
# set CH3 vertical scale be 0.8136729826297715
# CH3 no clipping, auto set vertical scale to 0.8136729826297715
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '286.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 61
# The maximum B value is 2.9719421092977e-06 T
# The minimum B value is -3.2725936307543e-06 T
# The delta of B is 0.12389951865182541 T
# 調整後的 delta B: 0.12389951865182541
# delta B 大於70 mT
# 實際 delta B: 0.12389951865182541 與預期 delta B: 0.12 差了 -0.0038995186518254177T
# 實際deltaB大於預期deltaB 0.0015
# AFG 振幅已減少 5V， 設為281.0E-3 VPP
# 增益減少 1
# set excitation amplitude be 281.0E-3VPP
# set power gain be 60
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 17
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 6.759061546853
# set CH1 vertical scale be 0.965580220979
# CH1 no clipping, auto set vertical scale to 0.965580220979
# clipping state:0.0
# amplitude of CH2 is 18.0160486490646
# set CH2 vertical scale be 2.573721235580657
# CH2 no clipping, auto set vertical scale to 2.573721235580657
# clipping state:0.0
# amplitude of CH3 is 5.3981779936
# set CH3 vertical scale be 0.7711682848
# CH3 no clipping, auto set vertical scale to 0.7711682848
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '281.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 60
# The maximum B value is 2.7791051024906e-06 T
# The minimum B value is -3.0675156494908e-06 T
# The delta of B is 0.11600437999963097 T
# 調整後的 delta B: 0.11600437999963097
# delta B 大於70 mT
# 實際 delta B: 0.11600437999963097 與預期 delta B: 0.12 差了 0.0039956200003690295T
# delta B 誤差介於 0.003 ~ 0.006
# 增益增加 1
# set excitation amplitude be 281.0E-3VPP
# set power gain be 61
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 18
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 7.01043072899
# set CH1 vertical scale be 1.0014901041414286
# CH1 no clipping, auto set vertical scale to 1.0014901041414286
# clipping state:0.0
# amplitude of CH2 is 18.7226224692767
# set CH2 vertical scale be 2.6746603527538144
# CH2 no clipping, auto set vertical scale to 2.6746603527538144
# clipping state:0.0
# amplitude of CH3 is 5.5791172573037
# set CH3 vertical scale be 0.7970167510433858
# CH3 no clipping, auto set vertical scale to 0.7970167510433858
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '281.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 61
# The maximum B value is 2.89524023679e-06 T
# The minimum B value is -3.2090609288894e-06 T
# The delta of B is 0.12111708662062304 T
# 調整後的 delta B: 0.12111708662062304
# delta B已達預期的0.12
# {1: '278.0E-3', 2: '284.0E-3', 3: '287.0E-3', 4: '289.0E-3', 5: '285.0E-3', 6: '281.0E-3'}
# {1: 2, 2: 29, 3: 42, 4: 50, 5: 56, 6: 61}
# CH1 deskew set to 0
# Current population: 9
# Current population: 18
# Current population: 38
# Current population: 58
# Current population: 78
# Current population: 98
# Current population: 118
# Poplution採樣數量已超過 100
# The maximum B value is 2.9521448495716e-06 T
# The minimum B value is -3.1600418577061e-06 T
# The delta of B is 0.12127354577931947 T
# The true power of 1 is 0.1024933457631173 W
# The true power of 2 is 0.0041254107801133 W
# Deskew time of CH1 = 5.555555555555556e-09
# CH1 deskew set to 5.555555555555556e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 18
# Current population: 38
# Current population: 58
# Current population: 78
# Current population: 97
# Current population: 117
# Poplution採樣數量已超過 100
# The maximum B value is 2.9038807308437e-06 T
# The minimum B value is -3.21188277451e-06 T
# The delta of B is 0.12134451399511312 T
# The true power of 1 is 0.1321629948658717 W
# The true power of 2 is 0.0131369358693651 W
# k factor:0.3037287383494942
# Core Real power loss:0.10124033995170009
# Every volume of Core Real power loss:197484.32644435792
# 已經測量完畢
# turn AFG31101 output off
# turn RF150A100D power off
#   core parameter                                                  \
#     type of core effective length of core effective area of core
# 0          ML95S                   0.0304               0.000017
# 1          ML95S                   0.0304               0.000017
# 2          ML95S                   0.0304               0.000017
# 3          ML95S                   0.0304               0.000017
# 4          ML95S                   0.0304               0.000017
# 5          ML95S                   0.0304               0.000017
#
#                                                      Test environment (R=10)  \
#   effective volume of core turns of wire on the core                Sequence
# 0             5.126500e-07                         3                       1
# 1             5.126500e-07                         3                       2
# 2             5.126500e-07                         3                       3
# 3             5.126500e-07                         3                       4
# 4             5.126500e-07                         3                       5
# 5             5.126500e-07                         3                       6
#
#                            flux density (DS=0)  ... L(DS=0 degree)  \
#    Vin(Vpp) Gain deltaB(T)                 Max  ...           P(W)
# 0  278.0E-3    2      0.02        4.829721e-07  ...       0.000864
# 1  284.0E-3   29      0.04        9.612129e-07  ...       0.005409
# 2  287.0E-3   42      0.06        1.476306e-06  ...       0.014465
# 3  289.0E-3   50      0.08        1.980343e-06  ...       0.030226
# 4  285.0E-3   56      0.10        2.452329e-06  ...       0.059177
# 5  281.0E-3   61      0.12        2.952145e-06  ...       0.102493
#
#   CL(DS=0 degree) flux density (DS=1)                          L(DS=1 degree)  \
#              P(W)                 Max           Min delta B(T)           P(W)
# 0        0.000078        4.748830e-07 -5.486743e-07   0.020309       0.001721
# 1        0.000432        9.462744e-07 -1.065106e-06   0.039908       0.008601
# 2        0.000343        1.447987e-06 -1.597409e-06   0.060425       0.022053
# 3        0.001504        1.945580e-06 -2.129268e-06   0.080850       0.045232
# 4        0.003554        2.407754e-06 -2.644623e-06   0.100246       0.080335
# 5        0.004125        2.903881e-06 -3.211883e-06   0.121345       0.132163
#
#   CL(DS=1 degree) Final calculate
#              P(W)               K Real Pcore(W) Real Pcv(W/m^3)
# 0        0.000395        0.369798      0.000835     1628.592423
# 1        0.001432        0.313199      0.005274    10287.635986
# 2        0.003000        0.350044      0.014345    27981.267941
# 3        0.005987        0.298723      0.029777    58083.895515
# 4        0.008698        0.243134      0.058313   113748.270986
# 5        0.013137        0.303729      0.101240   197484.326444
#
# [6 rows x 22 columns]
# AFG_31101 connection closed.
# MSO64B connection closed.
# RF_150A100D connection closed.
