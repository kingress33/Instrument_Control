# %%
#引入需要的包裝

import pyvisa
import pandas as pd
import time
import math

# %% [markdown]
# ### AFG31101
#
# ===============Function List=================
#
# * Set weveform type
# * Set frequency
# * Set amplitude
# * Set output state
# * Set amplitude limit
#
# 若要串接其他儀器 一樣使用class 定義其他儀器的function

# %%
class AFG_31101():
    def __init__(self, resource_address, visa_dll=None):
        """
        初始化儀器控制器。
        :param resource_address: 儀器的資源地址。
        :param visa_dll: 使用的 VISA DLL 路徑。如果為 None，則使用系統預設空白。
        """
        self.resource_address = resource_address
        self.visa_dll = visa_dll if visa_dll is not None else ''
        self.rm = pyvisa.ResourceManager(self.visa_dll)
        self.instrument = None
        self.connect_to_instrument()
        
    def connect_to_instrument(self):
        # 建立與儀器的連接
        self.instrument = self.rm.open_resource(self.resource_address)
        print("Connected to AFG_31101.")
        print(self.query_identity())

    def query_identity(self):
         # 查詢並返回儀器的身份識別信息
        if self.instrument:
             return self.instrument.query("*IDN?")
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def close_instrument(self):
        if self.instrument:
            self.instrument.close()
            print("AFG_31101 connection closed.")
        else:
            print("No instrument to close.")

    def set_waveform(self, shape):
        if self.instrument:
            self.instrument.write(f"SOURce1:FUNCtion {shape}")
            time.sleep(0.05)
            print(f"set signal form be {shape}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_frequency(self, freq_amplitude, freq_unit):
        if self.instrument:
            self.instrument.write(f"SOURce1:FREQuency:FIXed {freq_amplitude} {freq_unit}")
            time.sleep(0.05)
            print(f"set signal frequency be {freq_amplitude}{freq_unit}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def query_frequency(self):
        if self.instrument:
            self.instrument.write(f"SOURce1:FREQuency:FIXed?")
            time.sleep(0.05)
            return self.instrument.read()
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_amplitude(self, amp_magnitude, amp_unit):
        if self.instrument:
            self.instrument.write(f"SOURce1:VOLTage:LEVel:IMMediate:AMPLitude {amp_magnitude}{amp_unit}")
            time.sleep(0.05)
            print(f"set signal amplitude be {amp_magnitude}{amp_unit}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def query_amplitude(self):
        if self.instrument:
            self.instrument.write(f"SOURce1:VOLTage:LEVel:IMMediate:AMPLitude?")
            time.sleep(0.05)
            return self.instrument.read()
        else:
            raise Exception("Instrument not connected. Please connect first.")
    
    def output_on(self):
        if self.instrument:
            self.instrument.write(f"OUTPut1:STATe ON")
            time.sleep(0.05)
            print(f"turn AFG31101 output on")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def output_off(self):
        if self.instrument:
            self.instrument.write(f"OUTPut1:STATe OFF")
            time.sleep(0.05)
            print(f"turn AFG31101 output off")
        else:
            raise Exception("Instrument not connected. Please connect first.")

# %%
def check_output_state(afg, output_state):
    if output_state == 'ON': #判斷輸出狀態，選擇要操作在哪一個輸出狀態DEF
        afg.output_on()
    else:
        afg.output_off()

# %%
def check_amp_limit(afg, amplitude_limit, amplitude):  # 檢查振幅是否超過限制
    amp_num = float(amplitude['magnitude'])  # 將當下振幅大小的字串型態轉為數字型態
    if amp_num >= amplitude_limit:  # 判斷振幅是否大於AMPLITUDE_LIMIT
        print(f'Magnitude of amplitude cannot exceed {amplitude_limit} voltage')
        afg.output_off()  # 將OUTPUT關閉

# %% [markdown]
# ### RF-150A_100D
#
# ===============Function List=================
#
# * Set power state
# * Set gain
#
# 若要串接其他儀器 一樣使用class 定義其他儀器的function

# %%
class RF_150A100D():
    def __init__(self, resource_address, visa_dll=None):
        """
        初始化儀器控制器。
        :param resource_address: 儀器的資源地址。
        :param visa_dll: 使用的 VISA DLL 路徑。如果為 None，則使用系統預設空白。
        """
        self.resource_address = resource_address
        self.visa_dll = visa_dll if visa_dll is not None else ''
        self.rm = pyvisa.ResourceManager(self.visa_dll)
        self.instrument = None
        self.connect_to_instrument()
        
    def connect_to_instrument(self):
        # 建立與儀器的連接
        self.instrument = self.rm.open_resource(self.resource_address)
        print("Connected to RF_150A100D.")
        print(self.query_identity())

    def query_identity(self):
         # 查詢並返回儀器的身份識別信息
        if self.instrument:
             return self.instrument.query("*IDN?")
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def close_instrument(self):
        if self.instrument:
            self.instrument.close()
            print(f"RF_150A100D connection closed.")
        else:
            print(f"No instrument to close.")

    def power_on(self):
        if self.instrument:
            self.instrument.write(f"P1")
            print(f"turn RF150A100D power on")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def power_off(self):
        if self.instrument:
            self.instrument.write(f"P0")
            print(f"turn RF150A100D power off")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_gain(self,gain ,gain_set):
        if self.instrument:
            self.instrument.write(f"G{gain_set}")
            print(f"set power gain be {gain}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def query_gain(slef):
        if self.instrument:
            self.instrument.write(f"G?")
            time.sleep(0.05)
            return self.instrument.read()
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def reset(self):
        if self.instrument:
            self.instrument.write(f"R")
            print(f"clear faults")
        else:
            raise Exception("Instrument not connected. Please connect first.")

# %%
def check_power_state(rf, power_state):
    if power_state == 'ON': #判斷書出狀態，選擇def
        rf.power_on()
    else:
        rf.power_off()

# %%
def check_power_gain(rf, gain):
    if gain < 0:
        rf.power_off()
        print(f"gain you set {gain} can't < 0")

# %%
def calculate_gain_set(gain):
    """
    計算並返回設置增益的值
    透過設定的gain去計算給儀器的gain_set該為多少
    """
    ratio = 4095 / 100  # MAX和MIN的比例
    gain_set = math.ceil(ratio * gain)  # 使用 math函數進行無條件進位
    gain_set = min(gain_set, 4095)  # 限制 gain_set 最大值為 4095
    gain_set = str(gain_set).zfill(4)  # 保持四個字元
    #print(f"CMD of gain set be G{ratio * gain}")
    return gain_set

# %% [markdown]
# ### MSO64B
#
# ===============Function List=================
#
# * Set channel
# * Auto set horizontal scale
# * Auto set Gating type
# * Auto set cursor positon
# * Auto set bandwidth limit
# * Auto set Acquistion mode & numbers of waveform
# * Set measurements[AMP、MEAN、DELAY]
# * Set math function
#
# 若要串接其他儀器 一樣使用class 定義其他儀器的function

# %%
class MSO_64B():
    def __init__(self, resource_address, visa_dll=None):
        """
        初始化儀器控制器。
        :param resource_address: 儀器的資源地址。
        :param visa_dll: 使用的 VISA DLL 路徑。如果為 None，則使用系統預設空白。
        """
        self.resource_address = resource_address
        self.visa_dll = visa_dll if visa_dll is not None else ''
        self.rm = pyvisa.ResourceManager(self.visa_dll)
        self.instrument = None
        self.connect_to_instrument()
        
    def connect_to_instrument(self):
        # 建立與儀器的連接
        self.instrument = self.rm.open_resource(self.resource_address)
        print("Connected to MSO64B.")
        print(self.query_identity())

    def query_identity(self):
         # 查詢並返回儀器的身份識別信息
        if self.instrument:
             return self.instrument.query("*IDN?")
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def close_instrument(self):
        #關閉與儀器的連接
        if self.instrument:
            self.instrument.close()
            print("MSO64B connection closed.")
        else:
            print("No instrument to close.")

    def clear(self):
        #執行示波器上的clear鍵，讓計算、測量項重新運算
        if self.instrument:
            self.instrument.write(f':CLEAR')
            time.sleep(0.3)  # 在命令之間暫停0.5
            print(f"clear acquistions, measurements, and waveforms")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_gating_type(self):
        if self.instrument:
            #設定measurement中Gating type
            self.instrument.write(f'MEASUrement:GATing CURSor')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"take measurements on the portion of the waveform between the cursor")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def cursor_control(self, cursor_A_position, cursor_B_position):
        if self.instrument:
            #設定cursor範圍為三個波形週期
            self.instrument.write(f':DISplay:WAVEView1:CURSor:CURSOR1:STATE ON')
            self.instrument.write(f':DISplay:WAVEView1:CURSor:CURSOR1:WAVEform:APOSition {cursor_A_position}')
            self.instrument.write(f':DISplay:WAVEView1:CURSor:CURSOR1:WAVEform:BPOSition {cursor_B_position}')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"set cursor range be {cursor_A_position} to {cursor_B_position}")
        else:
            raise Exception("Instrument not connected. Please connect first.")
            
    def result_table(self):
        #打開resulit table
        if self.instrument:
            self.instrument.write(f':MEASTABle:ADDNew "TABLE1"')
            time.sleep(0.05)  # 在命令之間暫停0.5
            print(f"add measurent result table")
        else:
            raise Exception("Instrument not connected. Please connect first.")
            
    def add_measurement(self,meas,source):
        if self.instrument:       #新增CH1、CH2、CH3的MEAN測量值
            type_CMD = f":MEASUrement:{meas}:TYPE MEAN" #測量類型CMD
            source_CMD = f":MEASUrement:{meas}:SOURCE {source}" #訊號源CMD
            command = f"{type_CMD};{source_CMD}" #完整叫出AMPLITUDE的CMD
            self.instrument.write(command) #寫入儀器
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"add measurent {meas} of {source}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_horizon_scale(self, horizon_scale):
        if self.instrument:
            self.instrument.write(f':HORIZONTAL:MODE:SCALE {horizon_scale}')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"set Horizontal Scale to {horizon_scale}s/div")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def detect_clip(self,clip_check):
        if self.instrument:
            #查看是否有波形clipping?
            return self.instrument.query(f":{clip_check}:CLIPping?")
            time.sleep(0.05)  # 在命令之間暫停0.5秒
        else:
            raise Exception("Instrument not connected. Please connect first.")
            
    def query_vertical_scale(self,clip_check):
        if self.instrument:
            #回傳當下有clipping之通道的vertical scale為多少?
            return self.instrument.query(f":{clip_check}:SCAle?")
            time.sleep(0.05)  # 在命令之間暫停0.5秒
        else:
            raise Exception("Instrument not connected. Please connect first.")
    
    def set_vertical_scale(self, clip_channel, new_vertical_value):
        if self.instrument:
            #重新對通道設定vertical scale
            self.instrument.write(f":{clip_channel}:SCAle {new_vertical_value}")
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"set {clip_channel} vertical scale be {new_vertical_value}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def math_add(self, math_num, math_function):
        if self.instrument:
            #新增math formula
            self.instrument.write(f':MATH:ADDNew "{math_num}"')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            self.instrument.write(f':MATH:{math_num}:DEFine "{math_function}"')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"Add {math_num} to calculate {math_function}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_math_autoscale(self):
        if self.instrument:
            #新增math formula
            self.instrument.write(f':DISplay:WAVEView1:MATH:MATH4:AUTOScale ON')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"enables the autoscaling the math4 in the specified Waveform View")
            self.instrument.write(f':DISplay:WAVEView1:MATH:MATH5:AUTOScale ON')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"enables the autoscaling the math5 in the specified Waveform View")
        else:
            raise Exception("Instrument not connected. Please connect first.")
            
    def set_math_label(self, math_num, label_name):
        if self.instrument:
            #新增math formula
            self.instrument.write(f':MATH:{math_num}:LABel:NAMe "{label_name}" ')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"set label of {math_num} be {label_name} ")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def off_display(self, off_channel, off_math):  
        if self.instrument:
            #將不必要的波形關閉
            self.instrument.write(f':DIS:WAVEVIEW1:{off_channel}:STATE OFF')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"turn {off_channel} display off")
            self.instrument.write(f':DISplay:WAVEView1:MATH:{off_math}:STATE OFF')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"turn {off_math} display off")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def measure_delta_B(self):
        if self.instrument:
            #新增測量磁通最大值及最小值的measurement
            self.instrument.write(f':MEASUREMENT:MEAS9:TYPE MAXIMUM; SOUrce MATH5') #新增math5的最大值
            time.sleep(0.05)  # 在命令之間暫停0.5秒           
            self.instrument.write(f':MEASUREMENT:MEAS10:TYPE MINIMUM; SOUrce MATH5') #新增math5的最小值
            time.sleep(0.05)  # 在命令之間暫停0.5
            print(f"add measurent maximum of math5")
            print(f"add measurent minimum of math5")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def power_function(self,num,voltage,current):
        if self.instrument:
            self.instrument.write(f':POWer:POWer{num}:POWERQUALITY:VSOURce {voltage}') #新增math5的最小值
            time.sleep(0.05)  # 在命令之間暫停0.5
            self.instrument.write(f':POWer:POWer{num}:POWERQUALITY:ISOURce {current}') #新增math5的最小值
            time.sleep(0.05)  # 在命令之間暫停0.5
            print(f"add measurent maximum of math5")
            print(f"add measurent minimum of math5")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_deskew(self, deskew_ch1):
        if self.instrument:
            self.instrument.write(f'CH1:DESKEW {deskew_ch1}')
            print(f"CH1 deskew set to {deskew_ch1}")
            time.sleep(0.05)
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_deskew_zero(self):
        if self.instrument:
            self.instrument.write(f'CH1:DESKEW 0')
            print(f"CH1 deskew set to 0")
            time.sleep(0.05)
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def query_mean_value(self, meas):
        if self.instrument:                  
            self.instrument.write(f'MEASUrement:{meas}:RESUlts:CURRentacq:MEAN?')
            time.sleep(0.05)
            return float(self.instrument.read())
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def query_true_power(self, power_num):
        if self.instrument:
            self.instrument.write(f'POWer:POWer{power_num}:RESUlts:CURRentacq:MEAN? "TruePWR"')
            time.sleep(0.05)
            return float(self.instrument.read())
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def query_population(self):
        if self.instrument:
            self.instrument.write(f'MEASUrement:MEAS3:RESUlts:ALLAcqs:POPUlation?')
            time.sleep(0.05)
            return int(self.instrument.read())
        else:
            raise Exception("Instrument not connected. Please connect first.")

# %%
def wait_for_population(mso, threshold=25):
    while True: #重複查詢採樣次數(population)
        pop_num = mso.query_population() 
        print(f"Current population: {pop_num}") #列出每0.5秒的pop次數
        if pop_num >= threshold: #當pop次數大於等於100，結束while迴圈
            print(f"Poplution採樣數量已超過 {threshold}") 
            break #跳脫迴圈
        time.sleep(1)  # 防止過於頻繁的查詢，調整每0.5秒查詢一次

# %%
def set_cursor_range(afg, mso):
    """
    設置示波器的cursor range
    [因為如果一開始示波器的horizon scale沒有調好，抓到的freq值會過大，調整錯誤，因此直接從AFG訊號產生器抓值]
    """
    freq = float(afg.query_frequency()) #從afg抓頻率值
    print(f"the frequency of excitaton is {freq} Hz")
    
    cursor_A_position = -2 * (1 / freq)  # 設cursor_A為負1.5波形週期sec
    cursor_B_position = 2 * (1 / freq)  # 設cursor_B為正1.5波形週期sec
    mso.cursor_control(cursor_A_position, cursor_B_position)

# %%
def set_horizon_scale(afg, mso):
    """
    設置示波器的horizon scale
    [因為如果一開始示波器的horizon scale沒有調好，抓到的freq值會過大，調整錯誤，因此直接從AFG訊號產生器抓值]
    """
    freq = float(afg.query_frequency()) #從afg抓頻率值
    print(f"the frequency of signal is {freq}Hz")
    
    horizon_scale = (1 / freq) * (4 / 10)
    mso.set_horizon_scale(horizon_scale) #自動調整horizon scale

# %%
def set_vertical_scale(mso):
    clip_channels = ['CH1','CH2','CH3']#分別測試ch1、ch2、ch3是否clipping?

    channel_meas = {'CH1': 'MEAS3','CH2': 'MEAS4','CH3': 'MEAS5'} #每個channel對應的amplitude測量項
    
    for clip_channel in clip_channels:
        while True: #重複測試到最後沒通道clipping & vertical scale都設定到80%
            all_channels_clipped = False
            
            clip_result = float(mso.detect_clip(clip_channel)) 
            #print(f"clipping state:{clip_result}") #顯示1代表有clipping，0代表沒有clipping
            if clip_result == 1: #clipping時
                clip_vertical_scale = float(mso.query_vertical_scale(clip_channel))
                new_clip_vertical_scale = clip_vertical_scale + 40e-3 #將當下的vertical scale以20mV/div為step加上去
                print(f"{clip_channel} is clipping")
                mso.set_vertical_scale(clip_channel, new_clip_vertical_scale) #設定新的vertical scale
                time.sleep(0.05) #最後調整到沒有clipping等待久一點，讓下面程序執行正常
            elif clip_result == 0: # 當channel沒有clipping時
                meas = channel_meas[clip_channel] #當下的clip_channel對應的meas是什麼?
                time.sleep(2)
                print(f"{clip_channel} no clipping")
                clip_amplitude = float(mso.query_mean_value(meas)) # 看該通道的amplitude大小
                print(f"amplitude of {clip_channel} is {clip_amplitude}")
                new_vertical_scale = clip_amplitude / 5.5  #將amplitude大小除以7即為理想的60~80% vertical scale
                mso.set_vertical_scale(clip_channel, new_vertical_scale) # 設定新的vertical scale
                time.sleep(0.2)
                clip_result = float(mso.detect_clip(clip_channel)) 
                if clip_result == 1:
                    time.sleep(0.5)
                    print(f'{clip_channel} is clipping')
                    print('readjust the vertical scale')
                    all_channels_clipped = True  # 代表還有channel clipping
                else:
                    print(f'vertical state of {clip_channel} is good')
                    break

# %%
def calculate_core_parameters(core_He, core_OD, core_ID):
    """
    計算鐵芯的有效路徑長度(l_e)、有效截面積(A_e)和有效體積(V_e)
    """
    # 計算 C1 和 C2
    h = core_He
    d1 = core_OD
    d2 = core_ID

    C1 = (2 * math.pi) / (h * math.log(d1 / d2))
    C2 = (4 * math.pi * (1/d2 - 1/d1)) / (h**2 * math.log(d1 / d2)**3)

    # 計算 le, Ae, Ve
    le = (C1**2) / C2
    Ae = C1 / C2
    Ve = le * Ae
    print(f"有效路徑長度 (le): {le} mm")
    print(f"有效截面積 (Ae): {Ae} mm^2")
    print(f"有效體積 (Ve): {Ve} mm^3")

    return le, Ae, Ve

# %%
def save_mso_query_values(mso, sequence, core_effective_area, turn):
    """
    用來儲存向儀器(示波器)查詢之值的包裝
    """
    B_max = mso.query_mean_value('MEAS9')
    B_min = mso.query_mean_value('MEAS10')
    calculate_delta_B = (B_max - B_min) / (core_effective_area * turn * 0.000001)
    
    time.sleep(0.05)
    print(f"The maximum B value is {B_max} T")
    print(f"The minimum B value is {B_min} T")
    print(f"The delta of B is {calculate_delta_B} T")
    
    return B_max, B_min, calculate_delta_B

# %%
def save_mso_power_values(mso, sequence):
    """
    用來儲存向儀器(示波器)查詢之值的包裝
    """
    power1_value = float(mso.query_true_power('1'))
    power2_value = float(mso.query_true_power('2'))
    
    time.sleep(0.05)
    print(f"The true power of 1 is {power1_value} W")
    print(f"The true power of 2 is {power2_value} W")
    
    return power1_value, power2_value

# %%
def set_vref_deskew(afg, mso, deskew_vref):
    freq = float(afg.query_frequency()) #查詢測試環境所設定之激勵源的頻率
    deskew_ch1 = (deskew_vref)/(360 * freq) #計算Deskew角度要調整的秒數
    mso.set_deskew(deskew_ch1)

# %%
def acquire_measurement(mso, i, core_effective_area, turn, max_B, min_B, delta_B, Pcore_true_power, PL_true_power, deskew=False):
    B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
        
    # 更新 max_B 和 min_B 字典
    if deskew:
        if 'MEAS9' not in max_B:
            max_B['MEAS9'] = []
        max_B['MEAS9'].append((i, B_max))
        # print("max_B_deskew:", max_B)

        if 'MEAS10' not in min_B:
            min_B['MEAS10'] = []
        min_B['MEAS10'].append((i, B_min))
        # print("min_B_deskew:", min_B)
        
        delta_B[i] = calculate_delta_B
        # print("delta_B_deskew:", delta_B)
    else:
        if 'MEAS9' not in max_B:
            max_B['MEAS9'] = []
        max_B['MEAS9'].append((i, B_max))
        # print("max_B:", max_B)

        if 'MEAS10' not in min_B:
            min_B['MEAS10'] = []
        min_B['MEAS10'].append((i, B_min))
        # print("min_B:", min_B)
        
        delta_B[i] = calculate_delta_B
        # print("delta_B:", delta_B)

    # 量測損耗功率
    power1_value, power2_value = save_mso_power_values(mso, i)

    if deskew:
        if '1' not in Pcore_true_power:
            Pcore_true_power['1'] = []
        Pcore_true_power['1'].append((i, power1_value))
        # print("Pcore true power_deskew:", Pcore_true_power)
        
        if '2' not in PL_true_power:
            PL_true_power['2'] = []
        PL_true_power['2'].append((i, power2_value))
        # print("PL true power_deskew:", PL_true_power)
    else:
        if '1' not in Pcore_true_power:
            Pcore_true_power['1'] = []
        Pcore_true_power['1'].append((i, power1_value))
        #print("Pcore true power:", Pcore_true_power)
        
        if '2' not in PL_true_power:
            PL_true_power['2'] = []
        PL_true_power['2'].append((i, power2_value))
        #print("PL true power:", PL_true_power)

# %%
def calculate_final_power_loss(sequence, Pcore_true_power, PL_true_power, Pcore_true_power_deskew, PL_true_power_deskew, core_effective_volume):
    """
    套公式計算 k_factor, Pcore 和 Pcore_cv
    """
    k_factor = (PL_true_power_deskew['2'][sequence-1][1] - PL_true_power['2'][sequence-1][1]) / (Pcore_true_power_deskew['1'][sequence-1][1] - Pcore_true_power['1'][sequence-1][1])
    print(f"k factor:{k_factor}")
    Pcore = (Pcore_true_power['1'][sequence-1][1] - (k_factor * PL_true_power['2'][sequence-1][1]))
    print(f"Core Real power loss:{Pcore}")
    Pcore_cv = (Pcore / core_effective_volume) * 1000000
    print(f"Every volume of Core Real power loss:{Pcore_cv}")

    return k_factor, Pcore, Pcore_cv

# %%
def adjust_rf_afg(mso, rf, afg, i, core_effective_area, turn, target_deltaB, gain, amplitude, amplitude_limit):
    """
    調整 RF 增益以達到目標 delta B 值
    減少
    """
    tolerance_top = 0.015
    tolerance_max = 0.008
    tolerance_mid = 0.005
    tolerance_min = 0.003
    tolerance_final = 0.001 #磁通密度抓得較精準

    time.sleep(0.5)
    # 查詢初始的 delta B 值
    B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
    
    while abs(target_deltaB - calculate_delta_B) > tolerance_final:
        if calculate_delta_B > 0.155:
            print("delta B 大於155 mT")
            tolerance_final = 0.0018 #磁通密度較高，抓得精準範圍越鬆
            step_rf_max = 1
            step_rf_mid = 1
            step_rf_mean = 1
            step_rf_min = 1
            step_rf_decrease = 1
            step_afg_increase_max = 0
            step_afg_increase_mid = 0
            step_afg_increase_min = 0
            step_afg_decrease = 7
        elif calculate_delta_B > 0.11:
            print("delta B 大於110 mT")
            tolerance_final = 0.0018 #磁通密度較高，抓得精準範圍越鬆
            step_rf_max = 2
            step_rf_mid = 1
            step_rf_mean = 1
            step_rf_min = 1
            step_rf_decrease = 1
            step_afg_increase_max = 2
            step_afg_increase_mid = 1
            step_afg_increase_min = 0
            step_afg_decrease = 5
        elif calculate_delta_B > 0.07:
            print("delta B 大於70 mT")
            tolerance_final = 0.0015 #磁通密度較高，抓得精準範圍越鬆
            step_rf_max = 2
            step_rf_mid = 2
            step_rf_mean = 1
            step_rf_min = 1
            step_rf_decrease = 2
            step_afg_increase_max = 2
            step_afg_increase_mid = 1
            step_afg_increase_min = 1
            step_afg_decrease = 3
        elif calculate_delta_B > 0.04:
            print("delta B 大於50 mT")
            tolerance_final = 0.001 #磁通密度較高，抓得精準範圍越鬆
            step_rf_max = 3
            step_rf_mid = 2
            step_rf_mean = 2
            step_rf_min = 1
            step_rf_decrease = 2         
            step_afg_increase_max = 8
            step_afg_increase_mid = 4
            step_afg_increase_min = 2
            step_afg_decrease = 3
        else:
            print("delta B 小於50 mT")
            step_rf_max = 5
            step_rf_mid = 3
            step_rf_mean = 2
            step_rf_min = 1
            step_rf_decrease = 1
            step_afg_increase_max = 10
            step_afg_increase_mid = 7
            step_afg_increase_min = 4
            step_afg_decrease = 2
            
        tolerance = target_deltaB - calculate_delta_B
        print(f"實際 delta B: {calculate_delta_B} 與預期 delta B: {target_deltaB} 差了 {tolerance}T")

        if tolerance < -tolerance_final:
            print(f"實際deltaB大於預期deltaB {tolerance_final}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) - step_afg_decrease  # 移除 'E-3' 並減少 1mV
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已減少 {step_afg_decrease}V")
            gain -= step_rf_decrease
            print(f"增益減少 {step_rf_decrease")
        elif tolerance > tolerance_max:
            print(f"delta B 誤差大於 {tolerance_max}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg_increase_max  # 移除 'E-3' 並增加 3mV
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已增加 {step_afg_increase_max}V")
            gain += step_rf_max
            print(f"增益增加 {step_rf_max}")
        elif tolerance > tolerance_mid:
            print(f"delta B 誤差介於 {tolerance_mid} ~ {tolerance_max}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg_increase_mid  # 移除 'E-3' 並增加 2mV
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已增加 {step_afg_increase_mid}V")
            gain += step_rf_mid
            print(f"增益增加 {step_rf_mid}")
        elif tolerance > tolerance_min:
            print(f"delta B 誤差介於 {tolerance_min} ~ {tolerance_mid}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg_increase_min  # 移除 'E-3' 並增加 2mV
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已增加 {step_afg_increase_min}V")
            gain += step_rf_mean
            print(f"增益增加 {step_rf_mean}")
        else:
            print(f"delta B 誤差介於 {tolerance_final} ~ {tolerance_min}")
            gain += step_rf_min
            print(f"增益增加 {step_rf_min}")
            
        check_amp_limit(afg, amplitude_limit, amplitude)  # 檢查振幅是否超過限制
        afg.set_amplitude(amplitude['magnitude'], amplitude['unit'])

        check_power_gain(rf, gain)
        gain_set = calculate_gain_set(gain)
        rf.set_gain(gain, gain_set)
        
        time.sleep(0.5)
        set_vertical_scale(mso)

        time.sleep(1)

        time.sleep(1.5)
        B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
    
    print(f"delta B已達預期的{target_deltaB}")
    return amplitude, gain

# %% [markdown]
# #### 從較小的激勵源開始
#
# * 設定expect deltaB：[0.02,0.04,0.06](T)
# * 查看calculate deltaB
# * 計算兩者誤差tolerance
#
# * tolerance為負的:RF的Gain:不變/AFG振幅:-5mV
#
# * 相差0.01以上：RF的Gain:+10/AFG振幅：不變
#
# * 相差0.005~0.01：RF的:Gain+5/AFG振幅:不變
#
# * 相差0.003~0.005：RF的:Gain+3/AFG振幅：不變
#
# * 相差0.001~0.003：RF的:Gain+1/AFG振幅：不變
#
# * 相差0.001內:不變/AFG振幅：不變

# %%
def format_time(seconds):
    """將記錄下來測量時間的秒數轉為分:秒"""
    minutes = int(seconds // 60)
    remaining_seconds = int(seconds % 60)
    return f"{minutes}:{remaining_seconds}"

# %%
def every_measurement_time(i, start_time, measurement_start_time, measurement_times, accumulated_times):
    """計算每次測量的結束時間及其花費時間"""
    measurement_end_time = time.time()
    measurement_duration = measurement_end_time - measurement_start_time
    measurement_times.append(measurement_duration)

    accumulated_time = measurement_end_time - start_time
    accumulated_times.append(accumulated_time)

    formatted_measurement_duration = format_time(measurement_duration)
    formatted_accumulated_time = format_time(accumulated_time)

    print(f"[第{i}次測量]花費時間: {formatted_measurement_duration}")
    print(f"程式執行累計時間: {formatted_accumulated_time}")

    return measurement_end_time

# %%
# def final_measurement_time(start_time, measurement_times):
#     """在程式結束後，顯示所有測量的時間統計"""
#     total_duration = time.time() - start_time
#     formatted_total_duration = format_time(total_duration)
#     print(f"整個程式執行的總時間: {formatted_total_duration}")

#     for i, duration in enumerate(measurement_times, 1):
#         formatted_duration = format_time(duration)
#         print(f"[第{i}次測量]花費時間: {formatted_duration}")

# %%
def main():
    
    # =========================Parmeters===============================
    #=====MSO64B parameter=====
    """
    channel:{CH1 | CH2 | CH3 | CH4 }[page:2-541]
    measure type:{AMPLITUDE | FREQUENCY | MAXIMUM | MEAN | MINIMUM | PERIOD | PHASE 
    | PK2PK | RMS } [page:2-717]
    math_num:{MATH1 | MATH2 | MATH3 | MATH4 | ...}[page:2-672]
    math_function:{first letter should be capital then calculate}[page:2-677]
    gating_type:{NONE | SCREEN | CURSor | LOGic | SEARch | TIMe }[page:2-754]
    """

    #針對display的通道新增測量項
    measurements = [
        {'measurement': 'MEAS6','channel': 'CH1'},
        {'measurement': 'MEAS7','channel': 'CH2'},
        {'measurement': 'MEAS8','channel': 'CH3'}
    ]    
    
    #設定欲增加計算及公式
    mso_maths = [
        {'math_num': 'MATH1', 'math_function': 'Ch1-Meas6'},
        {'math_num': 'MATH2', 'math_function': 'Ch2-Meas7'},
        {'math_num': 'MATH3', 'math_function': 'Ch3-Meas8'},
        {'math_num': 'MATH4', 'math_function': 'Math1/10'},
        {'math_num': 'MATH5', 'math_function': 'Intg(Math2)'}
    ]

    math_labels = [
        {'math_num' : 'MATH4', 'label_name': 'A'},
        {'math_num' : 'MATH5', 'label_name': 'T'},
    ]
    
    #設定powerfunction內容 done
    powers = [
        {'Power_num': '1','Voltage_Source': 'MATH2', 'Current_Source': 'MATH4'},
        {'Power_num': '2','Voltage_Source': 'MATH3', 'Current_Source': 'MATH4'}
    ]

    #將特定通道停止顯示(display off)，可控制channel&math
    off_displays = [
        {'channel': 'NONE','math': 'MATH1'},
        {'channel': 'NONE','math': 'MATH2'},
        {'channel': 'NONE','math': 'MATH3'},
        {'channel': 'NONE','math': 'MATH6'},
        {'channel': 'NONE','math': 'MATH7'},
        {'channel': 'NONE','math': 'MATH8'},
        {'channel': 'NONE','math': 'MATH9'}
    ]

    #=====AFG_31101 parameter=====
    """
    shape:{SINusoid|SQUare|PULSe|RAMP|PRNoise|DC|SINC|GAUSsian|LORentz|ERISe|EDECay|HAVersine
     |EMEMory[1]|EMEMory2|EFILe} 
    amplitude:
        magnitude:output amplitude
        <units>::=[VPP | VRMS | DBM]
    frequency:
        magnitude:output frequency
        <units>::=[Hz | kHz | MHz]
    output_state:{ON|OFF}
    """
    #設置輸入源訊號參數
    shape = 'SINusoid'
    frequency = {'magnitude': '1000','unit': 'KHz'}
    amplitude = {'magnitude': '300E-3','unit': 'VPP'}
    output_state = "ON"
    amplitude_limit = 0.5

    #=======RF_150A_100D parameter======
    """
    Gain : 0~100
    Power state : { ON | OFF }
    """
    #設置射頻功率放大器參數
    gain = 5
    power_state = 'ON'
    
    #====================Instrument Connect Test===========================
    #=====MSO64B connection===
    MSO_instrument_address = 'USB0::0x0699::0x0530::C048992::INSTR'
    mso = MSO_64B(MSO_instrument_address)
    
    #=====AFG_31101 connection=====
    AFG_instrument_address = 'USB0::0x0699::0x0359::C016504::INSTR'
    afg = AFG_31101(AFG_instrument_address)

    #=====RF_150A_100D connection=====
    RF_instrument_address = 'USB0::0x0547::0x1B58::0358752::INSTR'
    rf = RF_150A100D(RF_instrument_address)
    #若有其他儀器串接下去...
    
    #============================Auto Test================================= 
    # 初始化時間追蹤列表
    start_time = time.time()
    measurement_times = []
    accumulated_times = []
    
    # TO DO: 這邊給你寫For迴圈自動測量的區域
    
    #=====MSO64B control===== #若示波器已設置完成，可省略這段
    mso.result_table()#新增measurement result table的介面
    
    #===新增測量項目及功率測量項==    
    # for measurement in measurements:
    #     meas = measurement['measurement']
    #     source = measurement['channel']
    #     mso.add_measurement(meas,source)  

    set_cursor_range(afg, mso)
    
    #回傳math部分需要的公式
    # for mso_math in mso_maths:
    #     math_num = mso_math['math_num']
    #     math_function = mso_math['math_function']
    #     mso.math_add(math_num, math_function)

    # mso.set_math_autoscale()

    # for math_label in math_labels:
    #     math_num = math_label['math_num']
    #     label_name = math_label['label_name']
    #     mso.set_math_label(math_num,label_name)
        
    # mso.set_gating_type() #調整measurement的gating type
    # mso.measure_delta_B() #執行測量Bmax&Bmin
    
    # for power in powers:
    #     num = power['Power_num']
    #     voltage = power['Voltage_Source']
    #     current = power['Current_Source']
    #     mso.power_function(num,voltage, current)

    # for off_display in off_displays:
    #     off_channel = off_display['channel']
    #     off_math = off_display['math']
    #     mso.off_display(off_channel,off_math)

    #=====RF_150A_100D control=====
    gain_set = calculate_gain_set(gain)  # 計算增益設置值
    rf.set_gain(gain, gain_set)

    check_power_state(rf, power_state) #判斷放大power狀態，是開或關
    
    #=====AFG_31101 control=====
    afg.set_waveform(shape) #設置訊號類
    afg.set_frequency(frequency['magnitude'],frequency['unit']) #設置訊號頻率
    afg.set_amplitude(amplitude['magnitude'],amplitude['unit']) #設置訊號振幅

    check_output_state(afg, output_state) #判斷輸出狀態，是開或關
    check_amp_limit(afg, amplitude_limit, amplitude)  # 檢查振幅是否超過限制
    
    #===Autoset horizon & vertical scale===
    mso.clear()
    wait_for_population(mso, threshold=2) #先等待pop到10再抓數值
    set_horizon_scale(afg, mso)

    mso.clear()
    wait_for_population(mso, threshold=2)
    set_vertical_scale(mso)
        
    #=====start measure & save data to Excel by pandas======
    #=====core parameter=====
    #記錄待測鐵心知各樣參數
    core_type = 'ML95S'
    core_He = 5 #unit:mm
    core_OD = 14 #unit:mm
    core_ID = 7 #unit:mm
    turn = 3 #unit:turn
    core_effective_length, core_effective_area, core_effective_volume = calculate_core_parameters(core_He, core_OD, core_ID)
    
    #===開始量測===
    # 設定測量順序、目標 delta B 值及desekw Vref的角度

    expect_deltaB = [0.02, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2]
    deskew_vref = 1
    sequences = list(range(1, len(expect_deltaB) + 1))
    
    # 將這個值的字典先重製歸零
    vin_amplitude = {}
    power_gain ={}
    max_B = {}
    min_B = {}
    delta_B ={}
    Pcore_true_power = {}
    PL_true_power = {}
    max_B_deskew = {}
    min_B_deskew = {}
    delta_B_deskew ={}
    Pcore_true_power_deskew = {}
    PL_true_power_deskew = {}
    k_factor = {}
    Pcore = {}
    Pcore_cv = {}

    #===開始測量===
    for i in sequences:
        print(f"[第{i}次測量]")

        # 計算每次測量開始的時間
        measurement_start_time = time.time()
    
        #===自動調整激勵源===
        target_deltaB = expect_deltaB[i-1] #從expect deltaB抓出當下對應預期要達到的deltaB
        wait_for_population(mso, threshold=5) #讓最測量的最一開始先等待一下再抓delta B
        amplitude, gain = adjust_rf_afg(mso, rf, afg, i, core_effective_area, turn, target_deltaB, gain, amplitude, amplitude_limit)
    
        vin_amplitude[i] = amplitude['magnitude']
        #print(vin_amplitude)
        power_gain[i] = gain
        #print(power_gain)
    
        #===開始抓值===
        mso.set_deskew_zero() #將channel1(Vref)的Deskew歸零
    
        wait_for_population(mso) #先等待pop到一定次數再抓數值
        
        acquire_measurement(mso, i, core_effective_area, turn, max_B, min_B, delta_B, Pcore_true_power, PL_true_power)

        print("對Vref Deskew")
        set_vref_deskew(afg, mso, deskew_vref) #設定Vref deskew
    
        mso.clear()
        wait_for_population(mso) #先等待pop到一定次數再抓數值
    
        acquire_measurement(mso, i, core_effective_area, turn, max_B_deskew, min_B_deskew, delta_B_deskew, Pcore_true_power_deskew, PL_true_power_deskew, deskew=True)
    
        # 計算 k_factor, Pcore, Pcore_cv
        k_factor[i], Pcore[i], Pcore_cv[i] = calculate_final_power_loss(i, Pcore_true_power, PL_true_power, Pcore_true_power_deskew, PL_true_power_deskew, core_effective_volume)

        # 計算每次測量的結束時間及其花費時間
        measurement_end_time = every_measurement_time(i, start_time, measurement_start_time, measurement_times, accumulated_times)

    #=====測量完畢，關閉儀器====
    print("已經測量完畢")
    afg.output_off() #資料儲存完畢，關閉AFG
    rf.power_off() #資料儲存完畢，關閉RF

    # 程式結束後，顯示所有測量的時間統計
    # final_measurement_time(start_time, measurement_times)
    
    #=====將所有資料丟到data最後建立成DataFrame=====
    data = {
        ("core parameter","type of core"): [core_type] * len(sequences),
        ("core parameter","effective length of core(mm)"): [core_effective_length] * len(sequences),
        ("core parameter","effective area of core(mm^2)"): [core_effective_area] * len(sequences),
        ("core parameter","effective volume of core(mm^3)"): [core_effective_volume] * len(sequences),
        ("core parameter","turns of wire on the core"): [turn] * len(sequences),
        ("Test environment (R=10)", "Sequence"): sequences,
        ("Test environment (R=10)", "Function"): [shape] * len(sequences),
        ("Test environment (R=10)", "freq(kHz)"): [frequency['magnitude']] * len(sequences),
        ("Test environment (R=10)", "deltaB(T)"): expect_deltaB,
        ("Test environment (R=10)", "Vin(Vpp)"): [vin_amplitude[seq] for seq in sequences], #每次調整都要重新記錄
        ("Test environment (R=10)", "Gain"): [power_gain[seq] for seq in sequences], #每次調整都要記錄
        ("flux density (DS=0)", "Max(T)"): [v for seq, v in max_B['MEAS9']],
        ("flux density (DS=0)", "Min(T)"): [v for seq, v in min_B['MEAS10']],
        ("flux density (DS=0)", "delta B(T)"): [delta_B[seq] for seq in sequences],
        ("L(DS=0)", "P(W)"): [v for seq, v in Pcore_true_power['1']],
        ("Lair(DS=0)", "P(W)"): [v for seq, v in PL_true_power['2']],
        ("flux density (DS=1)", "Max(T)"): [v for seq, v in max_B_deskew['MEAS9']],
        ("flux density (DS=1)", "Min(T)"): [v for seq, v in min_B_deskew['MEAS10']],
        ("flux density (DS=1)", "delta B(T)"): [delta_B_deskew[seq] for seq in sequences],
        ("L(DS=1)", "P(W)"): [v for seq, v in Pcore_true_power_deskew['1']],
        ("Lair(DS=1)", "P(W)"): [v for seq, v in PL_true_power_deskew['2']],
        ("Final calculate","K"):[k_factor[seq] for seq in sequences],
        ("Final calculate","Real Pcore(W)"):[Pcore[seq] for seq in sequences],
        ("Final calculate","Real Pcv(kW/m^3)"):[Pcore_cv[seq] for seq in sequences],
        ("Final calculate", "Spend time(sec)"): [format_time(duration) for duration in measurement_times],  # 每次測試花費的時間
        ("Final calculate", "Accumulated time(sec)"): [format_time(accumulated_time) for accumulated_time in accumulated_times],  # 累計時間
    }

    # 建立MultiIndex
    index = pd.MultiIndex.from_tuples(data.keys())

    #建立DataFrame
    df = pd.DataFrame(data) #用一代號表示整個二維資料
    df.columns = index

    #顯示DataFrame
    print(df) #列出來

    #儲存為Excel文件
    df.to_csv('(1MHz)ML95s_SIN_20-200mT(0816).csv', index=False) #將資料弄成一個CSV檔
    
    # ============================ Close Instrument =================================
    afg.close_instrument()
    mso.close_instrument()
    rf.close_instrument()
    
if __name__ == "__main__":
    main()
# Out:
# Connected to MSO64B.
# TEKTRONIX,MSO64B,C048992,CF:91.1CT FV:1.44.3.433
#
# Connected to AFG_31101.
# TEKTRONIX,AFG31101,C016504,SCPI:99.0 FV:1.6.1
#
# Connected to RF_150A100D.
# AR-RF/MICROWAVE-INST,150A100D,1.0
#
# add measurent result table
# the frequency of excitaton is 1000000.0
# set cursor range be -2e-06 to 2e-06
# set power gain be 5
# turn RF150A100D power on
# set excitation form be SINusoid
# set excitation frequency be 1000KHz
# set excitation amplitude be 300E-3VPP
# turn AFG31101 output on
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 2
# Poplution採樣數量已超過 2
# the frequency of excitaton is 1000000.0
# set Horizontal Scale to 4e-07s/div
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 3
# Poplution採樣數量已超過 2
# CH1 no clipping
# amplitude of CH1 is 0.9036240876188688
# set CH1 vertical scale be 0.16429528865797616
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 4.9284776748968
# set CH2 vertical scale be 0.8960868499812363
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 1.4533305409417
# set CH3 vertical scale be 0.26424191653485457
# vertical state of CH3 is good
# 有效路徑長度 (le): 30.486205264250426 mm
# 有效截面積 (Ae): 16.81585548713705 mm^2
# 有效體積 (Ve): 512.651622074832 mm^3
# [第1次測量]
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 6
# Poplution採樣數量已超過 5
# The maximum B value is 4.341495127846429e-07 T
# The minimum B value is -3.510759825076093e-07 T
# The delta of B is 0.01556518084758151 T
# delta B 小於50 mT
# 實際 delta B: 0.01556518084758151 與預期 delta B: 0.02 差了 0.004434819152418491T
# delta B 誤差介於 0.003 ~ 0.005
# AFG 振幅已增加 4V，設為304.0E-3 VPP
# 增益增加 2
# set excitation amplitude be 304.0E-3VPP
# set power gain be 7
# CH1 no clipping
# amplitude of CH1 is 0.905084904349662
# set CH1 vertical scale be 0.16456089169993857
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 5.1911672673971
# set CH2 vertical scale be 0.9438485940722
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 1.5075645875113
# set CH3 vertical scale be 0.2741026522747818
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '304.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 7
# The maximum B value is 4.563993059036875e-07 T
# The minimum B value is -3.736053315606114e-07 T
# The delta of B is 0.01645281815722854 T
# 調整後的 delta B: 0.01645281815722854
# delta B 小於50 mT
# 實際 delta B: 0.01645281815722854 與預期 delta B: 0.02 差了 0.00354718184277146T
# delta B 誤差介於 0.003 ~ 0.005
# AFG 振幅已增加 4V，設為308.0E-3 VPP
# 增益增加 2
# set excitation amplitude be 308.0E-3VPP
# set power gain be 9
# CH1 no clipping
# amplitude of CH1 is 0.9648182911858734
# set CH1 vertical scale be 0.17542150748834062
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 5.4758653948761
# set CH2 vertical scale be 0.9956118899774726
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 1.5948711950368
# set CH3 vertical scale be 0.2899765809157818
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '308.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 9
# The maximum B value is 4.31728352623395e-07 T
# The minimum B value is -3.54945456138012e-07 T
# The delta of B is 0.015593890130719334 T
# 調整後的 delta B: 0.015593890130719334
# delta B 小於50 mT
# 實際 delta B: 0.015593890130719334 與預期 delta B: 0.02 差了 0.004406109869280667T
# delta B 誤差介於 0.003 ~ 0.005
# AFG 振幅已增加 4V，設為312.0E-3 VPP
# 增益增加 2
# set excitation amplitude be 312.0E-3VPP
# set power gain be 11
# CH1 no clipping
# amplitude of CH1 is 0.9278688177411786
# set CH1 vertical scale be 0.168703421407487
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 5.0136724071478
# set CH2 vertical scale be 0.9115768012996
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 1.6934194186543
# set CH3 vertical scale be 0.30789443975532726
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '312.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 11
# The maximum B value is 4.503992272475443e-07 T
# The minimum B value is -3.78301336922959e-07 T
# The delta of B is 0.016426968083869835 T
# 調整後的 delta B: 0.016426968083869835
# delta B 小於50 mT
# 實際 delta B: 0.016426968083869835 與預期 delta B: 0.02 差了 0.0035730319161301656T
# delta B 誤差介於 0.003 ~ 0.005
# AFG 振幅已增加 4V，設為316.0E-3 VPP
# 增益增加 2
# set excitation amplitude be 316.0E-3VPP
# set power gain be 13
# CH1 no clipping
# amplitude of CH1 is 1.03350303291
# set CH1 vertical scale be 0.1879096423472727
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 6.1270789174268
# set CH2 vertical scale be 1.1140143486230547
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 1.5445414672372
# set CH3 vertical scale be 0.28082572131585454
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '316.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 13
# The maximum B value is 5.327484586814535e-07 T
# The minimum B value is -4.437829375092406e-07 T
# The delta of B is 0.01935735387628008 T
# 調整後的 delta B: 0.01935735387628008
# delta B已達預期的0.02
# {1: '316.0E-3'}
# {1: 13}
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 7
# Current population: 16
# Current population: 21
# Current population: 27
# Poplution採樣數量已超過 25
# The maximum B value is 5.238347853264713e-07 T
# The minimum B value is -4.52130677786045e-07 T
# The delta of B is 0.019346135632906325 T
# The true power of 1 is 0.00300656782451 W
# The true power of 2 is 9.45251737327287e-05 W
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 6
# Current population: 13
# Current population: 17
# Current population: 27
# Poplution採樣數量已超過 25
# The maximum B value is 5.330522299118456e-07 T
# The minimum B value is -4.425541533237265e-07 T
# The delta of B is 0.019339017749881802 T
# The true power of 1 is 0.0042293684904515 W
# The true power of 2 is 0.0005013776634305057 W
# k factor:0.33272184177665587
# Core Real power loss:0.0029751172346113883
# Every volume of Core Real power loss:5.803389878238032
# [第1次測量]花費時間: 1:15
# 程式執行累計時間: 1:41
# [第2次測量]
# Current population: 30
# Poplution採樣數量已超過 5
# The maximum B value is 5.02655211676029e-07 T
# The minimum B value is -4.164877509538201e-07 T
# The delta of B is 0.018219768109784422 T
# delta B 小於50 mT
# 實際 delta B: 0.018219768109784422 與預期 delta B: 0.04 差了 0.02178023189021558T
# delta B 誤差大於 0.008
# AFG 振幅已增加 10V，設為326.0E-3 VPP
# 增益增加 5
# set excitation amplitude be 326.0E-3VPP
# set power gain be 18
# CH1 no clipping
# amplitude of CH1 is 1.1166254907689
# set CH1 vertical scale be 0.20302281650343634
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 7.084858969664
# set CH2 vertical scale be 1.2881561763025455
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 2.0667196999478
# set CH3 vertical scale be 0.3757672181723273
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '326.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 18
# The maximum B value is 6.140672326182539e-07 T
# The minimum B value is -5.185947316022066e-07 T
# The delta of B is 0.022452261698031904 T
# 調整後的 delta B: 0.022452261698031904
# delta B 小於50 mT
# 實際 delta B: 0.022452261698031904 與預期 delta B: 0.04 差了 0.017547738301968097T
# delta B 誤差大於 0.008
# AFG 振幅已增加 10V，設為336.0E-3 VPP
# 增益增加 5
# set excitation amplitude be 336.0E-3VPP
# set power gain be 23
# CH1 no clipping
# amplitude of CH1 is 1.3937694706391
# set CH1 vertical scale be 0.2534126310252909
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 8.3216793635342
# set CH2 vertical scale be 1.5130326115516726
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 2.4059495410592
# set CH3 vertical scale be 0.4374453711016727
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '336.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 23
# The maximum B value is 7.214841275526851e-07 T
# The minimum B value is -6.017886562403874e-07 T
# The delta of B is 0.026230656434246106 T
# 調整後的 delta B: 0.026230656434246106
# delta B 小於50 mT
# 實際 delta B: 0.026230656434246106 與預期 delta B: 0.04 差了 0.013769343565753895T
# delta B 誤差大於 0.008
# AFG 振幅已增加 10V，設為346.0E-3 VPP
# 增益增加 5
# set excitation amplitude be 346.0E-3VPP
# set power gain be 28
# CH1 no clipping
# amplitude of CH1 is 1.6290263265625
# set CH1 vertical scale be 0.29618660482954545
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 9.8422607331557
# set CH2 vertical scale be 1.7895019514828545
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 2.8244860855011
# set CH3 vertical scale be 0.5135429246365636
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '346.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 28
# The maximum B value is 8.50525509576983e-07 T
# The minimum B value is -7.17295904451021e-07 T
# The delta of B is 0.031078236751564167 T
# 調整後的 delta B: 0.031078236751564167
# delta B 小於50 mT
# 實際 delta B: 0.031078236751564167 與預期 delta B: 0.04 差了 0.008921763248435834T
# delta B 誤差大於 0.008
# AFG 振幅已增加 10V，設為356.0E-3 VPP
# 增益增加 5
# set excitation amplitude be 356.0E-3VPP
# set power gain be 33
# CH1 no clipping
# amplitude of CH1 is 1.9185287782855
# set CH1 vertical scale be 0.34882341423372726
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 11.7410050214915
# set CH2 vertical scale be 2.134728185725727
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 3.3672213544848
# set CH3 vertical scale be 0.6122220644517818
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '356.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 33
# The maximum B value is 1.0191527053394e-06 T
# The minimum B value is -8.475797130813589e-07 T
# The delta of B is 0.037003418586081416 T
# 調整後的 delta B: 0.037003418586081416
# delta B 小於50 mT
# 實際 delta B: 0.037003418586081416 與預期 delta B: 0.04 差了 0.002996581413918585T
# delta B 誤差介於 0.001 ~ 0.003
# 增益增加 1
# set excitation amplitude be 356.0E-3VPP
# set power gain be 34
# CH1 no clipping
# amplitude of CH1 is 2.127365939711
# set CH1 vertical scale be 0.3867938072201818
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 12.0579978861486
# set CH2 vertical scale be 2.192363252027018
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 3.4822438743947
# set CH3 vertical scale be 0.6331352498899455
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '356.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 34
# The maximum B value is 1.0513617780816e-06 T
# The minimum B value is -8.744959245632344e-07 T
# The delta of B is 0.038175433182054096 T
# 調整後的 delta B: 0.038175433182054096
# delta B 小於50 mT
# 實際 delta B: 0.038175433182054096 與預期 delta B: 0.04 差了 0.0018245668179459051T
# delta B 誤差介於 0.001 ~ 0.003
# 增益增加 1
# set excitation amplitude be 356.0E-3VPP
# set power gain be 35
# CH1 no clipping
# amplitude of CH1 is 2.1812716949794
# set CH1 vertical scale be 0.3965948536326182
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 12.4690954234657
# set CH2 vertical scale be 2.267108258811945
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 3.5832104801591
# set CH3 vertical scale be 0.6514928145743818
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '356.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 35
# The maximum B value is 1.0836715773621e-06 T
# The minimum B value is -8.985990120891074e-07 T
# The delta of B is 0.03929368111279471 T
# 調整後的 delta B: 0.03929368111279471
# delta B已達預期的0.04
# {1: '316.0E-3', 2: '356.0E-3'}
# {1: 13, 2: 35}
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 4
# Current population: 10
# Current population: 16
# Current population: 25
# Poplution採樣數量已超過 25
# The maximum B value is 1.0667905598893e-06 T
# The minimum B value is -9.144553132500732e-07 T
# The delta of B is 0.039273368610453926 T
# The true power of 1 is 0.0167567396391422 W
# The true power of 2 is 0.0006901289234992608 W
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 3
# Current population: 9
# Current population: 14
# Current population: 23
# Current population: 33
# Poplution採樣數量已超過 25
# The maximum B value is 1.0847163594008e-06 T
# The minimum B value is -8.9754155396804e-07 T
# The delta of B is 0.03929342984036958 T
# The true power of 1 is 0.0228510443021928 W
# The true power of 2 is 0.0024223193794935 W
# k factor:0.28423102417186413
# Core Real power loss:0.01656058358840538
# Every volume of Core Real power loss:32.30377682485519
# [第2次測量]花費時間: 1:28
# 程式執行累計時間: 3:9
# [第3次測量]
# Current population: 36
# Poplution採樣數量已超過 5
# The maximum B value is 1.0849406635316e-06 T
# The minimum B value is -8.972647265181877e-07 T
# The delta of B is 0.03929238869363571 T
# delta B 小於50 mT
# 實際 delta B: 0.03929238869363571 與預期 delta B: 0.06 差了 0.02070761130636429T
# delta B 誤差大於 0.008
# AFG 振幅已增加 10V，設為366.0E-3 VPP
# 增益增加 5
# set excitation amplitude be 366.0E-3VPP
# set power gain be 40
# CH1 no clipping
# amplitude of CH1 is 2.3391205479659
# set CH1 vertical scale be 0.4252946450847091
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 15.0427381492492
# set CH2 vertical scale be 2.735043299863491
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 4.2981137952346
# set CH3 vertical scale be 0.7814752354972
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '366.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 40
# The maximum B value is 1.3161658216632e-06 T
# The minimum B value is -1.08236554297e-06 T
# The delta of B is 0.047545036022062795 T
# 調整後的 delta B: 0.047545036022062795
# delta B 大於50 mT
# 實際 delta B: 0.047545036022062795 與預期 delta B: 0.06 差了 0.012454963977937203T
# delta B 誤差大於 0.008
# AFG 振幅已增加 8V，設為374.0E-3 VPP
# 增益增加 3
# set excitation amplitude be 374.0E-3VPP
# set power gain be 43
# CH1 no clipping
# amplitude of CH1 is 2.8075553149986
# set CH1 vertical scale be 0.5104646027270182
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 17.0535954167718
# set CH2 vertical scale be 3.100653712140327
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 4.8321292170608
# set CH3 vertical scale be 0.878568948556509
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '374.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 43
# The maximum B value is 1.4867470099489e-06 T
# The minimum B value is -1.2210425666126e-06 T
# The delta of B is 0.053675326016623004 T
# 調整後的 delta B: 0.053675326016623004
# delta B 大於50 mT
# 實際 delta B: 0.053675326016623004 與預期 delta B: 0.06 差了 0.006324673983376994T
# delta B 誤差介於 0.005 ~ 0.008
# AFG 振幅已增加 4V，設為378.0E-3 VPP
# 增益增加 2
# set excitation amplitude be 378.0E-3VPP
# set power gain be 45
# CH1 no clipping
# amplitude of CH1 is 3.0819851318975
# set CH1 vertical scale be 0.5603609330722727
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 18.4509552989089
# set CH2 vertical scale be 3.3547191452561638
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 5.212410704283
# set CH3 vertical scale be 0.9477110371423637
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '378.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 45
# The maximum B value is 1.6128610695887e-06 T
# The minimum B value is -1.321865738646e-06 T
# The delta of B is 0.05817380329890759 T
# 調整後的 delta B: 0.05817380329890759
# delta B 大於50 mT
# 實際 delta B: 0.05817380329890759 與預期 delta B: 0.06 差了 0.0018261967010924085T
# delta B 誤差介於 0.001 ~ 0.003
# 增益增加 1
# set excitation amplitude be 378.0E-3VPP
# set power gain be 46
# CH1 no clipping
# amplitude of CH1 is 3.2669920111181
# set CH1 vertical scale be 0.5939985474760182
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 19.0789537411796
# set CH2 vertical scale be 3.468900680214473
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 5.3730588984159
# set CH3 vertical scale be 0.9769197997119818
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '378.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 46
# The maximum B value is 1.6754661373852e-06 T
# The minimum B value is -1.3593892163044e-06 T
# The delta of B is 0.06015860757150796 T
# 調整後的 delta B: 0.06015860757150796
# delta B已達預期的0.06
# {1: '316.0E-3', 2: '356.0E-3', 3: '378.0E-3'}
# {1: 13, 2: 35, 3: 46}
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 6
# Current population: 13
# Current population: 17
# Current population: 27
# Poplution採樣數量已超過 25
# The maximum B value is 1.6464470036226e-06 T
# The minimum B value is -1.3869733948013e-06 T
# The delta of B is 0.06013016308218265 T
# The true power of 1 is 0.0485279195105388 W
# The true power of 2 is 0.0016635836280776 W
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 7
# Current population: 11
# Current population: 20
# Current population: 29
# Poplution採樣數量已超過 25
# The maximum B value is 1.67265568507e-06 T
# The minimum B value is -1.3599099020212e-06 T
# The delta of B is 0.060113218531777944 T
# The true power of 1 is 0.0622784407748751 W
# The true power of 2 is 0.005551135570728 W
# k factor:0.2827203324090159
# Core Real power loss:0.048057590594218505
# Every volume of Core Real power loss:93.74317475036395
# [第3次測量]花費時間: 1:6
# 程式執行累計時間: 4:16
# [第4次測量]
# Current population: 34
# Poplution採樣數量已超過 5
# The maximum B value is 1.6727350384826e-06 T
# The minimum B value is -1.3596246617453e-06 T
# The delta of B is 0.060109137326722045 T
# delta B 大於50 mT
# 實際 delta B: 0.060109137326722045 與預期 delta B: 0.08 差了 0.019890862673277956T
# delta B 誤差大於 0.008
# AFG 振幅已增加 8V，設為386.0E-3 VPP
# 增益增加 3
# set excitation amplitude be 386.0E-3VPP
# set power gain be 49
# CH1 no clipping
# amplitude of CH1 is 3.4266127785792
# set CH1 vertical scale be 0.6230205051962182
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 21.7097161749104
# set CH2 vertical scale be 3.947221122710982
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 6.0827782615991
# set CH3 vertical scale be 1.105959683927109
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '386.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 49
# The maximum B value is 1.91742287825e-06 T
# The minimum B value is -1.5364238379334e-06 T
# The delta of B is 0.06846408971630674 T
# 調整後的 delta B: 0.06846408971630674
# delta B 大於50 mT
# 實際 delta B: 0.06846408971630674 與預期 delta B: 0.08 差了 0.01153591028369326T
# delta B 誤差大於 0.008
# AFG 振幅已增加 8V，設為394.0E-3 VPP
# 增益增加 3
# set excitation amplitude be 394.0E-3VPP
# set power gain be 52
# CH1 no clipping
# amplitude of CH1 is 3.96921810774
# set CH1 vertical scale be 0.7216760195890909
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 24.7757646032817
# set CH2 vertical scale be 4.5046844733239455
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 6.871048942286
# set CH3 vertical scale be 1.249281625870182
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '394.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 52
# The maximum B value is 2.2004642232787e-06 T
# The minimum B value is -1.7366556903653e-06 T
# The delta of B is 0.07804380250245807 T
# 調整後的 delta B: 0.07804380250245807
# delta B 大於70 mT
# 實際 delta B: 0.07804380250245807 與預期 delta B: 0.08 差了 0.001956197497541931T
# delta B 誤差介於 0.0015 ~ 0.003
# 增益增加 1
# set excitation amplitude be 394.0E-3VPP
# set power gain be 53
# CH1 no clipping
# amplitude of CH1 is 4.2946364679023
# set CH1 vertical scale be 0.7808429941640544
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 25.6204987524612
# set CH2 vertical scale be 4.658272500447491
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 7.1131978669369
# set CH3 vertical scale be 1.2933087030794364
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '394.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 53
# The maximum B value is 2.2902881937625e-06 T
# The minimum B value is -1.7940294583241e-06 T
# The delta of B is 0.08096163875834955 T
# 調整後的 delta B: 0.08096163875834955
# delta B已達預期的0.08
# {1: '316.0E-3', 2: '356.0E-3', 3: '378.0E-3', 4: '394.0E-3'}
# {1: 13, 2: 35, 3: 46, 4: 53}
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 5
# Current population: 12
# Current population: 16
# Current population: 24
# Current population: 33
# Poplution採樣數量已超過 25
# The maximum B value is 2.24964469453e-06 T
# The minimum B value is -1.8307914615434e-06 T
# The delta of B is 0.08088469756404697 T
# The true power of 1 is 0.1087424271542686 W
# The true power of 2 is 0.0023352705851513 W
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 4
# Current population: 12
# Current population: 16
# Current population: 26
# Poplution採樣數量已超過 25
# The maximum B value is 2.287891220476e-06 T
# The minimum B value is -1.7936772565008e-06 T
# The delta of B is 0.08090714306504583 T
# The true power of 1 is 0.1330106086543921 W
# The true power of 2 is 0.0091156177878928 W
# k factor:0.27939247127795697
# Core Real power loss:0.10808997013438046
# Every volume of Core Real power loss:210.8448807728585
# [第4次測量]花費時間: 0:57
# 程式執行累計時間: 5:14
# [第5次測量]
# Current population: 29
# Poplution採樣數量已超過 5
# The maximum B value is 2.2873455236549e-06 T
# The minimum B value is -1.7938682503882e-06 T
# The delta of B is 0.08090011194424893 T
# delta B 大於70 mT
# 實際 delta B: 0.08090011194424893 與預期 delta B: 0.1 差了 0.01909988805575108T
# delta B 誤差大於 0.008
# AFG 振幅已增加 2V，設為396.0E-3 VPP
# 增益增加 2
# set excitation amplitude be 396.0E-3VPP
# set power gain be 55
# CH1 no clipping
# amplitude of CH1 is 4.4548338864245
# set CH1 vertical scale be 0.8099697975317273
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 27.7893554058721
# set CH2 vertical scale be 5.052610073794927
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 7.6852023014527
# set CH3 vertical scale be 1.3973095093550363
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '396.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 55
# The maximum B value is 2.4932251108112e-06 T
# The minimum B value is -1.9362960301805e-06 T
# The delta of B is 0.08780445622446373 T
# 調整後的 delta B: 0.08780445622446373
# delta B 大於70 mT
# 實際 delta B: 0.08780445622446373 與預期 delta B: 0.1 差了 0.012195543775536277T
# delta B 誤差大於 0.008
# AFG 振幅已增加 2V，設為398.0E-3 VPP
# 增益增加 2
# set excitation amplitude be 398.0E-3VPP
# set power gain be 57
# CH1 no clipping
# amplitude of CH1 is 4.8756347858671
# set CH1 vertical scale be 0.8864790519758364
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 30.1645202946181
# set CH2 vertical scale be 5.484458235385109
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 8.229589422973
# set CH3 vertical scale be 1.4962889859950907
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '398.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 57
# The maximum B value is 2.7439193672762e-06 T
# The minimum B value is -2.096508978866e-06 T
# The delta of B is 0.09594968966133952 T
# 調整後的 delta B: 0.09594968966133952
# delta B 大於70 mT
# 實際 delta B: 0.09594968966133952 與預期 delta B: 0.1 差了 0.00405031033866049T
# delta B 誤差介於 0.003 ~ 0.005
# AFG 振幅已增加 1V，設為399.0E-3 VPP
# 增益增加 1
# set excitation amplitude be 399.0E-3VPP
# set power gain be 58
# CH1 no clipping
# amplitude of CH1 is 5.1576880590794
# set CH1 vertical scale be 0.9377614652871636
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 31.6644002291191
# set CH2 vertical scale be 5.757163678021654
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 8.5176267707043
# set CH3 vertical scale be 1.5486594128553273
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '399.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 58
# The maximum B value is 2.8650085823756e-06 T
# The minimum B value is -2.172200311179e-06 T
# The delta of B is 0.09985038420847737 T
# 調整後的 delta B: 0.09985038420847737
# delta B已達預期的0.1
# {1: '316.0E-3', 2: '356.0E-3', 3: '378.0E-3', 4: '394.0E-3', 5: '399.0E-3'}
# {1: 13, 2: 35, 3: 46, 4: 53, 5: 58}
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 6
# Current population: 13
# Current population: 18
# Current population: 27
# Poplution採樣數量已超過 25
# The maximum B value is 2.8204915452079e-06 T
# The minimum B value is -2.2205545064935e-06 T
# The delta of B is 0.09992644651268652 T
# The true power of 1 is 0.19404643154998 W
# The true power of 2 is 0.0043790692479428 W
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 11
# Current population: 13
# Current population: 23
# Current population: 32
# Poplution採樣數量已超過 25
# The maximum B value is 2.8657727852988e-06 T
# The minimum B value is -2.1770249531983e-06 T
# The delta of B is 0.09996116943231517 T
# The true power of 1 is 0.2303238666871818 W
# The true power of 2 is 0.014210386305911 W
# k factor:0.2710036423684864
# Core Real power loss:0.19285968783360366
# Every volume of Core Real power loss:376.200287932478
# [第5次測量]花費時間: 0:56
# 程式執行累計時間: 6:10
# [第6次測量]
# Current population: 36
# Poplution採樣數量已超過 5
# The maximum B value is 2.8660126645264e-06 T
# The minimum B value is -2.1768610167783e-06 T
# The delta of B is 0.0999626748133063 T
# delta B 大於70 mT
# 實際 delta B: 0.0999626748133063 與預期 delta B: 0.12 差了 0.020037325186693697T
# delta B 誤差大於 0.008
# AFG 振幅已增加 2V，設為401.0E-3 VPP
# 增益增加 2
# set excitation amplitude be 401.0E-3VPP
# set power gain be 60
# CH1 no clipping
# amplitude of CH1 is 5.3734497327872
# set CH1 vertical scale be 0.9769908605067635
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 34.421530315015
# set CH2 vertical scale be 6.258460057275454
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 9.2286463625382
# set CH3 vertical scale be 1.6779357022796726
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '401.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 60
# The maximum B value is 3.1388535717269e-06 T
# The minimum B value is -2.344410177102e-06 T
# The delta of B is 0.10869233410938092 T
# 調整後的 delta B: 0.10869233410938092
# delta B 大於70 mT
# 實際 delta B: 0.10869233410938092 與預期 delta B: 0.12 差了 0.011307665890619073T
# delta B 誤差大於 0.008
# AFG 振幅已增加 2V，設為403.0E-3 VPP
# 增益增加 2
# set excitation amplitude be 403.0E-3VPP
# set power gain be 62
# CH1 no clipping
# amplitude of CH1 is 5.9005030378322
# set CH1 vertical scale be 1.0728187341513091
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 37.4837900926927
# set CH2 vertical scale be 6.815234562307764
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 9.9487559014414
# set CH3 vertical scale be 1.8088647093529817
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '403.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 62
# The maximum B value is 3.4275471989531e-06 T
# The minimum B value is -2.5512320007692e-06 T
# The delta of B is 0.1185147197198431 T
# 調整後的 delta B: 0.1185147197198431
# delta B已達預期的0.12
# {1: '316.0E-3', 2: '356.0E-3', 3: '378.0E-3', 4: '394.0E-3', 5: '399.0E-3', 6: '403.0E-3'}
# {1: 13, 2: 35, 3: 46, 4: 53, 5: 58, 6: 62}
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 6
# Current population: 14
# Current population: 23
# Current population: 30
# Poplution採樣數量已超過 25
# The maximum B value is 3.3728319976944e-06 T
# The minimum B value is -2.6062755296152e-06 T
# The delta of B is 0.11852122801370801 T
# The true power of 1 is 0.3074014599434673 W
# The true power of 2 is 0.0035008425317163 W
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Current population: 11
# Current population: 20
# Current population: 29
# Poplution採樣數量已超過 25
# The maximum B value is 3.4263068755536e-06 T
# The minimum B value is -2.5530478069413e-06 T
# The delta of B is 0.11852612726262399 T
# The true power of 1 is 0.3568550286631901 W
# The true power of 2 is 0.0167934066061503 W
# k factor:0.2687887733597017
# Core Real power loss:0.3064604727736418
# Every volume of Core Real power loss:597.7947978264813
# [第6次測量]花費時間: 0:46
# 程式執行累計時間: 6:57
# [第7次測量]
# Current population: 33
# Poplution採樣數量已超過 5
# The maximum B value is 3.4262495773874e-06 T
# The minimum B value is -2.5529011509207e-06 T
# The delta of B is 0.11852208436816732 T
# delta B 大於110 mT
# 實際 delta B: 0.11852208436816732 與預期 delta B: 0.14 差了 0.021477915631832697T
# delta B 誤差大於 0.008
# AFG 振幅已增加 2V，設為405.0E-3 VPP
# 增益增加 2
# set excitation amplitude be 405.0E-3VPP
# set power gain be 64
# CH1 no clipping
# amplitude of CH1 is 6.2813773940409
# set CH1 vertical scale be 1.1420686170983456
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 40.8880629282564
# set CH2 vertical scale be 7.434193259682982
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 10.7411917877534
# set CH3 vertical scale be 1.9529439614097093
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '405.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 64
# The maximum B value is 3.7491581679205e-06 T
# The minimum B value is -2.7598421183939e-06 T
# The delta of B is 0.1290250599361087 T
# 調整後的 delta B: 0.1290250599361087
# delta B 大於110 mT
# 實際 delta B: 0.1290250599361087 與預期 delta B: 0.14 差了 0.010974940063891325T
# delta B 誤差大於 0.008
# AFG 振幅已增加 2V，設為407.0E-3 VPP
# 增益增加 2
# set excitation amplitude be 407.0E-3VPP
# set power gain be 66
# CH1 no clipping
# amplitude of CH1 is 6.8740314284253
# set CH1 vertical scale be 1.2498238960773274
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 44.6003511691282
# set CH2 vertical scale be 8.10915475802331
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 11.5407334315315
# set CH3 vertical scale be 2.098315169369364
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '407.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 66
# The maximum B value is 4.1309117477795e-06 T
# The minimum B value is -2.9703639938816e-06 T
# The delta of B is 0.14076547670724768 T
# 調整後的 delta B: 0.14076547670724768
# delta B已達預期的0.14
# {1: '316.0E-3', 2: '356.0E-3', 3: '378.0E-3', 4: '394.0E-3', 5: '399.0E-3', 6: '403.0E-3', 7: '407.0E-3'}
# {1: 13, 2: 35, 3: 46, 4: 53, 5: 58, 6: 62, 7: 66}
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 7
# Current population: 10
# Current population: 18
# Current population: 28
# Poplution採樣數量已超過 25
# The maximum B value is 4.0660697777639e-06 T
# The minimum B value is -3.0274684377218e-06 T
# The delta of B is 0.1406120991170458 T
# The true power of 1 is 0.4894086538116912 W
# The true power of 2 is 0.0039308987670572 W
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 7
# Current population: 10
# Current population: 19
# Current population: 28
# Poplution採樣數量已超過 25
# The maximum B value is 4.122938207729e-06 T
# The minimum B value is -2.9694519980694e-06 T
# The delta of B is 0.1405893426241597 T
# The true power of 1 is 0.5579215429394111 W
# The true power of 2 is 0.0221561160231655 W
# k factor:0.2660115124051087
# Core Real power loss:0.4883629894855549
# Every volume of Core Real power loss:952.6215629807729
# [第7次測量]花費時間: 0:46
# 程式執行累計時間: 7:43
# [第8次測量]
# Current population: 31
# Poplution採樣數量已超過 5
# The maximum B value is 4.1250764297729e-06 T
# The minimum B value is -2.9676480153285e-06 T
# The delta of B is 0.14059596810337396 T
# delta B 大於110 mT
# 實際 delta B: 0.14059596810337396 與預期 delta B: 0.16 差了 0.01940403189662604T
# delta B 誤差大於 0.008
# AFG 振幅已增加 2V，設為409.0E-3 VPP
# 增益增加 2
# set excitation amplitude be 409.0E-3VPP
# set power gain be 68
# CH1 no clipping
# amplitude of CH1 is 7.3182711659159
# set CH1 vertical scale be 1.3305947574392545
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 48.696490434034
# set CH2 vertical scale be 8.853907351642546
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 12.4489928211743
# set CH3 vertical scale be 2.2634532402135092
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '409.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 68
# The maximum B value is 4.5420874812407e-06 T
# The minimum B value is -3.2209800338023e-06 T
# The delta of B is 0.1538838849834551 T
# 調整後的 delta B: 0.1538838849834551
# delta B 大於110 mT
# 實際 delta B: 0.1538838849834551 與預期 delta B: 0.16 差了 0.00611611501654491T
# delta B 誤差介於 0.005 ~ 0.008
# AFG 振幅已增加 1V，設為410.0E-3 VPP
# 增益增加 1
# set excitation amplitude be 410.0E-3VPP
# set power gain be 69
# CH1 no clipping
# amplitude of CH1 is 7.9297468328829
# set CH1 vertical scale be 1.4417721514332547
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 50.9241456816316
# set CH2 vertical scale be 9.258935578478473
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 12.933938500165
# set CH3 vertical scale be 2.3516251818481817
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '410.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 69
# The maximum B value is 4.7739081310283e-06 T
# The minimum B value is -3.33783646056e-06 T
# The delta of B is 0.1607955578549704 T
# 調整後的 delta B: 0.1607955578549704
# delta B已達預期的0.16
# {1: '316.0E-3', 2: '356.0E-3', 3: '378.0E-3', 4: '394.0E-3', 5: '399.0E-3', 6: '403.0E-3', 7: '407.0E-3', 8: '410.0E-3'}
# {1: 13, 2: 35, 3: 46, 4: 53, 5: 58, 6: 62, 7: 66, 8: 69}
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 6
# Current population: 13
# Current population: 18
# Current population: 28
# Poplution採樣數量已超過 25
# The maximum B value is 4.705660558102e-06 T
# The minimum B value is -3.4094382499461e-06 T
# The delta of B is 0.16086204701777995 T
# The true power of 1 is 0.7039743175601634 W
# The true power of 2 is 0.0057630637853164 W
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 5
# Current population: 9
# Current population: 17
# Current population: 26
# Poplution採樣數量已超過 25
# The maximum B value is 4.7774797167222e-06 T
# The minimum B value is -3.3337391869281e-06 T
# The delta of B is 0.16078513737337188 T
# The true power of 1 is 0.7909617563208755 W
# The true power of 2 is 0.0284618360937413 W
# k factor:0.26094310433562046
# Core Real power loss:0.7024704858055387
# Every volume of Core Real power loss:1370.2687274497666
# [第8次測量]花費時間: 0:46
# 程式執行累計時間: 8:29
# [第9次測量]
# Current population: 30
# Poplution採樣數量已超過 5
# The maximum B value is 4.7767580326763e-06 T
# The minimum B value is -3.3342907954648e-06 T
# The delta of B is 0.16078176604109304 T
# delta B 大於155 mT
# 實際 delta B: 0.16078176604109304 與預期 delta B: 0.18 差了 0.019218233958906955T
# delta B 誤差大於 0.008
# AFG 振幅已增加 0V，設為410.0E-3 VPP
# 增益增加 1
# set excitation amplitude be 410.0E-3VPP
# set power gain be 70
# CH1 no clipping
# amplitude of CH1 is 8.1638794808715
# set CH1 vertical scale be 1.4843417237948182
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 53.0482813805405
# set CH2 vertical scale be 9.645142069189182
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 13.431298684192
# set CH3 vertical scale be 2.4420543062167273
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '410.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 70
# The maximum B value is 5.01423892274e-06 T
# The minimum B value is -3.4708752991719e-06 T
# The delta of B is 0.16819670039787582 T
# 調整後的 delta B: 0.16819670039787582
# delta B 大於155 mT
# 實際 delta B: 0.16819670039787582 與預期 delta B: 0.18 差了 0.011803299602124173T
# delta B 誤差大於 0.008
# AFG 振幅已增加 0V，設為410.0E-3 VPP
# 增益增加 1
# set excitation amplitude be 410.0E-3VPP
# set power gain be 71
# CH1 no clipping
# amplitude of CH1 is 8.5479164181619
# set CH1 vertical scale be 1.554166621483982
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 55.5222457425172
# set CH2 vertical scale be 10.094953771366763
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 13.9368509915794
# set CH3 vertical scale be 2.5339729075598907
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '410.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 71
# The maximum B value is 5.2691511882585e-06 T
# The minimum B value is -3.5931350339524e-06 T
# The delta of B is 0.1756732156543156 T
# 調整後的 delta B: 0.1756732156543156
# delta B 大於155 mT
# 實際 delta B: 0.1756732156543156 與預期 delta B: 0.18 差了 0.004326784345684398T
# delta B 誤差介於 0.003 ~ 0.005
# AFG 振幅已增加 0V，設為410.0E-3 VPP
# 增益增加 1
# set excitation amplitude be 410.0E-3VPP
# set power gain be 72
# CH1 no clipping
# amplitude of CH1 is 8.858593896911
# set CH1 vertical scale be 1.610653435802
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 57.9169565271396
# set CH2 vertical scale be 10.5303557322072
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 14.49958089064
# set CH3 vertical scale be 2.6362874346618184
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '410.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 72
# The maximum B value is 5.5429914027627e-06 T
# The minimum B value is -3.7268694086379e-06 T
# The delta of B is 0.1837523881056065 T
# 調整後的 delta B: 0.1837523881056065
# delta B 大於155 mT
# 實際 delta B: 0.1837523881056065 與預期 delta B: 0.18 差了 -0.003752388105606519T
# 實際deltaB大於預期deltaB 0.0018
# AFG 振幅已減少 7V， 設為403.0E-3 VPP
# 增益減少 1
# set excitation amplitude be 403.0E-3VPP
# set power gain be 71
# CH1 no clipping
# amplitude of CH1 is 8.8197631140835
# set CH1 vertical scale be 1.6035932934697272
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 54.464023699
# set CH2 vertical scale be 9.902549763454546
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 13.6700131679051
# set CH3 vertical scale be 2.4854569396191093
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '403.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 71
# The maximum B value is 5.16999489264e-06 T
# The minimum B value is -3.5422533528617e-06 T
# The delta of B is 0.17269907860007397 T
# 調整後的 delta B: 0.17269907860007397
# delta B 大於155 mT
# 實際 delta B: 0.17269907860007397 與預期 delta B: 0.18 差了 0.007300921399926025T
# delta B 誤差介於 0.005 ~ 0.008
# AFG 振幅已增加 0V，設為403.0E-3 VPP
# 增益增加 1
# set excitation amplitude be 403.0E-3VPP
# set power gain be 72
# CH1 no clipping
# amplitude of CH1 is 8.7297459980405
# set CH1 vertical scale be 1.5872265450982725
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 57.0614928589527
# set CH2 vertical scale be 10.374816883445945
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 14.2821148199769
# set CH3 vertical scale be 2.596748149086709
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '403.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 72
# The maximum B value is 5.4462125262944e-06 T
# The minimum B value is -3.67471352547e-06 T
# The delta of B is 0.18080011963988923 T
# 調整後的 delta B: 0.18080011963988923
# delta B已達預期的0.18
# {1: '316.0E-3', 2: '356.0E-3', 3: '378.0E-3', 4: '394.0E-3', 5: '399.0E-3', 6: '403.0E-3', 7: '407.0E-3', 8: '410.0E-3', 9: '403.0E-3'}
# {1: 13, 2: 35, 3: 46, 4: 53, 5: 58, 6: 62, 7: 66, 8: 69, 9: 72}
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 7
# Current population: 16
# Current population: 18
# Current population: 27
# Poplution採樣數量已超過 25
# The maximum B value is 5.3591402320308e-06 T
# The minimum B value is -3.7622694435413e-06 T
# The delta of B is 0.1808097063026685 T
# The true power of 1 is 0.9668930437377767 W
# The true power of 2 is 0.0085931748216681 W
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 4
# Current population: 11
# Current population: 15
# Current population: 24
# Current population: 34
# Poplution採樣數量已超過 25
# The maximum B value is 5.4455658755614e-06 T
# The minimum B value is -3.6808269214816e-06 T
# The delta of B is 0.18090848453560293 T
# The true power of 1 is 1.0787650897693 W
# The true power of 2 is 0.036503102672596 W
# k factor:0.24948080276518284
# Core Real power loss:0.9647492115849654
# Every volume of Core Real power loss:1881.8807354600365
# [第9次測量]花費時間: 1:18
# 程式執行累計時間: 9:48
# [第10次測量]
# Current population: 37
# Poplution採樣數量已超過 5
# The maximum B value is 5.4468910093419e-06 T
# The minimum B value is -3.68060841538e-06 T
# The delta of B is 0.18093042073107327 T
# delta B 大於155 mT
# 實際 delta B: 0.18093042073107327 與預期 delta B: 0.2 差了 0.019069579268926745T
# delta B 誤差大於 0.008
# AFG 振幅已增加 0V，設為403.0E-3 VPP
# 增益增加 1
# set excitation amplitude be 403.0E-3VPP
# set power gain be 73
# CH1 no clipping
# amplitude of CH1 is 9.026206636083
# set CH1 vertical scale be 1.6411284792878182
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 59.8432250812466
# set CH2 vertical scale be 10.880586378408474
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 14.7654325842855
# set CH3 vertical scale be 2.6846241062337275
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '403.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 73
# The maximum B value is 5.7337515499967e-06 T
# The minimum B value is -3.8543084883713e-06 T
# The delta of B is 0.19005991192265326 T
# 調整後的 delta B: 0.19005991192265326
# delta B 大於155 mT
# 實際 delta B: 0.19005991192265326 與預期 delta B: 0.2 差了 0.009940088077346754T
# delta B 誤差大於 0.008
# AFG 振幅已增加 0V，設為403.0E-3 VPP
# 增益增加 1
# set excitation amplitude be 403.0E-3VPP
# set power gain be 74
# CH1 no clipping
# amplitude of CH1 is 9.47123573546
# set CH1 vertical scale be 1.7220428609927274
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 62.8954812805687
# set CH2 vertical scale be 11.435542051012492
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 15.4373799170521
# set CH3 vertical scale be 2.8067963485549274
# vertical state of CH3 is good
# 設定 Vin amplitude為:{'magnitude': '403.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 74
# The maximum B value is 6.0706552176271e-06 T
# The minimum B value is -3.9934520827956e-06 T
# The delta of B is 0.1994963881582085 T
# 調整後的 delta B: 0.1994963881582085
# delta B已達預期的0.2
# {1: '316.0E-3', 2: '356.0E-3', 3: '378.0E-3', 4: '394.0E-3', 5: '399.0E-3', 6: '403.0E-3', 7: '407.0E-3', 8: '410.0E-3', 9: '403.0E-3', 10: '403.0E-3'}
# {1: 13, 2: 35, 3: 46, 4: 53, 5: 58, 6: 62, 7: 66, 8: 69, 9: 72, 10: 74}
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 6
# Current population: 11
# Current population: 19
# Current population: 28
# Poplution採樣數量已超過 25
# The maximum B value is 5.9703220358642e-06 T
# The minimum B value is -4.07853303841e-06 T
# The delta of B is 0.19919404996395354 T
# The true power of 1 is 1.2449535379577 W
# The true power of 2 is 0.00730767242306 W
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# 對Vref Deskew
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Current population: 11
# Current population: 20
# Current population: 29
# Poplution採樣數量已超過 25
# The maximum B value is 6.05711238677e-06 T
# The minimum B value is -3.9980782275961e-06 T
# The delta of B is 0.19931963659847923 T
# The true power of 1 is 1.3767975188677 W
# The true power of 2 is 0.0400419101712118 W
# k factor:0.2482801074589594
# Core Real power loss:1.2431391882632277
# Every volume of Core Real power loss:2424.920032890808
# [第10次測量]花費時間: 0:46
# 程式執行累計時間: 10:34
# 已經測量完畢
# turn AFG31101 output off
# turn RF150A100D power off
# 整個程式執行的總時間: 10:34
# [第1次測量]花費時間: 1:15
# [第2次測量]花費時間: 1:28
# [第3次測量]花費時間: 1:6
# [第4次測量]花費時間: 0:57
# [第5次測量]花費時間: 0:56
# [第6次測量]花費時間: 0:46
# [第7次測量]花費時間: 0:46
# [第8次測量]花費時間: 0:46
# [第9次測量]花費時間: 1:18
# [第10次測量]花費時間: 0:46
#   core parameter                                                            \
#     type of core effective length of core(mm) effective area of core(mm^2)
# 0          ML95S                    30.486205                    16.815855
# 1          ML95S                    30.486205                    16.815855
# 2          ML95S                    30.486205                    16.815855
# 3          ML95S                    30.486205                    16.815855
# 4          ML95S                    30.486205                    16.815855
# 5          ML95S                    30.486205                    16.815855
# 6          ML95S                    30.486205                    16.815855
# 7          ML95S                    30.486205                    16.815855
# 8          ML95S                    30.486205                    16.815855
# 9          ML95S                    30.486205                    16.815855
#
#                                                             \
#   effective volume of core(mm^3) turns of wire on the core
# 0                     512.651622                         3
# 1                     512.651622                         3
# 2                     512.651622                         3
# 3                     512.651622                         3
# 4                     512.651622                         3
# 5                     512.651622                         3
# 6                     512.651622                         3
# 7                     512.651622                         3
# 8                     512.651622                         3
# 9                     512.651622                         3
#
#   Test environment (R=10)                                          ...  \
#                  Sequence  Function freq(kHz) deltaB(T)  Vin(Vpp)  ...
# 0                       1  SINusoid      1000      0.02  316.0E-3  ...
# 1                       2  SINusoid      1000      0.04  356.0E-3  ...
# 2                       3  SINusoid      1000      0.06  378.0E-3  ...
# 3                       4  SINusoid      1000      0.08  394.0E-3  ...
# 4                       5  SINusoid      1000      0.10  399.0E-3  ...
# 5                       6  SINusoid      1000      0.12  403.0E-3  ...
# 6                       7  SINusoid      1000      0.14  407.0E-3  ...
# 7                       8  SINusoid      1000      0.16  410.0E-3  ...
# 8                       9  SINusoid      1000      0.18  403.0E-3  ...
# 9                      10  SINusoid      1000      0.20  403.0E-3  ...
#
#   flux density (DS=1)                          L(DS=1 degree) CL(DS=1 degree)  \
#                   Max           Min delta B(T)           P(W)            P(W)
# 0        5.330522e-07 -4.425542e-07   0.019339       0.004229        0.000501
# 1        1.084716e-06 -8.975416e-07   0.039293       0.022851        0.002422
# 2        1.672656e-06 -1.359910e-06   0.060113       0.062278        0.005551
# 3        2.287891e-06 -1.793677e-06   0.080907       0.133011        0.009116
# 4        2.865773e-06 -2.177025e-06   0.099961       0.230324        0.014210
# 5        3.426307e-06 -2.553048e-06   0.118526       0.356855        0.016793
# 6        4.122938e-06 -2.969452e-06   0.140589       0.557922        0.022156
# 7        4.777480e-06 -3.333739e-06   0.160785       0.790962        0.028462
# 8        5.445566e-06 -3.680827e-06   0.180908       1.078765        0.036503
# 9        6.057112e-06 -3.998078e-06   0.199320       1.376798        0.040042
#
#   Final calculate                                                 \
#                 K Real Pcore(W) Real Pcv(kW/m^3) Spend time(sec)
# 0        0.332722      0.002975         5.803390            1:15
# 1        0.284231      0.016561        32.303777            1:28
# 2        0.282720      0.048058        93.743175             1:6
# 3        0.279392      0.108090       210.844881            0:57
# 4        0.271004      0.192860       376.200288            0:56
# 5        0.268789      0.306460       597.794798            0:46
# 6        0.266012      0.488363       952.621563            0:46
# 7        0.260943      0.702470      1370.268727            0:46
# 8        0.249481      0.964749      1881.880735            1:18
# 9        0.248280      1.243139      2424.920033            0:46
#
#
#   Measurement accumulated time(sec)
# 0                              1:41
# 1                               3:9
# 2                              4:16
# 3                              5:14
# 4                              6:10
# 5                              6:57
# 6                              7:43
# 7                              8:29
# 8                              9:48
# 9                             10:34
#
# [10 rows x 26 columns]
# AFG_31101 connection closed.
# MSO64B connection closed.
# RF_150A100D connection closed.
