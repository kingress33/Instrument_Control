# %%
#引入需要的包裝

import pyvisa
import pandas as pd
import time
import math

# %% [markdown]
# ### AFG31101
#
# ===============Function List=================
#
# * Set weveform type
# * Set frequency
# * Set amplitude
# * Set output state
# * Set amplitude limit
#
# 若要串接其他儀器 一樣使用class 定義其他儀器的function

# %%
class AFG_31101():
    def __init__(self, resource_address, visa_dll=None):
        """
        初始化儀器控制器。
        :param resource_address: 儀器的資源地址。
        :param visa_dll: 使用的 VISA DLL 路徑。如果為 None，則使用系統預設空白。
        """
        self.resource_address = resource_address
        self.visa_dll = visa_dll if visa_dll is not None else ''
        self.rm = pyvisa.ResourceManager(self.visa_dll)
        self.instrument = None
        self.connect_to_instrument()
        
    def connect_to_instrument(self):
        # 建立與儀器的連接
        self.instrument = self.rm.open_resource(self.resource_address)
        print("Connected to AFG_31101.")
        print(self.query_identity())

    def query_identity(self):
         # 查詢並返回儀器的身份識別信息
        if self.instrument:
             return self.instrument.query("*IDN?")
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def close_instrument(self):
        if self.instrument:
            self.instrument.close()
            print("AFG_31101 connection closed.")
        else:
            print("No instrument to close.")

    def set_waveform(self, shape):
        if self.instrument:
            self.instrument.write(f"SOURce1:FUNCtion {shape}")
            time.sleep(0.05)
            print(f"set excitation form be {shape}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_frequency(self, freq_amplitude, freq_unit):
        if self.instrument:
            self.instrument.write(f"SOURce1:FREQuency:FIXed {freq_amplitude} {freq_unit}")
            time.sleep(0.05)
            print(f"set excitation frequency be {freq_amplitude}{freq_unit}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def query_frequency(self):
        if self.instrument:
            self.instrument.write(f"SOURce1:FREQuency:FIXed?")
            time.sleep(0.05)
            return self.instrument.read()
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_amplitude(self, amp_magnitude, amp_unit):
        if self.instrument:
            self.instrument.write(f"SOURce1:VOLTage:LEVel:IMMediate:AMPLitude {amp_magnitude}{amp_unit}")
            time.sleep(0.05)
            print(f"set excitation amplitude be {amp_magnitude}{amp_unit}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def query_amplitude(self):
        if self.instrument:
            self.instrument.write(f"SOURce1:VOLTage:LEVel:IMMediate:AMPLitude?")
            time.sleep(0.05)
            return self.instrument.read()
        else:
            raise Exception("Instrument not connected. Please connect first.")
    
    def output_on(self):
        if self.instrument:
            self.instrument.write(f"OUTPut1:STATe ON")
            time.sleep(0.05)
            print(f"turn AFG31101 output on")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def output_off(self):
        if self.instrument:
            self.instrument.write(f"OUTPut1:STATe OFF")
            time.sleep(0.05)
            print(f"turn AFG31101 output off")
        else:
            raise Exception("Instrument not connected. Please connect first.")

# %%
def check_output_state(afg, output_state):
    if output_state == 'ON': #判斷輸出狀態，選擇要操作在哪一個輸出狀態DEF
        afg.output_on()
    else:
        afg.output_off()

# %%
def check_amp_limit(afg, amplitude_limit):
    query_amp = afg.query_amplitude()  # 回傳波形振幅大小
    amp_num = float(query_amp)  # 將回傳振幅大小的字串型態轉為數字型態
    if amp_num >= amplitude_limit:  # 判斷振幅是否大於AMPLITUDE_LIMIT
        print(f'Magnitude of amplitude cannot exceed {amplitude_limit} voltage')
        afg.output_off()  # 將OUTPUT關閉

# %% [markdown]
# ### RF-150A_100D
#
# ===============Function List=================
#
# * Set power state
# * Set gain
#
# 若要串接其他儀器 一樣使用class 定義其他儀器的function

# %%
class RF_150A100D():
    def __init__(self, resource_address, visa_dll=None):
        """
        初始化儀器控制器。
        :param resource_address: 儀器的資源地址。
        :param visa_dll: 使用的 VISA DLL 路徑。如果為 None，則使用系統預設空白。
        """
        self.resource_address = resource_address
        self.visa_dll = visa_dll if visa_dll is not None else ''
        self.rm = pyvisa.ResourceManager(self.visa_dll)
        self.instrument = None
        self.connect_to_instrument()
        
    def connect_to_instrument(self):
        # 建立與儀器的連接
        self.instrument = self.rm.open_resource(self.resource_address)
        print("Connected to RF_150A100D.")
        print(self.query_identity())

    def query_identity(self):
         # 查詢並返回儀器的身份識別信息
        if self.instrument:
             return self.instrument.query("*IDN?")
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def close_instrument(self):
        if self.instrument:
            self.instrument.close()
            print(f"RF_150A100D connection closed.")
        else:
            print(f"No instrument to close.")

    def power_on(self):
        if self.instrument:
            self.instrument.write(f"P1")
            print(f"turn RF150A100D power on")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def power_off(self):
        if self.instrument:
            self.instrument.write(f"P0")
            print(f"turn RF150A100D power off")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_gain(self,gain ,gain_set):
        if self.instrument:
            self.instrument.write(f"G{gain_set}")
            print(f"set power gain be {gain}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def reset(self):
        if self.instrument:
            self.instrument.write(f"R")
            print(f"clear faults")
        else:
            raise Exception("Instrument not connected. Please connect first.")

# %%
def check_power_state(rf, power_state):
    if power_state == 'ON': #判斷書出狀態，選擇def
        rf.power_on()
    else:
        rf.power_off()

# %%
def calculate_gain_set(gain):
    """
    計算並返回設置增益的值
    透過設定的gain去計算給儀器的gain_set該為多少
    """
    ratio = 4095 / 100  # MAX和MIN的比例
    gain_set = math.ceil(ratio * gain)  # 使用 math函數進行無條件進位
    gain_set = min(gain_set, 4095)  # 限制 gain_set 最大值為 4095
    gain_set = str(gain_set).zfill(4)  # 保持四個字元
    #print(f"CMD of gain set be G{ratio * gain}")
    return gain_set

# %% [markdown]
# ### MSO64B
#
# ===============Function List=================
#
# * Set channel
# * Auto set horizontal scale
# * Auto set Gating type
# * Auto set cursor positon
# * Auto set bandwidth limit
# * Auto set Acquistion mode & numbers of waveform
# * Set measurements[AMP、MEAN、DELAY]
# * Set math function
#
# 若要串接其他儀器 一樣使用class 定義其他儀器的function

# %%
class MSO_64B():
    def __init__(self, resource_address, visa_dll=None):
        """
        初始化儀器控制器。
        :param resource_address: 儀器的資源地址。
        :param visa_dll: 使用的 VISA DLL 路徑。如果為 None，則使用系統預設空白。
        """
        self.resource_address = resource_address
        self.visa_dll = visa_dll if visa_dll is not None else ''
        self.rm = pyvisa.ResourceManager(self.visa_dll)
        self.instrument = None
        self.connect_to_instrument()
        
    def connect_to_instrument(self):
        # 建立與儀器的連接
        self.instrument = self.rm.open_resource(self.resource_address)
        print("Connected to MSO64B.")
        print(self.query_identity())

    def query_identity(self):
         # 查詢並返回儀器的身份識別信息
        if self.instrument:
             return self.instrument.query("*IDN?")
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def close_instrument(self):
        #關閉與儀器的連接
        if self.instrument:
            self.instrument.close()
            print("MSO64B connection closed.")
        else:
            print("No instrument to close.")

    def clear(self):
        #執行示波器上的clear鍵，讓計算、測量項重新運算
        if self.instrument:
            self.instrument.write(f':CLEAR')
            time.sleep(0.3)  # 在命令之間暫停0.5
            print(f"clear acquistions, measurements, and waveforms")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_gating_type(self):
        if self.instrument:
            #設定measurement中Gating type
            self.instrument.write(f'MEASUrement:GATing CURSor')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"take measurements on the portion of the waveform between the cursor")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def cursor_control(self, cursor_A_position, cursor_B_position):
        if self.instrument:
            #設定cursor範圍為三個波形週期
            self.instrument.write(f':DISplay:WAVEView1:CURSor:CURSOR1:STATE ON')
            self.instrument.write(f':DISplay:WAVEView1:CURSor:CURSOR1:WAVEform:APOSition {cursor_A_position}')
            self.instrument.write(f':DISplay:WAVEView1:CURSor:CURSOR1:WAVEform:BPOSition {cursor_B_position}')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"set cursor range be {cursor_A_position} to {cursor_B_position}")
        else:
            raise Exception("Instrument not connected. Please connect first.")
            
    def result_table(self):
        #打開resulit table
        if self.instrument:
            self.instrument.write(f':MEASTABle:ADDNew "TABLE1"')
            time.sleep(0.05)  # 在命令之間暫停0.5
            print(f"add measurent result table")
        else:
            raise Exception("Instrument not connected. Please connect first.")
            
    def add_measurement(self,meas,channel):
        if self.instrument:       #新增CH1、CH2、CH3的MEAN測量值
            source_CMD = f":DISplay:SELect:WAVEView1:SOUrce {channel}" #測量訊號源CMD
            type_CMD = f":MEASUREMENT:ADDMEAS {meas}" #測量類型CMD
            command = f"{source_CMD};{type_CMD}"
            self.instrument.write(command)
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"add measurent {meas} of {channel}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_horizon_scale(self, horizon_scale):
        if self.instrument:
            self.instrument.write(f':HORIZONTAL:MODE:SCALE {horizon_scale}')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"set Horizontal Scale to {horizon_scale}s/div")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def detect_clip(self,clip_check):
        if self.instrument:
            #查看是否有波形clipping?
            return self.instrument.query(f":{clip_check}:CLIPping?")
            time.sleep(0.05)  # 在命令之間暫停0.5秒
        else:
            raise Exception("Instrument not connected. Please connect first.")
            
    def query_vertical_scale(self,clip_check):
        if self.instrument:
            #回傳當下有clipping之通道的vertical scale為多少?
            return self.instrument.query(f":{clip_check}:SCAle?")
            time.sleep(0.05)  # 在命令之間暫停0.5秒
        else:
            raise Exception("Instrument not connected. Please connect first.")
    
    def set_vertical_scale(self, clip_channel, new_vertical_value):
        if self.instrument:
            #重新對通道設定vertical scale
            self.instrument.write(f":{clip_channel}:SCAle {new_vertical_value}")
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"set {clip_channel} vertical scale be {new_vertical_value}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def math_add(self, math_num, math_function):
        if self.instrument:
            #新增math formula
            self.instrument.write(f':MATH:ADDNew "{math_num}"')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            self.instrument.write(f':MATH:{math_num}:DEFine "{math_function}"')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"Add {math_num} to calculate {math_function}")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def off_display(self, off_channel, off_math):  
        if self.instrument:
            #將不必要的波形關閉
            self.instrument.write(f':DIS:WAVEVIEW1:{off_channel}:STATE OFF')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"turn {off_channel} display off")
            self.instrument.write(f':DISplay:WAVEView1:MATH:{off_math}:STATE OFF')
            time.sleep(0.05)  # 在命令之間暫停0.5秒
            print(f"turn {off_math} display off")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def measure_delta_B(self):
        if self.instrument:
            #新增測量磁通最大值及最小值的measurement
            self.instrument.write(f':MEASUREMENT:MEAS9:TYPE MAXIMUM; SOUrce MATH5') #新增math5的最大值
            time.sleep(0.05)  # 在命令之間暫停0.5秒           
            self.instrument.write(f':MEASUREMENT:MEAS10:TYPE MINIMUM; SOUrce MATH5') #新增math5的最小值
            time.sleep(0.05)  # 在命令之間暫停0.5
            print(f"add measurent maximum of math5")
            print(f"add measurent minimum of math5")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def power_function(self,num,voltage,current):
        if self.instrument:
            self.instrument.write(f':POWer:POWer{num}:POWERQUALITY:VSOURce {voltage}') #新增math5的最小值
            time.sleep(0.05)  # 在命令之間暫停0.5
            self.instrument.write(f':POWer:POWer{num}:POWERQUALITY:ISOURce {current}') #新增math5的最小值
            time.sleep(0.05)  # 在命令之間暫停0.5
            print(f"add measurent maximum of math5")
            print(f"add measurent minimum of math5")
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_deskew(self, deskew_ch1):
        if self.instrument:
            self.instrument.write(f'CH1:DESKEW {deskew_ch1}')
            print(f"CH1 deskew set to {deskew_ch1}")
            time.sleep(0.05)
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def set_deskew_zero(self):
        if self.instrument:
            self.instrument.write(f'CH1:DESKEW 0')
            print(f"CH1 deskew set to 0")
            time.sleep(0.05)
        else:
            raise Exception("Instrument not connected. Please connect first.")

    def query_mean_value(self, meas):
        if self.instrument:                  
            self.instrument.write(f'MEASUrement:{meas}:RESUlts:ALLAcqs:MEAN?')
            time.sleep(0.05)
            return float(self.instrument.read())
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def query_true_power(self, power_num):
        if self.instrument:
            self.instrument.write(f'POWer:POWer{power_num}:RESUlts:CURRentacq:MEAN? "TruePWR"')
            time.sleep(0.05)
            return float(self.instrument.read())
        else:
             raise Exception("Instrument not connected. Please connect first.")

    def query_population(self):
        if self.instrument:
            self.instrument.write(f'MEASUrement:MEAS1:RESUlts:ALLAcqs:POPUlation?')
            time.sleep(0.05)
            return int(self.instrument.read())
        else:
            raise Exception("Instrument not connected. Please connect first.")

# %%
def wait_for_population(mso, threshold=100):
    while True: #重複查詢採樣次數(population)
        pop_num = mso.query_population() 
        print(f"Current population: {pop_num}") #列出每0.5秒的pop次數
        if pop_num >= threshold: #當pop次數大於等於100，結束while迴圈
            print(f"Poplution採樣數量已超過 {threshold}") 
            break #跳脫迴圈
        time.sleep(2)  # 防止過於頻繁的查詢，調整每0.5秒查詢一次

# %%
def set_horizon_scale(afg, mso):
    """
    設置示波器的horizon scale
    [因為如果一開始示波器的horizon scale沒有調好，抓到的freq值會過大，調整錯誤，因此直接從AFG訊號產生器抓值]
    """
    freq = float(afg.query_frequency()) #從afg抓頻率值
    print(f"the frequency of excitaton is {freq}")
    
    horizon_scale = (1 / freq) * (4 / 10)
    mso.set_horizon_scale(horizon_scale) #自動調整horizon scale

# %%
def set_cursor_range(afg, mso):
    """
    設置示波器的cursor range
    [因為如果一開始示波器的horizon scale沒有調好，抓到的freq值會過大，調整錯誤，因此直接從AFG訊號產生器抓值]
    """
    freq = float(afg.query_frequency()) #從afg抓頻率值
    print(f"the frequency of excitaton is {freq}")
    
    cursor_A_position = -1.5 * (1 / freq)  # 設cursor_A為負1.5波形週期sec
    cursor_B_position = 1.5 * (1 / freq)  # 設cursor_B為正1.5波形週期sec
    mso.cursor_control(cursor_A_position, cursor_B_position)

# %%
def set_vertical_scale(mso):
    clip_channels = ['CH1','CH2','CH3']#分別測試ch1、ch2、ch3是否clipping?

    channel_meas = {'CH1': 'MEAS3','CH2': 'MEAS4','CH3': 'MEAS5'}
    
    for clip_channel in clip_channels:
        while True: #重複測試到最後沒通道clipping & vertical scale都設定到80%
            clip_result = float(mso.detect_clip(clip_channel)) 
            print(f"clipping state:{clip_result}") #顯示1代表有clipping，0代表沒有clipping
            if clip_result == 1: #clipping時
                clip_vertical_scale = float(mso.query_vertical_scale(clip_channel))
                new_clip_vertical_scale = clip_vertical_scale + 40e-3 #將當下的vertical scale以20mV/div為step加上去
                mso.set_vertical_scale(clip_channel, new_clip_vertical_scale) #設定新的vertical scale
                time.sleep(0.5) #最後調整到沒有clipping等待久一點，讓下面程序執行正常
                print(f"{clip_channel} is clipping, auto set vertical scale from {clip_vertical_scale} to {new_clip_vertical_scale}")
            elif clip_result == 0: # 當channel沒有clipping時
                time.sleep(1)
                meas = channel_meas[clip_channel] #當下的clip_channel對應的meas是什麼?
                clip_amplitude = float(mso.query_mean_value(meas)) # 看該通道的amplitude大小
                print(f"amplitude of {clip_channel} is {clip_amplitude}")
                new_vertical_scale = clip_amplitude / 7  #將amplitude大小除以8即為理想的80% vertical scale
                mso.set_vertical_scale(clip_channel, new_vertical_scale) # 設定新的vertical scale
                print(f"{clip_channel} no clipping, auto set vertical scale to {new_vertical_scale}")
                break

# %%
def save_mso_query_values(mso, sequence, core_effective_area, turn):
    """
    用來儲存向儀器(示波器)查詢之值的包裝
    """
    B_max = mso.query_mean_value('MEAS9')
    B_min = mso.query_mean_value('MEAS10')
    calculate_delta_B = (B_max - B_min) / (core_effective_area * turn)
    
    time.sleep(0.05)
    print(f"The maximum B value is {B_max} T")
    print(f"The minimum B value is {B_min} T")
    print(f"The delta of B is {calculate_delta_B} T")
    
    return B_max, B_min, calculate_delta_B

# %%
def save_mso_power_values(mso, sequence):
    """
    用來儲存向儀器(示波器)查詢之值的包裝
    """
    power1_value = float(mso.query_true_power('1'))
    power2_value = float(mso.query_true_power('2'))
    
    time.sleep(0.05)
    print(f"The true power of 1 is {power1_value} W")
    print(f"The true power of 2 is {power2_value} W")
    
    return power1_value, power2_value

# %%
def set_vref_deskew(afg, mso, deskew_vref):
    freq = float(afg.query_frequency())
    deskew_ch1 = (deskew_vref)/(360 * freq)
    print(f"Deskew time of CH1 = {deskew_ch1}")
    mso.set_deskew(deskew_ch1)

# %%
def acquire_measurement(mso, i, core_effective_area, turn, max_B, min_B, delta_B, Pcore_true_power, PL_true_power, deskew=False):
    B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
        
    # 更新 max_B 和 min_B 字典
    if deskew:
        if 'MEAS9' not in max_B:
            max_B['MEAS9'] = []
        max_B['MEAS9'].append((i, B_max))
        print("max_B_deskew:", max_B)

        if 'MEAS10' not in min_B:
            min_B['MEAS10'] = []
        min_B['MEAS10'].append((i, B_min))
        print("min_B_deskew:", min_B)
        
        delta_B[i] = calculate_delta_B
        print("delta_B_deskew:", delta_B)
    else:
        if 'MEAS9' not in max_B:
            max_B['MEAS9'] = []
        max_B['MEAS9'].append((i, B_max))
        print("max_B:", max_B)

        if 'MEAS10' not in min_B:
            min_B['MEAS10'] = []
        min_B['MEAS10'].append((i, B_min))
        print("min_B:", min_B)
        
        delta_B[i] = calculate_delta_B
        print("delta_B:", delta_B)

    # 量測損耗功率
    power1_value, power2_value = save_mso_power_values(mso, i)

    if deskew:
        if '1' not in Pcore_true_power:
            Pcore_true_power['1'] = []
        Pcore_true_power['1'].append((i, power1_value))
        print("Pcore true power_deskew:", Pcore_true_power)
        
        if '2' not in PL_true_power:
            PL_true_power['2'] = []
        PL_true_power['2'].append((i, power2_value))
        print("PL true power_deskew:", PL_true_power)
    else:
        if '1' not in Pcore_true_power:
            Pcore_true_power['1'] = []
        Pcore_true_power['1'].append((i, power1_value))
        print("Pcore true power:", Pcore_true_power)
        
        if '2' not in PL_true_power:
            PL_true_power['2'] = []
        PL_true_power['2'].append((i, power2_value))
        print("PL true power:", PL_true_power)

# %%
def calculate_core_parameters(sequence, Pcore_true_power, PL_true_power, Pcore_true_power_deskew, PL_true_power_deskew, core_effective_volume):
    """
    套公式計算 k_factor, Pcore 和 Pcore_cv
    """
    k_factor = (PL_true_power_deskew['2'][sequence-1][1] - PL_true_power['2'][sequence-1][1]) / (Pcore_true_power_deskew['1'][sequence-1][1] - Pcore_true_power['1'][sequence-1][1])
    print(f"k factor:{k_factor}")
    Pcore = (Pcore_true_power['1'][sequence-1][1] - (k_factor * PL_true_power['2'][sequence-1][1]))
    print(f"Core Real power loss:{Pcore}")
    Pcore_cv = Pcore / core_effective_volume
    print(f"Every volume of Core Real power loss:{Pcore_cv}")

    return k_factor, Pcore, Pcore_cv

# %%
def adjust_rf_afg(mso, rf, afg, i, core_effective_area, turn, target_deltaB, gain, amplitude):
    """
    調整 RF 增益以達到目標 delta B 值
    """
    tolerance_max = 0.01
    tolerance_mean = 0.006
    tolerance_min = 0.003
    tolerance_final = 0.001
    
    # 查詢初始的 delta B 值
    B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
    
    while abs(target_deltaB - calculate_delta_B) > tolerance_final:
        if calculate_delta_B < 0.05:
            print("delta B 小於50 mT")
            tolerance_final = 0.0005
            step_rf_max = 10
            step_rf_mid = 5
            step_rf_mean = 3
            step_rf_min = 1
            step_afg = 3
        else:
            print("delta B 大於50 mT")
            step_rf_max = 5
            step_rf_mid = 3
            step_rf_mean = 2
            step_rf_min = 1
            step_afg = 2
            
        tolerance = target_deltaB - calculate_delta_B
        print(f"實際 delta B: {calculate_delta_B} 與預期 delta B: {target_deltaB} 差了 {tolerance}T")

        if tolerance < -tolerance_final:
            print(f"實際deltaB大於預期deltaB {tolerance_final}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) - step_afg  # 移除 'E-3' 並減少 3mV
            amplitude['magnitude'] = f"{amplitude_value}E-3"
            afg.set_amplitude(amplitude['magnitude'], amplitude['unit'])
            print(f"AFG 振幅已設置為 {amplitude['magnitude']} {amplitude['unit']}")
            gain -= step_rf_min
            print(f"增益減少 {step_rf_min}")
        elif tolerance < -tolerance_mean:
            print(f"實際deltaB大於預期deltaB {tolerance_mean}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) - step_afg  # 移除 'E-3' 並減少 3mV
            amplitude['magnitude'] = f"{amplitude_value}E-3"
            afg.set_amplitude(amplitude['magnitude'], amplitude['unit'])
            print(f"AFG 振幅已設置為 {amplitude['magnitude']} {amplitude['unit']}")
            gain -= step_rf_mean
            print(f"增益減少 {step_rf_mean}")
        elif tolerance > tolerance_max:
            print(f"delta B 誤差大於 {tolerance_max}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg  # 移除 'E-3' 並增加 3mV
            amplitude['magnitude'] = f"{amplitude_value}E-3"
            afg.set_amplitude(amplitude['magnitude'], amplitude['unit'])
            print(f"AFG 振幅已設置增加 {step_afg}V，設為{amplitude['magnitude']} {amplitude['unit']}")
            gain += step_rf_max
            print(f"增益增加 {step_rf_max}")
        elif tolerance > tolerance_mean:
            print(f"delta B 誤差介於 {tolerance_mean} ~ {tolerance_max}")
            gain += step_rf_mid
            print(f"增益增加 {step_rf_mid}")
        elif tolerance > tolerance_min:
            print(f"delta B 誤差介於 {tolerance_min} ~ {tolerance_mean}")
            gain += step_rf_mean
            print(f"增益增加 {step_rf_mean}")
        else: #改
            print(f"delta B 誤差介於 {tolerance_final} ~ {tolerance_min}")
            gain += step_rf_min
            print(f"增益增加 {step_rf_min}")

        gain_set = calculate_gain_set(gain)
        rf.set_gain(gain, gain_set)
        
        mso.clear()
        wait_for_population(mso, threshold=5)
        set_vertical_scale(mso)

        wait_for_population(mso, threshold=5)

        print(f"設定 Vin amplitude為:{amplitude}")
        print(f"設定 RF Gain為: {gain}")
        B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
        print(f"調整後的 delta B: {calculate_delta_B}")

    
    print(f"delta B已達預期的{target_deltaB}")
    return amplitude, gain

# %% [markdown]
# #### 從較小的激勵源開始
#
# * 設定expect deltaB：[0.02,0.04,0.06](T)
# * 查看calculate deltaB
# * 計算兩者誤差tolerance
#
# * tolerance為負的:RF的Gain:不變/AFG振幅:-5mV
#
# * 相差0.01以上：RF的Gain:+10/AFG振幅：不變
#
# * 相差0.005~0.01：RF的:Gain+5/AFG振幅:不變
#
# * 相差0.003~0.005：RF的:Gain+3/AFG振幅：不變
#
# * 相差0.001~0.003：RF的:Gain+1/AFG振幅：不變
#
# * 相差0.001內:不變/AFG振幅：不變

# %%
def main():
    
    # =========================Parmeters===============================
    #=====MSO64B parameter=====
    """
    channel:{CH1 | CH2 | CH3 | CH4 }[page:2-541]
    measure type:{AMPLITUDE | FREQUENCY | MAXIMUM | MEAN | MINIMUM | PERIOD | PHASE 
    | PK2PK | RMS } [page:2-717]
    math_num:{MATH1 | MATH2 | MATH3 | MATH4 | ...}[page:2-672]
    math_function:{first letter should be capital then calculate}[page:2-677]
    gating_type:{NONE | SCREEN | CURSor | LOGic | SEARch | TIMe }[page:2-754]
    """

    #針對display的通道新增測量項
    measurements = [
        {'channel': 'CH1','measurement': 'MEAN'},
        {'channel': 'CH2','measurement': 'MEAN'},
        {'channel': 'CH3','measurement': 'MEAN'}
    ]    
    
    #設定欲增加計算及公式
    mso_maths = [
        {'math_num': 'MATH1', 'math_function': 'Ch1-Meas6'},
        {'math_num': 'MATH2', 'math_function': 'Ch2-Meas7'},
        {'math_num': 'MATH3', 'math_function': 'Ch3-Meas8'},
        {'math_num': 'MATH4', 'math_function': 'Math1/10'},
        {'math_num': 'MATH5', 'math_function': 'Intg(Math2)'}
    ]
    
    #設定powerfunction內容 done
    powers = [
        {'Power_num': '1','Voltage_Source': 'MATH2', 'Current_Source': 'MATH4'},
        {'Power_num': '2','Voltage_Source': 'MATH3', 'Current_Source': 'MATH4'}
    ]

    #將特定通道停止顯示(display off)，可控制channel&math
    off_displays = [
        {'channel': 'NONE','math': 'MATH1'},
        {'channel': 'NONE','math': 'MATH2'},
        {'channel': 'NONE','math': 'MATH3'},
        {'channel': 'NONE','math': 'MATH6'},
        {'channel': 'NONE','math': 'MATH7'},
        {'channel': 'NONE','math': 'MATH8'},
        {'channel': 'NONE','math': 'MATH9'}
    ]

    #=====AFG_31101 parameter=====
    """
    shape:{SINusoid|SQUare|PULSe|RAMP|PRNoise|DC|SINC|GAUSsian|LORentz|ERISe|EDECay|HAVersine
     |EMEMory[1]|EMEMory2|EFILe} 
    amplitude:
        magnitude:output amplitude
        <units>::=[VPP | VRMS | DBM]
    frequency:
        magnitude:output frequency
        <units>::=[Hz | kHz | MHz]
    output_state:{ON|OFF}
    """
    #設置輸入源訊號參數
    shape = 'SINusoid'
    frequency = {'magnitude': '1','unit': 'MHz'}
    amplitude = {'magnitude': '300E-3','unit': 'VPP'}
    output_state = "ON"
    amplitude_limit = 0.5

    #=======RF_150A_100D parameter======
    """
    Gain : 0~100
    Power state : { ON | OFF }
    """
    #設置射極功率放大器參數
    gain = 17
    power_state = 'ON'
    
    #====================Instrument Connect Test===========================
    #=====MSO64B connection===
    MSO_instrument_address = 'USB0::0x0699::0x0530::C048992::INSTR'
    mso = MSO_64B(MSO_instrument_address)
    
    #=====AFG_31101 connection=====
    AFG_instrument_address = 'USB0::0x0699::0x0359::C016504::INSTR'
    afg = AFG_31101(AFG_instrument_address)

    #=====RF_150A_100D connection=====
    RF_instrument_address = 'USB0::0x0547::0x1B58::0358752::INSTR'
    rf = RF_150A100D(RF_instrument_address)
    #若有其他儀器串接下去...
    
    #============================Auto Test================================= 
    # # TO DO: 這邊給你寫For迴圈自動測量的區域
    
    #=====MSO64B control=====
    mso.result_table()#新增measurement result table的介面
    
    #===新增測量項目==    
    for measurement in measurements:
        channel = measurement['channel']
        meas = measurement['measurement']
        mso.add_measurement(meas,channel)  

    set_cursor_range(afg, mso)
    
    #回傳math部分需要的公式
    for mso_math in mso_maths:
        math_num = mso_math['math_num']
        math_function = mso_math['math_function']
        mso.math_add(math_num, math_function)
            
    mso.set_gating_type() #調整measurement的gating type
    mso.measure_delta_B() #執行測量Bmax&Bmin
    
    for power in powers:
        num = power['Power_num']
        voltage = power['Voltage_Source']
        current = power['Current_Source']
        mso.power_function(num,voltage, current)

    for off_display in off_displays:
        off_channel = off_display['channel']
        off_math = off_display['math']
        mso.off_display(off_channel,off_math)

    #=====RF_150A_100D control=====
    gain_set = calculate_gain_set(gain)  # 計算增益設置值
    rf.set_gain(gain, gain_set)

    check_power_state(rf, power_state) #判斷放大power狀態，是開或關
    
    #=====AFG_31101 control=====
    afg.set_waveform(shape) #設置訊號類

    afg.set_frequency(frequency['magnitude'],frequency['unit']) #設置訊號頻率

    afg.set_amplitude(amplitude['magnitude'],amplitude['unit']) #設置訊號振幅

    check_output_state(afg, output_state) #判斷輸出狀態，是開或關

    check_amp_limit(afg, amplitude_limit)  # 檢查振幅是否超過限制
    
    #===Autoset scale & cursor range===
    
    mso.clear()
    wait_for_population(mso, threshold=10) #先等待pop到10再抓數值
    set_horizon_scale(afg, mso)
    
    # mso.clear()
    # wait_for_population(mso, threshold=10) #先等待pop到10再抓數值
    # set_vertical_scale(mso) #自動調整vertical scale
        
    #=====start measure & save data to Excel by pandas======
    #=====core parameter=====
    #記錄待測鐵心知各樣參數
    core_type = 'ML95S'
    core_effective_length = 0.0304 #unit:m
    core_effective_area = 1.68e-5 #unit:m^2
    core_effective_volume = 5.1265e-7 #unit:m^3
    turn = 3 #unit:turn
    
    #===開始量測===
    # 設定測量順序、目標 delta B 值及desekw Vref的角度
    sequences = [1, 2, 3, 4, 5]
    expect_deltaB = [0.02, 0.04, 0.06, 0.08, 0.1]
    deskew_vref = 1
    
    # 將這個值的字典先重製歸零
    vin_amplitude = {}
    power_gain ={}
    max_B = {}
    min_B = {}
    delta_B ={}
    Pcore_true_power = {}
    PL_true_power = {}
    max_B_deskew = {}
    min_B_deskew = {}
    delta_B_deskew ={}
    Pcore_true_power_deskew = {}
    PL_true_power_deskew = {}
    k_factor = {}
    Pcore = {}
    Pcore_cv = {}
    
    #===第一次測量===
    i = 1
    print(f"[第{i}次測量]")

    #===自動調整激勵源===
    target_deltaB = expect_deltaB[i-1] #從expect deltaB抓出當下對應預期要達到的deltaB
    amplitude, gain = adjust_rf_afg(mso, rf, afg, i, core_effective_area, turn, target_deltaB, gain, amplitude)

    vin_amplitude[i] = amplitude['magnitude']
    print(vin_amplitude)
    power_gain[i] = gain
    print(power_gain)

    #===開始抓值===
    mso.set_deskew_zero() #將channel1(Vref)的Deskew歸零

    wait_for_population(mso) #先等待pop到一定次數再抓數值
    
    acquire_measurement(mso, i, core_effective_area, turn, max_B, min_B, delta_B, Pcore_true_power, PL_true_power)
    
    set_vref_deskew(afg, mso, deskew_vref) #設定Vref deskew

    wait_for_population(mso) #先等待pop到一定次數再抓數值

    acquire_measurement(mso, i, core_effective_area, turn, max_B_deskew, min_B_deskew, delta_B_deskew, Pcore_true_power_deskew, PL_true_power_deskew, deskew=True)

    # 計算 k_factor, Pcore, Pcore_cv
    k_factor[i], Pcore[i], Pcore_cv[i] = calculate_core_parameters(i, Pcore_true_power, PL_true_power, Pcore_true_power_deskew, PL_true_power_deskew, core_effective_volume)
    
    #===第二次測量===
    i = 2
    print(f"[第{i}次測量]")

    #===自動調整激勵源===
    target_deltaB = expect_deltaB[i-1] #從expect deltaB抓出當下對應預期要達到的deltaB
    amplitude, gain = adjust_rf_afg(mso, rf, afg, i, core_effective_area, turn, target_deltaB, gain, amplitude)

    vin_amplitude[i] = amplitude['magnitude']
    print(vin_amplitude)
    power_gain[i] = gain
    print(power_gain)

    #===開始抓值==
    mso.set_deskew_zero() #將channel1(VR)的Deskew歸零
    
    wait_for_population(mso) #先等待pop到一定次數再抓數值
    
    acquire_measurement(mso, i, core_effective_area, turn, max_B, min_B, delta_B, Pcore_true_power, PL_true_power)

    set_vref_deskew(afg, mso, deskew_vref)

    mso.clear()
    wait_for_population(mso) #先等待pop到一定次數再抓數值

    acquire_measurement(mso, i, core_effective_area, turn, max_B_deskew, min_B_deskew, delta_B_deskew, Pcore_true_power_deskew, PL_true_power_deskew, deskew=True)

    # 計算 k_factor, Pcore, Pcore_cv
    k_factor[i], Pcore[i], Pcore_cv[i] = calculate_core_parameters(i, Pcore_true_power, PL_true_power, Pcore_true_power_deskew, PL_true_power_deskew, core_effective_volume)

    #===第三次測量===
    i = 3
    print(f"[第{i}次測量]")
    #===自動調整激勵源===
    target_deltaB = expect_deltaB[i-1] #從expect deltaB抓出當下對應預期要達到的deltaB
    amplitude, gain = adjust_rf_afg(mso, rf, afg, i, core_effective_area, turn, target_deltaB, gain, amplitude)

    vin_amplitude[i] = amplitude['magnitude']
    print(vin_amplitude)
    power_gain[i] = gain
    print(power_gain)
    
    #===開始抓值==
    mso.set_deskew_zero() #將channel1(VR)的Deskew歸零
    
    wait_for_population(mso) #先等待pop到一定次數再抓數值
    
    acquire_measurement(mso, i, core_effective_area, turn, max_B, min_B, delta_B, Pcore_true_power, PL_true_power)
    
    set_vref_deskew(afg, mso, deskew_vref)

    mso.clear()
    wait_for_population(mso) #先等待pop到一定次數再抓數值

    acquire_measurement(mso, i, core_effective_area, turn, max_B_deskew, min_B_deskew, delta_B_deskew, Pcore_true_power_deskew, PL_true_power_deskew, deskew=True)

    # 計算 k_factor, Pcore, Pcore_cv
    k_factor[i], Pcore[i], Pcore_cv[i] = calculate_core_parameters(i, Pcore_true_power, PL_true_power, Pcore_true_power_deskew, PL_true_power_deskew, core_effective_volume)

    #===第四次測量===
    i = 4
    print(f"[第{i}次測量]")
    #===自動調整激勵源===
    target_deltaB = expect_deltaB[i-1] #從expect deltaB抓出當下對應預期要達到的deltaB
    amplitude, gain = adjust_rf_afg(mso, rf, afg, i, core_effective_area, turn, target_deltaB, gain, amplitude)

    vin_amplitude[i] = amplitude['magnitude']
    print(vin_amplitude)
    power_gain[i] = gain
    print(power_gain)

    #===開始抓值==
    mso.set_deskew_zero() #將channel1(VR)的Deskew歸零
    
    wait_for_population(mso) #先等待pop到一定次數再抓數值
    
    acquire_measurement(mso, i, core_effective_area, turn, max_B, min_B, delta_B, Pcore_true_power, PL_true_power)
    
    set_vref_deskew(afg, mso, deskew_vref) #設定Vref deskew

    mso.clear()
    wait_for_population(mso) #先等待pop到一定次數再抓數值

    acquire_measurement(mso, i, core_effective_area, turn, max_B_deskew, min_B_deskew, delta_B_deskew, Pcore_true_power_deskew, PL_true_power_deskew, deskew=True)

    # 計算 k_factor, Pcore, Pcore_cv
    k_factor[i], Pcore[i], Pcore_cv[i] = calculate_core_parameters(i, Pcore_true_power, PL_true_power, Pcore_true_power_deskew, PL_true_power_deskew, core_effective_volume)

    #===第五次測量===
    i = 5
    print(f"[第{i}次測量]")
    
    #===自動調整激勵源===
    target_deltaB = expect_deltaB[i-1] #從expect deltaB抓出當下對應預期要達到的deltaB
    amplitude, gain = adjust_rf_afg(mso, rf, afg, i, core_effective_area, turn, target_deltaB, gain, amplitude)

    vin_amplitude[i] = amplitude['magnitude']
    print(vin_amplitude)
    power_gain[i] = gain
    print(power_gain)

    #===開始抓值==
    mso.set_deskew_zero() #將channel1(VR)的Deskew歸零
    
    wait_for_population(mso) #先等待pop到一定次數再抓數值
    
    acquire_measurement(mso, i, core_effective_area, turn, max_B, min_B, delta_B, Pcore_true_power, PL_true_power)

    set_vref_deskew(afg, mso, deskew_vref) #設定Vref deskew

    mso.clear()
    wait_for_population(mso) #先等待pop到一定次數再抓數值

    acquire_measurement(mso, i, core_effective_area, turn, max_B_deskew, min_B_deskew, delta_B_deskew, Pcore_true_power_deskew, PL_true_power_deskew, deskew=True)

    # 計算 k_factor, Pcore, Pcore_cv
    k_factor[i], Pcore[i], Pcore_cv[i] = calculate_core_parameters(i, Pcore_true_power, PL_true_power, Pcore_true_power_deskew, PL_true_power_deskew, core_effective_volume)

    #=====測量完畢，關閉儀器====
    print("已經測量完畢")
    afg.output_off() #資料儲存完畢，關閉AFG
    rf.power_off() #資料儲存完畢，關閉RF
    
    #=====將所有資料丟到data最後建立成DataFrame=====
    data = {
        ("core parameter","type of core"): [core_type] * len(sequences),
        ("core parameter","effective length of core"): [core_effective_length] * len(sequences),
        ("core parameter","effective area of core"): [core_effective_area] * len(sequences),
        ("core parameter","effective volume of core"): [core_effective_volume] * len(sequences),
        ("core parameter","turns of wire on the core"): [turn] * len(sequences),
        ("Test environment (R=10)", "Sequence"): sequences,
        ("Test environment (R=10)", "Vin(Vpp)"): [vin_amplitude[seq] for seq in sequences], #每次調整都要重新記錄
        ("Test environment (R=10)", "Gain"): [power_gain[seq] for seq in sequences], #每次調整都要記錄
        ("Test environment (R=10)", "deltaB(T)"): expect_deltaB,
        ("flux density (DS=0)", "Max(V)"): [v for seq, v in max_B['MEAS9']],
        ("flux density (DS=0)", "Min(V)"): [v for seq, v in min_B['MEAS10']],
        ("flux density (DS=0)", "delta B(T)"): [delta_B[seq] for seq in sequences],
        ("L(DS=0 degree)", "P(W)"): [v for seq, v in Pcore_true_power['1']],
        ("CL(DS=0 degree)", "P(W)"): [v for seq, v in PL_true_power['2']],
        ("flux density (DS=1)", "Max(V)"): [v for seq, v in max_B_deskew['MEAS9']],
        ("flux density (DS=1)", "Min(V)"): [v for seq, v in min_B_deskew['MEAS10']],
        ("flux density (DS=1)", "delta B(T)"): [delta_B_deskew[seq] for seq in sequences],
        ("L(DS=1 degree)", "P(W)"): [v for seq, v in Pcore_true_power_deskew['1']],
        ("CL(DS=1 degree)", "P(W)"): [v for seq, v in PL_true_power_deskew['2']],
        ("Final calculate","K"):[k_factor[seq] for seq in sequences],
        ("Final calculate","Real Pcore(W)"):[Pcore[seq] for seq in sequences],
        ("Final calculate","Real Pcv(W/m^3)"):[Pcore_cv[seq] for seq in sequences]
    }

    # 建立MultiIndex
    index = pd.MultiIndex.from_tuples(data.keys())

    #建立DataFrame
    df = pd.DataFrame(data) #用一代號表示整個二維資料
    df.columns = index

    #顯示DataFrame
    print(df) #列出來

    #儲存為Excel文件
    df.to_csv('instruments_measurement_results.csv', index=False) #將資料弄成一個CSV檔
    
    # ============================ Close Instrument =================================
    afg.close_instrument()
    mso.close_instrument()
    rf.close_instrument()
    
if __name__ == "__main__":
    main()
# Out:
# Connected to MSO64B.
# TEKTRONIX,MSO64B,C048992,CF:91.1CT FV:1.44.3.433
#
# Connected to AFG_31101.
# TEKTRONIX,AFG31101,C016504,SCPI:99.0 FV:1.6.1
#
# Connected to RF_150A100D.
# AR-RF/MICROWAVE-INST,150A100D,1.0
#
# add measurent result table
# set power gain be 17
# turn RF150A100D power on
# set excitation form be SINusoid
# set excitation frequency be 1MHz
# set excitation amplitude be 300E-3VPP
# turn AFG31101 output on
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 11
# Poplution採樣數量已超過 10
# the frequency of excitaton is 1000000.0
# set Horizontal Scale to 4e-07s/div
# [第1次測量]
# The maximum B value is 5.222689765105315e-07 T
# The minimum B value is -4.001954100171393e-07 T
# The delta of B is 0.018302864812056965 T
# delta B 小於50 mT
# 實際 delta B: 0.018302864812056965 與預期 delta B: 0.03 差了 0.011697135187943034T
# delta B 誤差大於 0.01
# set excitation amplitude be 303.0E-3VPP
# AFG 振幅已設置增加 3V，設為303.0E-3 VPP
# 增益增加 10
# set power gain be 27
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 1.5621710320243
# set CH1 vertical scale be 0.22316729028918572
# CH1 no clipping, auto set vertical scale to 0.22316729028918572
# clipping state:0.0
# amplitude of CH2 is 8.1744795894867
# set CH2 vertical scale be 1.1677827984981
# CH2 no clipping, auto set vertical scale to 1.1677827984981
# clipping state:0.0
# amplitude of CH3 is 2.5127178455205
# set CH3 vertical scale be 0.3589596922172143
# CH3 no clipping, auto set vertical scale to 0.3589596922172143
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 7
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '303.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 27
# The maximum B value is 6.900704576651151e-07 T
# The minimum B value is -5.74470959691098e-07 T
# The delta of B is 0.025090107487226454 T
# 調整後的 delta B: 0.025090107487226454
# delta B 小於50 mT
# 實際 delta B: 0.025090107487226454 與預期 delta B: 0.03 差了 0.004909892512773545T
# delta B 誤差介於 0.003 ~ 0.006
# 增益增加 3
# set power gain be 30
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 12
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 1.658226736626
# set CH1 vertical scale be 0.23688953380371428
# CH1 no clipping, auto set vertical scale to 0.23688953380371428
# clipping state:0.0
# amplitude of CH2 is 8.9046485719125
# set CH2 vertical scale be 1.2720926531303571
# CH2 no clipping, auto set vertical scale to 1.2720926531303571
# clipping state:0.0
# amplitude of CH3 is 2.7332452142768
# set CH3 vertical scale be 0.39046360203954283
# CH3 no clipping, auto set vertical scale to 0.39046360203954283
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '303.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 30
# The maximum B value is 7.748039428810848e-07 T
# The minimum B value is -6.482981234512408e-07 T
# The delta of B is 0.02823615210976837 T
# 調整後的 delta B: 0.02823615210976837
# delta B 小於50 mT
# 實際 delta B: 0.02823615210976837 與預期 delta B: 0.03 差了 0.0017638478902316304T
# delta B 誤差介於 0.0005 ~ 0.003
# 增益增加 1
# set power gain be 31
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 13
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 1.7542424855984
# set CH1 vertical scale be 0.2506060693712
# CH1 no clipping, auto set vertical scale to 0.2506060693712
# clipping state:0.0
# amplitude of CH2 is 9.1922837699587
# set CH2 vertical scale be 1.3131833957083856
# CH2 no clipping, auto set vertical scale to 1.3131833957083856
# clipping state:0.0
# amplitude of CH3 is 2.8049444603
# set CH3 vertical scale be 0.4007063514714286
# CH3 no clipping, auto set vertical scale to 0.4007063514714286
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '303.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 31
# The maximum B value is 7.984772688966283e-07 T
# The minimum B value is -6.675246822851477e-07 T
# The delta of B is 0.02908734030122572 T
# 調整後的 delta B: 0.02908734030122572
# delta B 小於50 mT
# 實際 delta B: 0.02908734030122572 與預期 delta B: 0.03 差了 0.0009126596987742777T
# delta B 誤差介於 0.0005 ~ 0.003
# 增益增加 1
# set power gain be 32
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 1.8062994994974
# set CH1 vertical scale be 0.25804278564248573
# CH1 no clipping, auto set vertical scale to 0.25804278564248573
# clipping state:0.0
# amplitude of CH2 is 9.46257167246
# set CH2 vertical scale be 1.3517959532085713
# CH2 no clipping, auto set vertical scale to 1.3517959532085713
# clipping state:0.0
# amplitude of CH3 is 2.8795187789837
# set CH3 vertical scale be 0.41135982556909995
# CH3 no clipping, auto set vertical scale to 0.41135982556909995
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 7
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '303.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 32
# The maximum B value is 8.226631322827416e-07 T
# The minimum B value is -6.888734560561716e-07 T
# The delta of B is 0.02999080532418479 T
# 調整後的 delta B: 0.02999080532418479
# delta B已達預期的0.03
# {1: '303.0E-3'}
# {1: 32}
# CH1 deskew set to 0
# Current population: 11
# Current population: 1
# Current population: 1
# Current population: 9
# Current population: 35
# Current population: 60
# Current population: 86
# Current population: 112
# Poplution採樣數量已超過 100
# The maximum B value is 8.098038369398961e-07 T
# The minimum B value is -7.024711030841893e-07 T
# The delta of B is 0.03000545515920805 T
# max_B: {'MEAS9': [(1, 8.098038369398961e-07)]}
# min_B: {'MEAS10': [(1, -7.024711030841893e-07)]}
# delta_B: {1: 0.03000545515920805}
# The true power of 1 is 0.0072606751857821 W
# The true power of 2 is 0.0002551479852057004 W
# Pcore true power: {'1': [(1, 0.0072606751857821)]}
# PL true power: {'2': [(1, 0.0002551479852057004)]}
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# Current population: 119
# Poplution採樣數量已超過 100
# The maximum B value is 8.098084186567881e-07 T
# The minimum B value is -7.024761573632555e-07 T
# The delta of B is 0.030005646349604044 T
# max_B_deskew: {'MEAS9': [(1, 8.098084186567881e-07)]}
# min_B_deskew: {'MEAS10': [(1, -7.024761573632555e-07)]}
# delta_B_deskew: {1: 0.030005646349604044}
# The true power of 1 is 0.010851584839588 W
# The true power of 2 is 0.0014247429025361 W
# Pcore true power_deskew: {'1': [(1, 0.010851584839588)]}
# PL true power_deskew: {'2': [(1, 0.0014247429025361)]}
# k factor:0.32570992592107684
# Core Real power loss:0.00717757095442184
# Every volume of Core Real power loss:14000.918666579226
# [第2次測量]
# The maximum B value is 8.238947657446261e-07 T
# The minimum B value is -6.899225581946666e-07 T
# The delta of B is 0.03003605801466851 T
# delta B 小於50 mT
# 實際 delta B: 0.03003605801466851 與預期 delta B: 0.05 差了 0.019963941985331492T
# delta B 誤差大於 0.01
# set excitation amplitude be 306.0E-3VPP
# AFG 振幅已設置增加 3V，設為306.0E-3 VPP
# 增益增加 10
# set power gain be 42
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 10
# Poplution採樣數量已超過 5
# clipping state:1.0
# set CH1 vertical scale be 0.298043
# CH1 is clipping, auto set vertical scale from 0.258043 to 0.298043
# clipping state:0.0
# amplitude of CH1 is 2.460922675038
# set CH1 vertical scale be 0.3515603821482857
# CH1 no clipping, auto set vertical scale to 0.3515603821482857
# clipping state:1.0
# set CH2 vertical scale be 1.3918
# CH2 is clipping, auto set vertical scale from 1.3518 to 1.3918
# clipping state:0.0
# amplitude of CH2 is 13.0886390580581
# set CH2 vertical scale be 1.8698055797225857
# CH2 no clipping, auto set vertical scale to 1.8698055797225857
# clipping state:1.0
# set CH3 vertical scale be 0.45136
# CH3 is clipping, auto set vertical scale from 0.41136 to 0.45136
# clipping state:0.0
# amplitude of CH3 is 3.94543873994
# set CH3 vertical scale be 0.5636341057057143
# CH3 no clipping, auto set vertical scale to 0.5636341057057143
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '306.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 42
# The maximum B value is 1.1396617891377e-06 T
# The minimum B value is -9.502749031121816e-07 T
# The delta of B is 0.041466997862100834 T
# 調整後的 delta B: 0.041466997862100834
# delta B 小於50 mT
# 實際 delta B: 0.041466997862100834 與預期 delta B: 0.05 差了 0.008533002137899169T
# delta B 誤差介於 0.006 ~ 0.01
# 增益增加 5
# set power gain be 47
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 10
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 2.9080508504276
# set CH1 vertical scale be 0.41543583577537146
# CH1 no clipping, auto set vertical scale to 0.41543583577537146
# clipping state:0.0
# amplitude of CH2 is 15.5557003469469
# set CH2 vertical scale be 2.2222429067067
# CH2 no clipping, auto set vertical scale to 2.2222429067067
# clipping state:0.0
# amplitude of CH3 is 4.6644870935473
# set CH3 vertical scale be 0.6663552990781857
# CH3 no clipping, auto set vertical scale to 0.6663552990781857
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '306.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 47
# The maximum B value is 1.3541896208835e-06 T
# The minimum B value is -1.1203881184782e-06 T
# The delta of B is 0.049098764669875006 T
# 調整後的 delta B: 0.049098764669875006
# delta B 小於50 mT
# 實際 delta B: 0.049098764669875006 與預期 delta B: 0.05 差了 0.000901235330124997T
# delta B 誤差介於 0.0005 ~ 0.003
# 增益增加 1
# set power gain be 48
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 9
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 2.9974801846465
# set CH1 vertical scale be 0.42821145494949997
# CH1 no clipping, auto set vertical scale to 0.42821145494949997
# clipping state:0.0
# amplitude of CH2 is 16.0542264041341
# set CH2 vertical scale be 2.2934609148762997
# CH2 no clipping, auto set vertical scale to 2.2934609148762997
# clipping state:0.0
# amplitude of CH3 is 4.831766410681
# set CH3 vertical scale be 0.6902523443830001
# CH3 no clipping, auto set vertical scale to 0.6902523443830001
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '306.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 48
# The maximum B value is 1.4016348409819e-06 T
# The minimum B value is -1.1617363371544e-06 T
# The delta of B is 0.05086053924873612 T
# 調整後的 delta B: 0.05086053924873612
# delta B 大於50 mT
# 實際 delta B: 0.05086053924873612 與預期 delta B: 0.05 差了 -0.0008605392487361155T
# 實際deltaB大於預期deltaB 0.0005
# set excitation amplitude be 304.0E-3VPP
# AFG 振幅已設置為 304.0E-3 VPP
# 增益減少 1
# set power gain be 47
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 9
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 2.877544006324
# set CH1 vertical scale be 0.4110777151891428
# CH1 no clipping, auto set vertical scale to 0.4110777151891428
# clipping state:0.0
# amplitude of CH2 is 15.4436288799493
# set CH2 vertical scale be 2.206232697135614
# CH2 no clipping, auto set vertical scale to 2.206232697135614
# clipping state:0.0
# amplitude of CH3 is 4.6696212832583
# set CH3 vertical scale be 0.6670887547511857
# CH3 no clipping, auto set vertical scale to 0.6670887547511857
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '304.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 47
# The maximum B value is 1.3432631425935e-06 T
# The minimum B value is -1.1119917417091e-06 T
# The delta of B is 0.048715374688543665 T
# 調整後的 delta B: 0.048715374688543665
# delta B 小於50 mT
# 實際 delta B: 0.048715374688543665 與預期 delta B: 0.05 差了 0.0012846253114563375T
# delta B 誤差介於 0.0005 ~ 0.003
# 增益增加 1
# set power gain be 48
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 2.982524622824
# set CH1 vertical scale be 0.4260749461177143
# CH1 no clipping, auto set vertical scale to 0.4260749461177143
# clipping state:0.0
# amplitude of CH2 is 15.991964925495
# set CH2 vertical scale be 2.284566417927857
# CH2 no clipping, auto set vertical scale to 2.284566417927857
# clipping state:0.0
# amplitude of CH3 is 4.8033079027027
# set CH3 vertical scale be 0.6861868432432429
# CH3 no clipping, auto set vertical scale to 0.6861868432432429
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '304.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 48
# The maximum B value is 1.3946421688615e-06 T
# The minimum B value is -1.1533643878971e-06 T
# The delta of B is 0.050555685649972225 T
# 調整後的 delta B: 0.050555685649972225
# delta B 大於50 mT
# 實際 delta B: 0.050555685649972225 與預期 delta B: 0.05 差了 -0.0005556856499722221T
# 實際deltaB大於預期deltaB 0.0005
# set excitation amplitude be 302.0E-3VPP
# AFG 振幅已設置為 302.0E-3 VPP
# 增益減少 1
# set power gain be 47
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 11
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 2.8603381925456
# set CH1 vertical scale be 0.40861974179222854
# CH1 no clipping, auto set vertical scale to 0.40861974179222854
# clipping state:0.0
# amplitude of CH2 is 15.3182226333605
# set CH2 vertical scale be 2.1883175190515
# CH2 no clipping, auto set vertical scale to 2.1883175190515
# clipping state:0.0
# amplitude of CH3 is 4.6271040645707
# set CH3 vertical scale be 0.6610148663672428
# CH3 no clipping, auto set vertical scale to 0.6610148663672428
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '302.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 47
# The maximum B value is 1.3349269415307e-06 T
# The minimum B value is -1.1114595508843e-06 T
# The delta of B is 0.04853941453204366 T
# 調整後的 delta B: 0.04853941453204366
# delta B 小於50 mT
# 實際 delta B: 0.04853941453204366 與預期 delta B: 0.05 差了 0.0014605854679563407T
# delta B 誤差介於 0.0005 ~ 0.003
# 增益增加 1
# set power gain be 48
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 10
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 2.960243728677
# set CH1 vertical scale be 0.4228919612395714
# CH1 no clipping, auto set vertical scale to 0.4228919612395714
# clipping state:0.0
# amplitude of CH2 is 15.9245806602402
# set CH2 vertical scale be 2.2749400943200286
# CH2 no clipping, auto set vertical scale to 2.2749400943200286
# clipping state:0.0
# amplitude of CH3 is 4.7665592526675
# set CH3 vertical scale be 0.6809370360953572
# CH3 no clipping, auto set vertical scale to 0.6809370360953572
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 9
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '302.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 48
# The maximum B value is 1.3878204299544e-06 T
# The minimum B value is -1.1483528624012e-06 T
# The delta of B is 0.050320898657849215 T
# 調整後的 delta B: 0.050320898657849215
# delta B已達預期的0.05
# {1: '303.0E-3', 2: '302.0E-3'}
# {1: 32, 2: 48}
# CH1 deskew set to 0
# Current population: 13
# Current population: 1
# Current population: 1
# Current population: 11
# Current population: 37
# Current population: 63
# Current population: 90
# Current population: 115
# Poplution採樣數量已超過 100
# The maximum B value is 1.3661220217055e-06 T
# The minimum B value is -1.17017066651e-06 T
# The delta of B is 0.05032326762332342 T
# max_B: {'MEAS9': [(1, 8.098038369398961e-07), (2, 1.3661220217055e-06)]}
# min_B: {'MEAS10': [(1, -7.024711030841893e-07), (2, -1.17017066651e-06)]}
# delta_B: {1: 0.03000545515920805, 2: 0.05032326762332342}
# The true power of 1 is 0.0281090219188544 W
# The true power of 2 is 0.0020021115812034 W
# Pcore true power: {'1': [(1, 0.0072606751857821), (2, 0.0281090219188544)]}
# PL true power: {'2': [(1, 0.0002551479852057004), (2, 0.0020021115812034)]}
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 11
# Current population: 37
# Current population: 62
# Current population: 89
# Current population: 114
# Poplution採樣數量已超過 100
# The maximum B value is 1.38929803035e-06 T
# The minimum B value is -1.1469104166558e-06 T
# The delta of B is 0.05032159617075001 T
# max_B_deskew: {'MEAS9': [(1, 8.098084186567881e-07), (2, 1.38929803035e-06)]}
# min_B_deskew: {'MEAS10': [(1, -7.024761573632555e-07), (2, -1.1469104166558e-06)]}
# delta_B_deskew: {1: 0.030005646349604044, 2: 0.05032159617075001}
# The true power of 1 is 0.0384511334087105 W
# The true power of 2 is 0.0051086046099416 W
# Pcore true power_deskew: {'1': [(1, 0.010851584839588), (2, 0.0384511334087105)]}
# PL true power_deskew: {'2': [(1, 0.0014247429025361), (2, 0.0051086046099416)]}
# k factor:0.3003731908890322
# Core Real power loss:0.02750764127469245
# Every volume of Core Real power loss:53657.74168476046
# [第3次測量]
# The maximum B value is 1.3893191526451e-06 T
# The minimum B value is -1.146909097353e-06 T
# The delta of B is 0.0503219890872639 T
# delta B 大於50 mT
# 實際 delta B: 0.0503219890872639 與預期 delta B: 0.07 差了 0.019678010912736105T
# delta B 誤差大於 0.01
# set excitation amplitude be 304.0E-3VPP
# AFG 振幅已設置增加 2V，設為304.0E-3 VPP
# 增益增加 5
# set power gain be 53
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 3.5485723371278
# set CH1 vertical scale be 0.5069389053039715
# CH1 no clipping, auto set vertical scale to 0.5069389053039715
# clipping state:0.0
# amplitude of CH2 is 19.236751523696
# set CH2 vertical scale be 2.748107360528
# CH2 no clipping, auto set vertical scale to 2.748107360528
# clipping state:0.0
# amplitude of CH3 is 5.7423942482348
# set CH3 vertical scale be 0.8203420354621143
# CH3 no clipping, auto set vertical scale to 0.8203420354621143
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '304.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 53
# The maximum B value is 1.6938559055133e-06 T
# The minimum B value is -1.3820384538121e-06 T
# The delta of B is 0.06102964998661509 T
# 調整後的 delta B: 0.06102964998661509
# delta B 大於50 mT
# 實際 delta B: 0.06102964998661509 與預期 delta B: 0.07 差了 0.00897035001338492T
# delta B 誤差介於 0.006 ~ 0.01
# 增益增加 3
# set power gain be 56
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 3.95212185885
# set CH1 vertical scale be 0.5645888369785714
# CH1 no clipping, auto set vertical scale to 0.5645888369785714
# clipping state:0.0
# amplitude of CH2 is 21.6231594545596
# set CH2 vertical scale be 3.0890227792228004
# CH2 no clipping, auto set vertical scale to 3.0890227792228004
# clipping state:0.0
# amplitude of CH3 is 6.3627876454261
# set CH3 vertical scale be 0.9089696636323
# CH3 no clipping, auto set vertical scale to 0.9089696636323
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 7
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '304.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 56
# The maximum B value is 1.899142688444e-06 T
# The minimum B value is -1.5466353918075e-06 T
# The delta of B is 0.06836861270340279 T
# 調整後的 delta B: 0.06836861270340279
# delta B 大於50 mT
# 實際 delta B: 0.06836861270340279 與預期 delta B: 0.07 差了 0.001631387296597217T
# delta B 誤差介於 0.001 ~ 0.003
# 增益增加 1
# set power gain be 57
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 12
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 4.0888138464693
# set CH1 vertical scale be 0.5841162637813285
# CH1 no clipping, auto set vertical scale to 0.5841162637813285
# clipping state:0.0
# amplitude of CH2 is 22.4648081614701
# set CH2 vertical scale be 3.209258308781443
# CH2 no clipping, auto set vertical scale to 3.209258308781443
# clipping state:0.0
# amplitude of CH3 is 6.5853921126126
# set CH3 vertical scale be 0.9407703018018
# CH3 no clipping, auto set vertical scale to 0.9407703018018
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '304.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 57
# The maximum B value is 1.9754435622114e-06 T
# The minimum B value is -1.6074245991149e-06 T
# The delta of B is 0.07108865399456946 T
# 調整後的 delta B: 0.07108865399456946
# delta B 大於50 mT
# 實際 delta B: 0.07108865399456946 與預期 delta B: 0.07 差了 -0.0010886539945694496T
# 實際deltaB大於預期deltaB 0.001
# set excitation amplitude be 302.0E-3VPP
# AFG 振幅已設置為 302.0E-3 VPP
# 增益減少 1
# set power gain be 56
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 11
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 3.9134217784837
# set CH1 vertical scale be 0.5590602540691
# CH1 no clipping, auto set vertical scale to 0.5590602540691
# clipping state:0.0
# amplitude of CH2 is 21.5206418546853
# set CH2 vertical scale be 3.074377407812186
# CH2 no clipping, auto set vertical scale to 3.074377407812186
# clipping state:0.0
# amplitude of CH3 is 6.3186032192145
# set CH3 vertical scale be 0.9026576027449286
# CH3 no clipping, auto set vertical scale to 0.9026576027449286
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 9
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '302.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 56
# The maximum B value is 1.8870580081259e-06 T
# The minimum B value is -1.5334884665208e-06 T
# The delta of B is 0.06786798560806945 T
# 調整後的 delta B: 0.06786798560806945
# delta B 大於50 mT
# 實際 delta B: 0.06786798560806945 與預期 delta B: 0.07 差了 0.002132014391930559T
# delta B 誤差介於 0.001 ~ 0.003
# 增益增加 1
# set power gain be 57
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 9
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 4.0662587993722
# set CH1 vertical scale be 0.5808941141960285
# CH1 no clipping, auto set vertical scale to 0.5808941141960285
# clipping state:0.0
# amplitude of CH2 is 22.3171765364464
# set CH2 vertical scale be 3.1881680766352
# CH2 no clipping, auto set vertical scale to 3.1881680766352
# clipping state:0.0
# amplitude of CH3 is 6.5715121751736
# set CH3 vertical scale be 0.9387874535962286
# CH3 no clipping, auto set vertical scale to 0.9387874535962286
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '302.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 57
# The maximum B value is 1.9627855433808e-06 T
# The minimum B value is -1.5981003343768e-06 T
# The delta of B is 0.07065249757455558 T
# 調整後的 delta B: 0.07065249757455558
# delta B已達預期的0.07
# {1: '303.0E-3', 2: '302.0E-3', 3: '302.0E-3'}
# {1: 32, 2: 48, 3: 57}
# CH1 deskew set to 0
# Current population: 12
# Current population: 1
# Current population: 1
# Current population: 9
# Current population: 34
# Current population: 60
# Current population: 86
# Current population: 112
# Poplution採樣數量已超過 100
# The maximum B value is 1.932564397565e-06 T
# The minimum B value is -1.6300709518946e-06 T
# The delta of B is 0.0706872093146746 T
# max_B: {'MEAS9': [(1, 8.098038369398961e-07), (2, 1.3661220217055e-06), (3, 1.932564397565e-06)]}
# min_B: {'MEAS10': [(1, -7.024711030841893e-07), (2, -1.17017066651e-06), (3, -1.6300709518946e-06)]}
# delta_B: {1: 0.03000545515920805, 2: 0.05032326762332342, 3: 0.0706872093146746}
# The true power of 1 is 0.0643784665427145 W
# The true power of 2 is 0.002261103799028 W
# Pcore true power: {'1': [(1, 0.0072606751857821), (2, 0.0281090219188544), (3, 0.0643784665427145)]}
# PL true power: {'2': [(1, 0.0002551479852057004), (2, 0.0020021115812034), (3, 0.002261103799028)]}
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 12
# Current population: 37
# Current population: 64
# Current population: 90
# Current population: 116
# Poplution採樣數量已超過 100
# The maximum B value is 1.9630424738917e-06 T
# The minimum B value is -1.6005909142961e-06 T
# The delta of B is 0.07070701167039287 T
# max_B_deskew: {'MEAS9': [(1, 8.098084186567881e-07), (2, 1.38929803035e-06), (3, 1.9630424738917e-06)]}
# min_B_deskew: {'MEAS10': [(1, -7.024761573632555e-07), (2, -1.1469104166558e-06), (3, -1.6005909142961e-06)]}
# delta_B_deskew: {1: 0.030005646349604044, 2: 0.05032159617075001, 3: 0.07070701167039287}
# The true power of 1 is 0.0843195725997381 W
# The true power of 2 is 0.0081270379276053 W
# Pcore true power_deskew: {'1': [(1, 0.010851584839588), (2, 0.0384511334087105), (3, 0.0843195725997381)]}
# PL true power_deskew: {'2': [(1, 0.0014247429025361), (2, 0.0051086046099416), (3, 0.0081270379276053)]}
# k factor:0.2941629271617667
# Core Real power loss:0.06371333363057582
# Every volume of Core Real power loss:124282.32445250332
# [第4次測量]
# The maximum B value is 1.9630715034644e-06 T
# The minimum B value is -1.6005656349438e-06 T
# The delta of B is 0.07070708607952779 T
# delta B 大於50 mT
# 實際 delta B: 0.07070708607952779 與預期 delta B: 0.09 差了 0.019292913920472207T
# delta B 誤差大於 0.01
# set excitation amplitude be 304.0E-3VPP
# AFG 振幅已設置增加 2V，設為304.0E-3 VPP
# 增益增加 5
# set power gain be 62
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 6
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 4.8964809066494
# set CH1 vertical scale be 0.6994972723784858
# CH1 no clipping, auto set vertical scale to 0.6994972723784858
# clipping state:0.0
# amplitude of CH2 is 27.4293522265203
# set CH2 vertical scale be 3.9184788895029
# CH2 no clipping, auto set vertical scale to 3.9184788895029
# clipping state:0.0
# amplitude of CH3 is 7.94122677874
# set CH3 vertical scale be 1.1344609683914286
# CH3 no clipping, auto set vertical scale to 1.1344609683914286
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 7
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '304.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 62
# The maximum B value is 2.4358390646739e-06 T
# The minimum B value is -1.93249057803e-06 T
# The delta of B is 0.08667320719650598 T
# 調整後的 delta B: 0.08667320719650598
# delta B 大於50 mT
# 實際 delta B: 0.08667320719650598 與預期 delta B: 0.09 差了 0.0033267928034940164T
# delta B 誤差介於 0.003 ~ 0.006
# 增益增加 2
# set power gain be 64
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 10
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 5.2691218173134
# set CH1 vertical scale be 0.7527316881876286
# CH1 no clipping, auto set vertical scale to 0.7527316881876286
# clipping state:0.0
# amplitude of CH2 is 29.7023012610823
# set CH2 vertical scale be 4.2431858944403285
# CH2 no clipping, auto set vertical scale to 4.2431858944403285
# clipping state:0.0
# amplitude of CH3 is 8.5155824814588
# set CH3 vertical scale be 1.216511783065543
# CH3 no clipping, auto set vertical scale to 1.216511783065543
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '304.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 64
# The maximum B value is 2.6501721777095e-06 T
# The minimum B value is -2.09175403951e-06 T
# The delta of B is 0.09408583764324406 T
# 調整後的 delta B: 0.09408583764324406
# delta B 大於50 mT
# 實際 delta B: 0.09408583764324406 與預期 delta B: 0.09 差了 -0.004085837643244064T
# 實際deltaB大於預期deltaB 0.001
# set excitation amplitude be 302.0E-3VPP
# AFG 振幅已設置為 302.0E-3 VPP
# 增益減少 1
# set power gain be 63
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 12
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 5.0280889850345
# set CH1 vertical scale be 0.7182984264335
# CH1 no clipping, auto set vertical scale to 0.7182984264335
# clipping state:0.0
# amplitude of CH2 is 28.3455894673386
# set CH2 vertical scale be 4.049369923905514
# CH2 no clipping, auto set vertical scale to 4.049369923905514
# clipping state:0.0
# amplitude of CH3 is 8.1587914724324
# set CH3 vertical scale be 1.1655416389189142
# CH3 no clipping, auto set vertical scale to 1.1655416389189142
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 7
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '302.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 63
# The maximum B value is 2.52569415693e-06 T
# The minimum B value is -1.99763682455e-06 T
# The delta of B is 0.08974863058492065 T
# 調整後的 delta B: 0.08974863058492065
# delta B已達預期的0.09
# {1: '303.0E-3', 2: '302.0E-3', 3: '302.0E-3', 4: '302.0E-3'}
# {1: 32, 2: 48, 3: 57, 4: 63}
# CH1 deskew set to 0
# Current population: 11
# Current population: 1
# Current population: 1
# Current population: 9
# Current population: 35
# Current population: 61
# Current population: 86
# Current population: 112
# Poplution採樣數量已超過 100
# The maximum B value is 2.4865986551556e-06 T
# The minimum B value is -2.0353284353163e-06 T
# The delta of B is 0.08972077560460119 T
# max_B: {'MEAS9': [(1, 8.098038369398961e-07), (2, 1.3661220217055e-06), (3, 1.932564397565e-06), (4, 2.4865986551556e-06)]}
# min_B: {'MEAS10': [(1, -7.024711030841893e-07), (2, -1.17017066651e-06), (3, -1.6300709518946e-06), (4, -2.0353284353163e-06)]}
# delta_B: {1: 0.03000545515920805, 2: 0.05032326762332342, 3: 0.0706872093146746, 4: 0.08972077560460119}
# The true power of 1 is 0.1296132168231388 W
# The true power of 2 is 0.0053982964365783 W
# Pcore true power: {'1': [(1, 0.0072606751857821), (2, 0.0281090219188544), (3, 0.0643784665427145), (4, 0.1296132168231388)]}
# PL true power: {'2': [(1, 0.0002551479852057004), (2, 0.0020021115812034), (3, 0.002261103799028), (4, 0.0053982964365783)]}
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 13
# Current population: 38
# Current population: 64
# Current population: 90
# Current population: 115
# Poplution採樣數量已超過 100
# The maximum B value is 2.5301102486365e-06 T
# The minimum B value is -1.9979458117718e-06 T
# The delta of B is 0.08984238215095836 T
# max_B_deskew: {'MEAS9': [(1, 8.098084186567881e-07), (2, 1.38929803035e-06), (3, 1.9630424738917e-06), (4, 2.5301102486365e-06)]}
# min_B_deskew: {'MEAS10': [(1, -7.024761573632555e-07), (2, -1.1469104166558e-06), (3, -1.6005909142961e-06), (4, -1.9979458117718e-06)]}
# delta_B_deskew: {1: 0.030005646349604044, 2: 0.05032159617075001, 3: 0.07070701167039287, 4: 0.08984238215095836}
# The true power of 1 is 0.1608278921088942 W
# The true power of 2 is 0.014349886905517 W
# Pcore true power_deskew: {'1': [(1, 0.010851584839588), (2, 0.0384511334087105), (3, 0.0843195725997381), (4, 0.1608278921088942)]}
# PL true power_deskew: {'2': [(1, 0.0014247429025361), (2, 0.0051086046099416), (3, 0.0081270379276053), (4, 0.014349886905517)]}
# k factor:0.28677506291483673
# Core Real power loss:0.12806512002290613
# Every volume of Core Real power loss:249810.0458849237
# [第5次測量]
# The maximum B value is 2.5301145579152e-06 T
# The minimum B value is -1.9979944069243e-06 T
# The delta of B is 0.08984343184205358 T
# delta B 大於50 mT
# 實際 delta B: 0.08984343184205358 與預期 delta B: 0.11 差了 0.02015656815794642T
# delta B 誤差大於 0.01
# set excitation amplitude be 304.0E-3VPP
# AFG 振幅已設置增加 2V，設為304.0E-3 VPP
# 增益增加 5
# set power gain be 68
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 6.1121120108124
# set CH1 vertical scale be 0.8731588586874857
# CH1 no clipping, auto set vertical scale to 0.8731588586874857
# clipping state:0.0
# amplitude of CH2 is 35.2023977972128
# set CH2 vertical scale be 5.028913971030399
# CH2 no clipping, auto set vertical scale to 5.028913971030399
# clipping state:0.0
# amplitude of CH3 is 9.83530628768
# set CH3 vertical scale be 1.4050437553828572
# CH3 no clipping, auto set vertical scale to 1.4050437553828572
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '304.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 68
# The maximum B value is 3.1894617728136e-06 T
# The minimum B value is -2.4418880684607e-06 T
# The delta of B is 0.1117331317713155 T
# 調整後的 delta B: 0.1117331317713155
# delta B 大於50 mT
# 實際 delta B: 0.1117331317713155 與預期 delta B: 0.11 差了 -0.0017331317713154964T
# 實際deltaB大於預期deltaB 0.001
# set excitation amplitude be 302.0E-3VPP
# AFG 振幅已設置為 302.0E-3 VPP
# 增益減少 1
# set power gain be 67
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 9
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 5.82140638525
# set CH1 vertical scale be 0.831629483607143
# CH1 no clipping, auto set vertical scale to 0.831629483607143
# clipping state:0.0
# amplitude of CH2 is 33.6314161092743
# set CH2 vertical scale be 4.804488015610614
# CH2 no clipping, auto set vertical scale to 4.804488015610614
# clipping state:0.0
# amplitude of CH3 is 9.4011209233784
# set CH3 vertical scale be 1.3430172747683429
# CH3 no clipping, auto set vertical scale to 1.3430172747683429
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 7
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '302.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 67
# The maximum B value is 3.0337619461664e-06 T
# The minimum B value is -2.3274856459921e-06 T
# The delta of B is 0.10637396016187502 T
# 調整後的 delta B: 0.10637396016187502
# delta B 大於50 mT
# 實際 delta B: 0.10637396016187502 與預期 delta B: 0.11 差了 0.0036260398381249836T
# delta B 誤差介於 0.003 ~ 0.006
# 增益增加 2
# set power gain be 69
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 12
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 6.2772115950756
# set CH1 vertical scale be 0.8967445135822285
# CH1 no clipping, auto set vertical scale to 0.8967445135822285
# clipping state:0.0
# amplitude of CH2 is 36.6786844564189
# set CH2 vertical scale be 5.2398120652027
# CH2 no clipping, auto set vertical scale to 5.2398120652027
# clipping state:0.0
# amplitude of CH3 is 10.0967302187575
# set CH3 vertical scale be 1.4423900312510713
# CH3 no clipping, auto set vertical scale to 1.4423900312510713
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '302.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 69
# The maximum B value is 3.32383635282e-06 T
# The minimum B value is -2.5171708936493e-06 T
# The delta of B is 0.11589300092200992 T
# 調整後的 delta B: 0.11589300092200992
# delta B 大於50 mT
# 實際 delta B: 0.11589300092200992 與預期 delta B: 0.11 差了 -0.005893000922009922T
# 實際deltaB大於預期deltaB 0.001
# set excitation amplitude be 300.0E-3VPP
# AFG 振幅已設置為 300.0E-3 VPP
# 增益減少 1
# set power gain be 68
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 12
# Poplution採樣數量已超過 5
# clipping state:0.0
# amplitude of CH1 is 5.9846588972438
# set CH1 vertical scale be 0.8549512710348285
# CH1 no clipping, auto set vertical scale to 0.8549512710348285
# clipping state:0.0
# amplitude of CH2 is 34.7225399705706
# set CH2 vertical scale be 4.960362852938657
# CH2 no clipping, auto set vertical scale to 4.960362852938657
# clipping state:0.0
# amplitude of CH3 is 9.7110199432479
# set CH3 vertical scale be 1.3872885633211285
# CH3 no clipping, auto set vertical scale to 1.3872885633211285
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 8
# Poplution採樣數量已超過 5
# 設定 Vin amplitude為:{'magnitude': '300.0E-3', 'unit': 'VPP'}
# 設定 RF Gain為: 68
# The maximum B value is 3.15529831596e-06 T
# The minimum B value is -2.410761857795e-06 T
# The delta of B is 0.11043770186021828 T
# 調整後的 delta B: 0.11043770186021828
# delta B已達預期的0.11
# {1: '303.0E-3', 2: '302.0E-3', 3: '302.0E-3', 4: '302.0E-3', 5: '300.0E-3'}
# {1: 32, 2: 48, 3: 57, 4: 63, 5: 68}
# CH1 deskew set to 0
# Current population: 11
# Current population: 1
# Current population: 1
# Current population: 10
# Current population: 36
# Current population: 62
# Current population: 87
# Current population: 112
# Poplution採樣數量已超過 100
# The maximum B value is 3.105969474834e-06 T
# The minimum B value is -2.4610883409032e-06 T
# The delta of B is 0.11045749634399207 T
# max_B: {'MEAS9': [(1, 8.098038369398961e-07), (2, 1.3661220217055e-06), (3, 1.932564397565e-06), (4, 2.4865986551556e-06), (5, 3.105969474834e-06)]}
# min_B: {'MEAS10': [(1, -7.024711030841893e-07), (2, -1.17017066651e-06), (3, -1.6300709518946e-06), (4, -2.0353284353163e-06), (5, -2.4610883409032e-06)]}
# delta_B: {1: 0.03000545515920805, 2: 0.05032326762332342, 3: 0.0706872093146746, 4: 0.08972077560460119, 5: 0.11045749634399207}
# The true power of 1 is 0.2296603863776416 W
# The true power of 2 is 0.007633251569008 W
# Pcore true power: {'1': [(1, 0.0072606751857821), (2, 0.0281090219188544), (3, 0.0643784665427145), (4, 0.1296132168231388), (5, 0.2296603863776416)]}
# PL true power: {'2': [(1, 0.0002551479852057004), (2, 0.0020021115812034), (3, 0.002261103799028), (4, 0.0053982964365783), (5, 0.007633251569008)]}
# Deskew time of CH1 = 2.777777777777778e-09
# CH1 deskew set to 2.777777777777778e-09
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 8
# Current population: 35
# Current population: 59
# Current population: 86
# Current population: 111
# Poplution採樣數量已超過 100
# The maximum B value is 3.1589330790536e-06 T
# The minimum B value is -2.41192517418e-06 T
# The delta of B is 0.11053290184987304 T
# max_B_deskew: {'MEAS9': [(1, 8.098084186567881e-07), (2, 1.38929803035e-06), (3, 1.9630424738917e-06), (4, 2.5301102486365e-06), (5, 3.1589330790536e-06)]}
# min_B_deskew: {'MEAS10': [(1, -7.024761573632555e-07), (2, -1.1469104166558e-06), (3, -1.6005909142961e-06), (4, -1.9979458117718e-06), (5, -2.41192517418e-06)]}
# delta_B_deskew: {1: 0.030005646349604044, 2: 0.05032159617075001, 3: 0.07070701167039287, 4: 0.08984238215095836, 5: 0.11053290184987304}
# The true power of 1 is 0.275642196347191 W
# The true power of 2 is 0.0203816703089 W
# Pcore true power_deskew: {'1': [(1, 0.010851584839588), (2, 0.0384511334087105), (3, 0.0843195725997381), (4, 0.1608278921088942), (5, 0.275642196347191)]}
# PL true power_deskew: {'2': [(1, 0.0014247429025361), (2, 0.0051086046099416), (3, 0.0081270379276053), (4, 0.014349886905517), (5, 0.0203816703089)]}
# k factor:0.27724917197331733
# Core Real power loss:0.22754407370067012
# Every volume of Core Real power loss:443858.52667642664
# 已經測量完畢
# turn AFG31101 output off
# turn RF150A100D power off
#   core parameter                                                  \
#     type of core effective length of core effective area of core
# 0          ML95S                   0.0304               0.000017
# 1          ML95S                   0.0304               0.000017
# 2          ML95S                   0.0304               0.000017
# 3          ML95S                   0.0304               0.000017
# 4          ML95S                   0.0304               0.000017
#
#                                                      Test environment (R=10)  \
#   effective volume of core turns of wire on the core                Sequence
# 0             5.126500e-07                         3                       1
# 1             5.126500e-07                         3                       2
# 2             5.126500e-07                         3                       3
# 3             5.126500e-07                         3                       4
# 4             5.126500e-07                         3                       5
#
#                            flux density (DS=0)  ... L(DS=0 degree)  \
#    Vin(Vpp) Gain deltaB(T)              Max(V)  ...           P(W)
# 0  303.0E-3   32      0.03        8.098038e-07  ...       0.007261
# 1  302.0E-3   48      0.05        1.366122e-06  ...       0.028109
# 2  302.0E-3   57      0.07        1.932564e-06  ...       0.064378
# 3  302.0E-3   63      0.09        2.486599e-06  ...       0.129613
# 4  300.0E-3   68      0.11        3.105969e-06  ...       0.229660
#
#   CL(DS=0 degree) flux density (DS=1)                          L(DS=1 degree)  \
#              P(W)              Max(V)        Min(V) delta B(T)           P(W)
# 0        0.000255        8.098084e-07 -7.024762e-07   0.030006       0.010852
# 1        0.002002        1.389298e-06 -1.146910e-06   0.050322       0.038451
# 2        0.002261        1.963042e-06 -1.600591e-06   0.070707       0.084320
# 3        0.005398        2.530110e-06 -1.997946e-06   0.089842       0.160828
# 4        0.007633        3.158933e-06 -2.411925e-06   0.110533       0.275642
#
#   CL(DS=1 degree) Final calculate
#              P(W)               K Real Pcore(W) Real Pcv(W/m^3)
# 0        0.001425        0.325710      0.007178    14000.918667
# 1        0.005109        0.300373      0.027508    53657.741685
# 2        0.008127        0.294163      0.063713   124282.324453
# 3        0.014350        0.286775      0.128065   249810.045885
# 4        0.020382        0.277249      0.227544   443858.526676
#
# [5 rows x 22 columns]
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[19], line 379
#     376     rf.close_instrument()
#     378 if __name__ == "__main__":
# --> 379     main()
#
# Cell In[19], line 371, in main()
#     368 print(df) #列出來
#     370 #儲存為Excel文件
# --> 371 df.to_csv('instruments_measurement_results.csv', index=False) #將資料弄成一個CSV檔
#     373 # ============================ Close Instrument =================================
#     374 afg.close_instrument()
#
# File ~\anaconda3\envs\PyVISA\lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File ~\anaconda3\envs\PyVISA\lib\site-packages\pandas\io\formats\format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\envs\PyVISA\lib\site-packages\pandas\io\formats\csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File ~\anaconda3\envs\PyVISA\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'instruments_measurement_results.csv'
