# %%
#引入需要的包裝
import pandas as pd
import numpy as np
import pyvisa
import time
import math
import matplotlib.pyplot as plt
from AFG31101 import AFG_31101
from RF150A100D import RF_150A100D
from MSO64B import MSO_64B
from HIOKI8450 import HIOKI_8450

# %% [markdown]
# ### AFG31101
#
# ===============Function List=================
#
# * Set weveform type
# * Set frequency
# * Set amplitude
# * Set output state
# * Set amplitude limit
#
# 若要串接其他儀器 一樣使用class 定義其他儀器的function

# %%
# class AFG_31101():
#     def __init__(self, resource_address, visa_dll=None):
#         """
#         初始化儀器控制器。
#         :param resource_address: 儀器的資源地址。
#         :param visa_dll: 使用的 VISA DLL 路徑。如果為 None，則使用系統預設空白。
#         """
#         self.resource_address = resource_address
#         self.visa_dll = visa_dll if visa_dll is not None else ''
#         self.rm = pyvisa.ResourceManager(self.visa_dll)
#         self.instrument = None
#         self.connect_to_instrument()
        
#     def connect_to_instrument(self):
#         # 建立與儀器的連接
#         self.instrument = self.rm.open_resource(self.resource_address)
#         print("Connected to AFG_31101.")
#         print(self.query_identity())

#     def query_identity(self):
#          # 查詢並返回儀器的身份識別信息
#         if self.instrument:
#              return self.instrument.query("*IDN?")
#         else:
#              raise Exception("Instrument not connected. Please connect first.")

#     def close_instrument(self):
#         if self.instrument:
#             self.instrument.close()
#             print("AFG_31101 connection closed.")
#         else:
#             print("No instrument to close.")

#     def set_waveform(self, shape):
#         if self.instrument:
#             self.instrument.write(f"SOURce1:FUNCtion {shape}")
#             time.sleep(0.05)
#             print(f"set signal form be {shape}")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def set_frequency(self, freq_amplitude, freq_unit):
#         if self.instrument:
#             self.instrument.write(f"SOURce1:FREQuency:FIXed {freq_amplitude} {freq_unit}")
#             time.sleep(0.05)
#             print(f"set signal frequency be {freq_amplitude}{freq_unit}")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def query_frequency(self):
#         if self.instrument:
#             self.instrument.write(f"SOURce1:FREQuency:FIXed?")
#             time.sleep(0.05)
#             return self.instrument.read()
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def set_amplitude(self, amp_magnitude, amp_unit):
#         if self.instrument:
#             self.instrument.write(f"SOURce1:VOLTage:LEVel:IMMediate:AMPLitude {amp_magnitude}{amp_unit}")
#             time.sleep(0.05)
#             print(f"set signal amplitude be {amp_magnitude}{amp_unit}")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def query_amplitude(self):
#         if self.instrument:
#             self.instrument.write(f"SOURce1:VOLTage:LEVel:IMMediate:AMPLitude?")
#             time.sleep(0.05)
#             return self.instrument.read()
#         else:
#             raise Exception("Instrument not connected. Please connect first.")
    
#     def output_on(self):
#         if self.instrument:
#             self.instrument.write(f"OUTPut1:STATe ON")
#             time.sleep(0.05)
#             print(f"turn AFG31101 output on")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def output_off(self):
#         if self.instrument:
#             self.instrument.write(f"OUTPut1:STATe OFF")
#             time.sleep(0.05)
#             print(f"turn AFG31101 output off")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

# %%
def check_output_state(afg, output_state):
    if output_state == 'ON': #判斷輸出狀態，選擇要操作在哪一個輸出狀態DEF
        afg.output_on()
    else:
        afg.output_off()

# %%
def check_amp_limit(afg, amplitude_limit, amplitude):  # 檢查振幅是否超過限制
    amp_num = float(amplitude['magnitude'])  # 將當下振幅大小的字串型態轉為數字型態
    if amp_num >= amplitude_limit:  # 判斷振幅是否大於AMPLITUDE_LIMIT
        print(f'Magnitude of amplitude cannot exceed {amplitude_limit} voltage')
        afg.output_off()  # 將OUTPUT關閉

# %% [markdown]
# ### RF-150A_100D
#
# ===============Function List=================
#
# * Set power state
# * Set gain
#
# 若要串接其他儀器 一樣使用class 定義其他儀器的function

# %%
# class RF_150A100D():
#     def __init__(self, resource_address, visa_dll=None):
#         """
#         初始化儀器控制器。
#         :param resource_address: 儀器的資源地址。
#         :param visa_dll: 使用的 VISA DLL 路徑。如果為 None，則使用系統預設空白。
#         """
#         self.resource_address = resource_address
#         self.visa_dll = visa_dll if visa_dll is not None else ''
#         self.rm = pyvisa.ResourceManager(self.visa_dll)
#         self.instrument = None
#         self.connect_to_instrument()
        
#     def connect_to_instrument(self):
#         # 建立與儀器的連接
#         self.instrument = self.rm.open_resource(self.resource_address)
#         print("Connected to RF_150A100D.")
#         print(self.query_identity())

#     def query_identity(self):
#          # 查詢並返回儀器的身份識別信息
#         if self.instrument:
#              return self.instrument.query("*IDN?")
#         else:
#              raise Exception("Instrument not connected. Please connect first.")

#     def close_instrument(self):
#         if self.instrument:
#             self.instrument.close()
#             print(f"RF_150A100D connection closed.")
#         else:
#             print(f"No instrument to close.")

#     def power_on(self):
#         if self.instrument:
#             self.instrument.write(f"P1")
#             print(f"turn RF150A100D power on")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def power_off(self):
#         if self.instrument:
#             self.instrument.write(f"P0")
#             print(f"turn RF150A100D power off")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def set_gain(self, gain ,gain_set):
#         if self.instrument:
#             self.instrument.write(f"G{gain_set}")
#             print(f"set power gain be {gain}")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def query_gain(self):
#         if self.instrument:
#             self.instrument.write(f"G?")
#             time.sleep(0.05)
#             return self.instrument.read()
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def reset(self):
#         if self.instrument:
#             self.instrument.write(f"R")
#             print(f"clear faults")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

# %%
def check_power_state(rf, power_state):
    if power_state == 'ON': #判斷書出狀態，選擇def
        rf.power_on()
    else:
        rf.power_off()

# %%
def check_power_gain(rf, gain):
    if gain < 0:
        rf.power_off()
        print(f"gain you set {gain} can't < 0")

# %%
def calculate_gain_set(gain):
    """
    計算並返回設置增益的值
    透過設定的gain去計算給儀器的gain_set該為多少
    """
    ratio = 4095 / 100  # MAX和MIN的比例
    gain_set = math.ceil(ratio * gain)  # 使用 math函數進行無條件進位
    gain_set = min(gain_set, 4095)  # 限制 gain_set 最大值為 4095
    gain_set = str(gain_set).zfill(4)  # 保持四個字元
    #print(f"CMD of gain set be G{ratio * gain}")
    return gain_set

# %%
def calculate_gain_from_set(gain_set):
    """
    根據儀器返回的四位數 gain_set，計算並返回實際的增益大小，並取整數
    """
    # 刪除前綴 "G" 並轉換為數字
    gain_value = int(gain_set[1:])
    
    # 根據比例 4095 對應 100%，反推出增益
    ratio = 100 / 4095  # MAX和MIN的比例
    gain = gain_value * ratio
    
    # 返回四捨五入到整數的增益
    return round(gain)

# %% [markdown]
# ### MSO64B
#
# ===============Function List=================
#
# * Set channel
# * Auto set horizontal scale
# * Auto set Gating type
# * Auto set cursor positon
# * Auto set bandwidth limit
# * Auto set Acquistion mode & numbers of waveform
# * Set measurements[AMP、MEAN、DELAY]
# * Set math function
#
# 若要串接其他儀器 一樣使用class 定義其他儀器的function

# %%
# class MSO_64B():
#     def __init__(self, resource_address, visa_dll=None):
#         """
#         初始化儀器控制器。
#         :param resource_address: 儀器的資源地址。
#         :param visa_dll: 使用的 VISA DLL 路徑。如果為 None，則使用系統預設空白。
#         """
#         self.resource_address = resource_address
#         self.visa_dll = visa_dll if visa_dll is not None else ''
#         self.rm = pyvisa.ResourceManager(self.visa_dll)
#         self.instrument = None
#         self.connect_to_instrument()
        
#     def connect_to_instrument(self):
#         # 建立與儀器的連接
#         self.instrument = self.rm.open_resource(self.resource_address)
#         print("Connected to MSO64B.")
#         print(self.query_identity())

#     def query_identity(self):
#          # 查詢並返回儀器的身份識別信息
#         if self.instrument:
#              return self.instrument.query("*IDN?")
#         else:
#              raise Exception("Instrument not connected. Please connect first.")

#     def close_instrument(self):
#         #關閉與儀器的連接
#         if self.instrument:
#             self.instrument.close()
#             print("MSO64B connection closed.")
#         else:
#             print("No instrument to close.")

#     def clear(self):
#         #執行示波器上的clear鍵，讓計算、測量項重新運算
#         if self.instrument:
#             self.instrument.write(f':CLEAR')
#             time.sleep(0.3)  # 在命令之間暫停0.5
#             print(f"clear acquistions, measurements, and waveforms")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def set_gating_type(self):
#         if self.instrument:
#             #設定measurement中Gating type
#             self.instrument.write(f'MEASUrement:GATing CURSor')
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#             print(f"take measurements on the portion of the waveform between the cursor")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def cursor_control(self, cursor_A_position, cursor_B_position):
#         if self.instrument:
#             #設定cursor範圍為三個波形週期
#             self.instrument.write(f':DISplay:WAVEView1:CURSor:CURSOR1:STATE ON')
#             self.instrument.write(f':DISplay:WAVEView1:CURSor:CURSOR1:WAVEform:APOSition {cursor_A_position}')
#             self.instrument.write(f':DISplay:WAVEView1:CURSor:CURSOR1:WAVEform:BPOSition {cursor_B_position}')
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#             print(f"set cursor range be {cursor_A_position} to {cursor_B_position}")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")
            
#     def result_table(self):
#         #打開resulit table
#         if self.instrument:
#             self.instrument.write(f':MEASTABle:ADDNew "TABLE1"')
#             time.sleep(0.05)  # 在命令之間暫停0.5
#             print(f"add measurent result table")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")
            
#     def add_measurement(self,meas,source):
#         if self.instrument:       #新增CH1、CH2、CH3的MEAN測量值
#             type_CMD = f":MEASUrement:{meas}:TYPE MEAN" #測量類型CMD
#             source_CMD = f":MEASUrement:{meas}:SOURCE {source}" #訊號源CMD
#             command = f"{type_CMD};{source_CMD}" #完整叫出AMPLITUDE的CMD
#             self.instrument.write(command) #寫入儀器
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#             print(f"add measurent {meas} of {source}")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def set_horizon_scale(self, horizon_scale):
#         if self.instrument:
#             self.instrument.write(f':HORIZONTAL:MODE:SCALE {horizon_scale}')
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#             print(f"set Horizontal Scale to {horizon_scale}s/div")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def detect_clip(self,clip_check):
#         if self.instrument:
#             #查看是否有波形clipping?
#             return self.instrument.query(f":{clip_check}:CLIPping?")
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#         else:
#             raise Exception("Instrument not connected. Please connect first.")
            
#     def query_vertical_scale(self,clip_check):
#         if self.instrument:
#             #回傳當下有clipping之通道的vertical scale為多少?
#             return self.instrument.query(f":{clip_check}:SCAle?")
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#         else:
#             raise Exception("Instrument not connected. Please connect first.")
    
#     def set_vertical_scale(self, clip_channel, new_vertical_value):
#         if self.instrument:
#             #重新對通道設定vertical scale
#             self.instrument.write(f":{clip_channel}:SCAle {new_vertical_value}")
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#             print(f"set {clip_channel} vertical scale be {new_vertical_value}")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def math_add(self, math_num, math_function):
#         if self.instrument:
#             #新增math formula
#             self.instrument.write(f':MATH:ADDNew "{math_num}"')
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#             self.instrument.write(f':MATH:{math_num}:DEFine "{math_function}"')
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#             print(f"Add {math_num} to calculate {math_function}")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def set_math_autoscale(self):
#         if self.instrument:
#             #新增math formula
#             self.instrument.write(f':DISplay:WAVEView1:MATH:MATH4:AUTOScale ON')
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#             print(f"enables the autoscaling the math4 in the specified Waveform View")
#             self.instrument.write(f':DISplay:WAVEView1:MATH:MATH5:AUTOScale ON')
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#             print(f"enables the autoscaling the math5 in the specified Waveform View")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")
            
#     def set_math_label(self, math_num, label_name):
#         if self.instrument:
#             #新增math formula
#             self.instrument.write(f':MATH:{math_num}:LABel:NAMe "{label_name}" ')
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#             print(f"set label of {math_num} be {label_name} ")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def off_display(self, off_channel, off_math):  
#         if self.instrument:
#             #將不必要的波形關閉
#             self.instrument.write(f':DIS:WAVEVIEW1:{off_channel}:STATE OFF')
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#             print(f"turn {off_channel} display off")
#             self.instrument.write(f':DISplay:WAVEView1:MATH:{off_math}:STATE OFF')
#             time.sleep(0.05)  # 在命令之間暫停0.5秒
#             print(f"turn {off_math} display off")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def measure_delta_B(self):
#         if self.instrument:
#             #新增測量磁通最大值及最小值的measurement
#             self.instrument.write(f':MEASUREMENT:MEAS9:TYPE MAXIMUM; SOUrce MATH5') #新增math5的最大值
#             time.sleep(0.05)  # 在命令之間暫停0.5秒           
#             self.instrument.write(f':MEASUREMENT:MEAS10:TYPE MINIMUM; SOUrce MATH5') #新增math5的最小值
#             time.sleep(0.05)  # 在命令之間暫停0.5
#             print(f"add measurent maximum of math5")
#             print(f"add measurent minimum of math5")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def power_function(self,num,voltage,current):
#         if self.instrument:
#             self.instrument.write(f':POWer:POWer{num}:POWERQUALITY:VSOURce {voltage}') #新增math5的最小值
#             time.sleep(0.05)  # 在命令之間暫停0.5
#             self.instrument.write(f':POWer:POWer{num}:POWERQUALITY:ISOURce {current}') #新增math5的最小值
#             time.sleep(0.05)  # 在命令之間暫停0.5
#             print(f"add measurent maximum of math5")
#             print(f"add measurent minimum of math5")
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def set_deskew(self, deskew_ch1):
#         if self.instrument:
#             self.instrument.write(f'CH1:DESKEW {deskew_ch1}')
#             print(f"CH1 deskew set to {deskew_ch1}")
#             time.sleep(0.05)
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def set_deskew_zero(self):
#         if self.instrument:
#             self.instrument.write(f'CH1:DESKEW 0')
#             print(f"CH1 deskew set to 0")
#             time.sleep(0.05)
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

#     def query_mean_value(self, meas):
#         if self.instrument:                  
#             self.instrument.write(f'MEASUrement:{meas}:RESUlts:CURRentacq:MEAN?')
#             time.sleep(0.05)
#             return float(self.instrument.read())
#         else:
#              raise Exception("Instrument not connected. Please connect first.")

#     def query_true_power(self, power_num):
#         if self.instrument:
#             self.instrument.write(f'POWer:POWer{power_num}:RESUlts:CURRentacq:MEAN? "TruePWR"')
#             time.sleep(0.05)
#             return float(self.instrument.read())
#         else:
#              raise Exception("Instrument not connected. Please connect first.")

#     def query_population(self):
#         if self.instrument:
#             self.instrument.write(f'MEASUrement:MEAS3:RESUlts:ALLAcqs:POPUlation?')
#             time.sleep(0.05)
#             return int(self.instrument.read())
#         else:
#             raise Exception("Instrument not connected. Please connect first.")

# %%
def wait_for_population(mso, threshold=25):
    while True: #重複查詢採樣次數(population)
        pop_num = mso.query_population() 
        print(f"Current population: {pop_num}") #列出每0.5秒的pop次數
        if pop_num >= threshold: #當pop次數大於等於100，結束while迴圈
            print(f"Poplution採樣數量已超過 {threshold}") 
            break #跳脫迴圈
        time.sleep(1)  # 防止過於頻繁的查詢，調整每0.5秒查詢一次

# %%
def set_cursor_range(afg, mso):
    """
    設置示波器的cursor range
    [因為如果一開始示波器的horizon scale沒有調好，抓到的freq值會過大，調整錯誤，因此直接從AFG訊號產生器抓值]
    """
    freq = float(afg.query_frequency()) #從afg抓頻率值
    print(f"the frequency of excitaton is {freq} Hz")
    
    cursor_A_position = -2 * (1 / freq)  # 設cursor_A為負1.5波形週期sec
    cursor_B_position = 2 * (1 / freq)  # 設cursor_B為正1.5波形週期sec
    mso.set_cursor(cursor_A_position, cursor_B_position)

# %%
def set_horizon_scale(afg, mso):
    """
    設置示波器的horizon scale
    [因為如果一開始示波器的horizon scale沒有調好，抓到的freq值會過大，調整錯誤，因此直接從AFG訊號產生器抓值]
    """
    freq = float(afg.query_frequency()) #從afg抓頻率值
    print(f"the frequency of signal is {freq}Hz")
    
    horizon_scale = (1 / freq) * (4 / 10)
    mso.set_horizon_scale(horizon_scale) #自動調整horizon scale

# %%
def set_vertical_scale(mso):
    clip_channels = ['CH1','CH2','CH3']#分別測試ch1、ch2、ch3是否clipping?

    channel_meas = {'CH1': 'MEAS3','CH2': 'MEAS4','CH3': 'MEAS5'} #每個channel對應的amplitude測量項
    
    for clip_channel in clip_channels:
        while True: #重複測試到最後沒通道clipping & vertical scale都設定到80%
            all_channels_clipped = False
            
            clip_result = float(mso.detect_clip(clip_channel)) 
            #print(f"clipping state:{clip_result}") #顯示1代表有clipping，0代表沒有clipping
            if clip_result == 1: #clipping時
                clip_vertical_scale = float(mso.query_vertical_scale(clip_channel))
                new_clip_vertical_scale = clip_vertical_scale + 40e-3 #將當下的vertical scale以20mV/div為step加上去
                print(f"{clip_channel} is clipping")
                mso.set_vertical_scale(clip_channel, new_clip_vertical_scale) #設定新的vertical scale
                time.sleep(0.05) #最後調整到沒有clipping等待久一點，讓下面程序執行正常
            elif clip_result == 0: # 當channel沒有clipping時
                meas = channel_meas[clip_channel] #當下的clip_channel對應的meas是什麼?
                time.sleep(0.5)
                print(f"{clip_channel} no clipping")
                clip_amplitude = float(mso.query_mean_value(meas)) # 看該通道的amplitude大小
                print(f"amplitude of {clip_channel} is {clip_amplitude}")
                new_vertical_scale = clip_amplitude / 6.5  #將amplitude大小除以7即為理想的60~80% vertical scale
                mso.set_vertical_scale(clip_channel, new_vertical_scale) # 設定新的vertical scale
                time.sleep(0.2)
                clip_result = float(mso.detect_clip(clip_channel)) 
                if clip_result == 1:
                    time.sleep(0.5)
                    print(f'{clip_channel} is clipping')
                    print('readjust the vertical scale')
                    all_channels_clipped = True  # 代表還有channel clipping
                else:
                    print(f'vertical state of {clip_channel} is good')
                    break

# %%
def calculate_core_parameters(core_He, core_OD, core_ID):
    """
    計算鐵芯的有效路徑長度(l_e)、有效截面積(A_e)和有效體積(V_e)
    """
    # 計算 C1 和 C2
    h = core_He
    d1 = core_OD
    d2 = core_ID

    C1 = (2 * math.pi) / (h * math.log(d1 / d2))
    C2 = (4 * math.pi * (1/d2 - 1/d1)) / (h**2 * math.log(d1 / d2)**3)

    # 計算 le, Ae, Ve
    le = (C1**2) / C2
    Ae = C1 / C2
    Ve = le * Ae
    print(f"有效路徑長度 (le): {le} mm")
    print(f"有效截面積 (Ae): {Ae} mm^2")
    print(f"有效體積 (Ve): {Ve} mm^3")

    return le, Ae, Ve

# %%
def save_mso_query_values(mso, sequence, core_effective_area, turn):
    """
    用來儲存向儀器(示波器)查詢之值的包裝
    """
    B_max = mso.query_mean_value('MEAS9')
    B_min = mso.query_mean_value('MEAS10')
    calculate_delta_B = (B_max - B_min) / (core_effective_area * turn * 0.000001)
    
    time.sleep(0.05)
    print(f"The maximum B value is {B_max} T")
    print(f"The minimum B value is {B_min} T")
    print(f"The delta of B is {calculate_delta_B} T")
    
    return B_max, B_min, calculate_delta_B

# %%
def save_mso_power_values(mso, sequence):
    """
    用來儲存向儀器(示波器)查詢之值的包裝
    """
    power1_value = float(mso.query_true_power('1'))
    power2_value = float(mso.query_true_power('2'))
    
    time.sleep(0.05)
    print(f"The true power of 1 is {power1_value} W")
    print(f"The true power of 2 is {power2_value} W")
    
    return power1_value, power2_value

# %%
def set_vref_deskew(afg, mso, deskew_vref):
    freq = float(afg.query_frequency()) #查詢測試環境所設定之激勵源的頻率
    deskew_ch1 = (deskew_vref)/(360 * freq) #計算Deskew角度要調整的秒數
    mso.set_deskew(deskew_ch1)

# %%
def acquire_measurement(mso, i, core_effective_area, turn, max_B, min_B, delta_B, Pcore_true_power, PL_true_power, deskew=False):
    B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
        
    # 更新 max_B 和 min_B 字典
    if deskew:
        if 'MEAS9' not in max_B:
            max_B['MEAS9'] = []
        max_B['MEAS9'].append((i, B_max))
        # print("max_B_deskew:", max_B)

        if 'MEAS10' not in min_B:
            min_B['MEAS10'] = []
        min_B['MEAS10'].append((i, B_min))
        # print("min_B_deskew:", min_B)
        
        delta_B[i] = calculate_delta_B
        # print("delta_B_deskew:", delta_B)
    else:
        if 'MEAS9' not in max_B:
            max_B['MEAS9'] = []
        max_B['MEAS9'].append((i, B_max))
        # print("max_B:", max_B)

        if 'MEAS10' not in min_B:
            min_B['MEAS10'] = []
        min_B['MEAS10'].append((i, B_min))
        # print("min_B:", min_B)
        
        delta_B[i] = calculate_delta_B
        # print("delta_B:", delta_B)

    # 量測損耗功率
    power1_value, power2_value = save_mso_power_values(mso, i)

    if deskew:
        if '1' not in Pcore_true_power:
            Pcore_true_power['1'] = []
        Pcore_true_power['1'].append((i, power1_value))
        # print("Pcore true power_deskew:", Pcore_true_power)
        
        if '2' not in PL_true_power:
            PL_true_power['2'] = []
        PL_true_power['2'].append((i, power2_value))
        # print("PL true power_deskew:", PL_true_power)
    else:
        if '1' not in Pcore_true_power:
            Pcore_true_power['1'] = []
        Pcore_true_power['1'].append((i, power1_value))
        #print("Pcore true power:", Pcore_true_power)
        
        if '2' not in PL_true_power:
            PL_true_power['2'] = []
        PL_true_power['2'].append((i, power2_value))
        #print("PL true power:", PL_true_power)

# %%
def calculate_final_power_loss(sequence, Pcore_true_power, PL_true_power, Pcore_true_power_deskew, PL_true_power_deskew, core_effective_volume):
    """
    套公式計算 k_factor, Pcore 和 Pcore_cv
    """
    k_factor = (PL_true_power_deskew['2'][sequence-1][1] - PL_true_power['2'][sequence-1][1]) / (Pcore_true_power_deskew['1'][sequence-1][1] - Pcore_true_power['1'][sequence-1][1])
    print(f"k factor:{k_factor}")
    Pcore = (Pcore_true_power['1'][sequence-1][1] - (k_factor * PL_true_power['2'][sequence-1][1]))
    print(f"Core Real power loss:{Pcore}")
    Pcore_cv = (Pcore / core_effective_volume) * 1000000
    print(f"Every volume of Core Real power loss:{Pcore_cv}")

    return k_factor, Pcore, Pcore_cv

# %%
# def adjust_rf_afg(mso, rf, afg, i, core_effective_area, turn, target_deltaB, gain, amplitude, amplitude_limit):
#     """
#     調整 RF 增益以達到目標 delta B 值
#     減少
#     """
#     tolerance_top = 0.015
#     tolerance_max = 0.008
#     tolerance_mid = 0.005
#     tolerance_min = 0.003
#     tolerance_final = 0.001 #磁通密度抓得較精準

#     time.sleep(0.5)
#     # 查詢初始的 delta B 值
#     B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
    
#     while abs(target_deltaB - calculate_delta_B) > tolerance_final:
#         if calculate_delta_B > 0.155:
#             print("delta B 大於155 mT")
#             tolerance_final = 0.0018 #磁通密度較高，抓得精準範圍越鬆
#             step_rf_max = 1
#             step_rf_mid = 1
#             step_rf_mean = 1
#             step_rf_min = 1
#             step_rf_decrease = 1
#             step_afg_increase_max = 0
#             step_afg_increase_mid = 0
#             step_afg_increase_min = 0
#             step_afg_decrease = 7
#         elif calculate_delta_B > 0.11:
#             print("delta B 大於110 mT")
#             tolerance_final = 0.0018 #磁通密度較高，抓得精準範圍越鬆
#             step_rf_max = 2
#             step_rf_mid = 1
#             step_rf_mean = 1
#             step_rf_min = 1
#             step_rf_decrease = 1
#             step_afg_increase_max = 2
#             step_afg_increase_mid = 1
#             step_afg_increase_min = 0
#             step_afg_decrease = 5
#         elif calculate_delta_B > 0.07:
#             print("delta B 大於70 mT")
#             tolerance_final = 0.0015 #磁通密度較高，抓得精準範圍越鬆
#             step_rf_max = 2
#             step_rf_mid = 2
#             step_rf_mean = 1
#             step_rf_min = 1
#             step_rf_decrease = 2
#             step_afg_increase_max = 2
#             step_afg_increase_mid = 1
#             step_afg_increase_min = 1
#             step_afg_decrease = 3
#         elif calculate_delta_B > 0.04:
#             print("delta B 大於50 mT")
#             tolerance_final = 0.001 #磁通密度較高，抓得精準範圍越鬆
#             step_rf_max = 3
#             step_rf_mid = 2
#             step_rf_mean = 2
#             step_rf_min = 1
#             step_rf_decrease = 2         
#             step_afg_increase_max = 8
#             step_afg_increase_mid = 4
#             step_afg_increase_min = 2
#             step_afg_decrease = 3
#         else:
#             print("delta B 小於50 mT")
#             step_rf_max = 4
#             step_rf_mid = 3
#             step_rf_mean = 2
#             step_rf_min = 1
#             step_rf_decrease = 1
#             step_afg_increase_max = 10
#             step_afg_increase_mid = 7
#             step_afg_increase_min = 4
#             step_afg_decrease = 2
            
#         tolerance = target_deltaB - calculate_delta_B
#         print(f"實際 delta B: {calculate_delta_B} 與預期 delta B: {target_deltaB} 差了 {tolerance}T")

#         if tolerance < -tolerance_final:
#             print(f"實際deltaB大於預期deltaB {tolerance_final}")
#             amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) - step_afg_decrease  # 移除 'E-3' 並減少 1mV
#             amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
#             print(f"AFG 振幅已減少 {step_afg_decrease}V")
#             gain -= step_rf_decrease
#             print(f"增益減少 {step_rf_decrease}")
#         elif tolerance > tolerance_max:
#             print(f"delta B 誤差大於 {tolerance_max}")
#             amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg_increase_max  # 移除 'E-3' 並增加 3mV
#             amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
#             print(f"AFG 振幅已增加 {step_afg_increase_max}V")
#             gain += step_rf_max
#             print(f"增益增加 {step_rf_max}")
#         elif tolerance > tolerance_mid:
#             print(f"delta B 誤差介於 {tolerance_mid} ~ {tolerance_max}")
#             amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg_increase_mid  # 移除 'E-3' 並增加 2mV
#             amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
#             print(f"AFG 振幅已增加 {step_afg_increase_mid}V")
#             gain += step_rf_mid
#             print(f"增益增加 {step_rf_mid}")
#         elif tolerance > tolerance_min:
#             print(f"delta B 誤差介於 {tolerance_min} ~ {tolerance_mid}")
#             amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg_increase_min  # 移除 'E-3' 並增加 2mV
#             amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
#             print(f"AFG 振幅已增加 {step_afg_increase_min}V")
#             gain += step_rf_mean
#             print(f"增益增加 {step_rf_mean}")
#         else:
#             print(f"delta B 誤差介於 {tolerance_final} ~ {tolerance_min}")
#             gain += step_rf_min
#             print(f"增益增加 {step_rf_min}")
            
#         check_amp_limit(afg, amplitude_limit, amplitude)  # 檢查振幅是否超過限制
#         afg.set_amplitude(amplitude['magnitude'], amplitude['unit'])

#         check_power_gain(rf, gain)
#         gain_set = calculate_gain_set(gain)
#         rf.set_gain(gain, gain_set)

#         time.sleep(0.5)
#         set_vertical_scale(mso)

#         time.sleep(1)

#         time.sleep(1.5)
#         B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
    
#     print(f"delta B已達預期的{target_deltaB}")
#     return amplitude, gain

# %%
def adjust_rf_afg_1(mso, rf, afg, i, core_effective_area, turn, target_deltaB, gain, amplitude, amplitude_limit):
    """
    調整 RF 增益以達到目標 delta B 值
    減少
    """
    tolerance_1 = 0.001
    tolerance_2 = 0.003
    tolerance_3 = 0.005
    tolerance_4 = 0.008
    tolerance_5 = 0.015 
    tolerance_6 = 0.0205

    time.sleep(0.5)
    # 查詢初始的 delta B 值
    B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
    
    while abs(target_deltaB - calculate_delta_B) > tolerance_1:
        query_gain = rf.query_gain()  # 查詢當前增益
        current_gain = calculate_gain_from_set(query_gain)  # 反推並取整的增益
        print(f"Gain now:{current_gain}")
        if current_gain <= 50:
            print("delta B 大於155 mT")
            step_afg_1 = 2
            step_afg_2 = 4
            step_afg_3 = 6
            step_afg_4 = 9
            decrease_afg_1 = 3
            decrease_afg_2 = 5
            
            step_rf_1 = 1
            step_rf_2 = 2
            step_rf_3 = 3
            step_rf_4 = 5
            step_rf_5 = 7
            step_rf_6 = 9
            decrease_rf_1 = 1
            decrease_rf_2 = 3
            
        else:
            print("delta B 小於50 mT")
            step_afg_1 = 0
            step_afg_2 = 1
            step_afg_3 = 1
            step_afg_4 = 2
            decrease_afg_1 = 5
            decrease_afg_2 = 8
            
            step_rf_1 = 1
            step_rf_2 = 1
            step_rf_3 = 1
            step_rf_4 = 1
            step_rf_5 = 2
            step_rf_6 = 2
            decrease_rf_1 = 1
            decrease_rf_2 = 2
            
        tolerance = target_deltaB - calculate_delta_B
        print(f"實際 delta B: {calculate_delta_B} 與預期 delta B: {target_deltaB} 差了 {tolerance}T")

        if tolerance < -tolerance_4:
            print(f"實際deltaB大於預期deltaB {tolerance_3}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) - decrease_afg_2  # 移除 'E-3' 並減少
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已減少 {decrease_afg_2}V")
            gain -= decrease_rf_2
            print(f"增益減少 {decrease_rf_2}")
        elif tolerance < -tolerance_2:
            print(f"實際deltaB大於預期deltaB {tolerance_1}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) - decrease_afg_2  # 移除 'E-3' 並減少
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已減少 {decrease_afg_2}V")
            gain -= decrease_rf_1
            print(f"增益減少 {decrease_rf_1}")
        elif tolerance < -tolerance_1:
            print(f"實際deltaB大於預期deltaB {tolerance_1}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) - decrease_afg_1  # 移除 'E-3' 並減少
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已減少 {decrease_afg_1}V")
            gain -= decrease_rf_1
            print(f"增益減少 {decrease_rf_1}")
        elif tolerance > tolerance_6:
            print(f"delta B 誤差大於 {tolerance_6}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg_4  # 移除 'E-3' 並增加 3mV
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已增加 {step_afg_4}V")
            gain += step_rf_6
            print(f"增益增加 {step_rf_6}")
        elif tolerance > tolerance_5:
            print(f"delta B 誤差介於 {tolerance_5} ~ {tolerance_6}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg_3  # 移除 'E-3' 並增加 2mV
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已增加 {step_afg_3}V")
            gain += step_rf_5
            print(f"增益增加 {step_rf_5}")
        elif tolerance > tolerance_4:
            print(f"delta B 誤差介於 {tolerance_4} ~ {tolerance_5}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg_2  # 移除 'E-3' 並增加 2mV
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已增加 {step_afg_2}V")
            gain += step_rf_4
            print(f"增益增加 {step_rf_4}")
        elif tolerance > tolerance_3:
            print(f"delta B 誤差介於 {tolerance_3} ~ {tolerance_4}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg_2  # 移除 'E-3' 並增加 2mV
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已增加 {step_afg_2}V")
            gain += step_rf_3
            print(f"增益增加 {step_rf_3}")
        elif tolerance > tolerance_2:
            print(f"delta B 誤差介於 {tolerance_2} ~ {tolerance_3}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg_1  # 移除 'E-3' 並增加 2mV
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已增加 {step_afg_1}V")
            gain += step_rf_2
            print(f"增益增加 {step_rf_2}")
        elif tolerance > tolerance_1:
            print(f"delta B 誤差介於 {tolerance_1} ~ {tolerance_2}")
            amplitude_value = float(amplitude['magnitude'].replace('E-3', '')) + step_afg_1  # 移除 'E-3' 並增加 2mV
            amplitude['magnitude'] = f"{amplitude_value}E-3" #重新設定amplitude
            print(f"AFG 振幅已增加 {step_afg_1}V")
            gain += step_rf_1
            print(f"增益增加 {step_rf_1}")
        else:
             print(f"delta B已達預期的{target_deltaB}")
            
        check_amp_limit(afg, amplitude_limit, amplitude)  # 檢查振幅是否超過限制
        afg.set_amplitude(amplitude['magnitude'], amplitude['unit'])

        check_power_gain(rf, gain)
        gain_set = calculate_gain_set(gain)
        rf.set_gain(gain, gain_set)

        time.sleep(0.5)
        set_vertical_scale(mso)

        time.sleep(0.5)

        B_max, B_min, calculate_delta_B = save_mso_query_values(mso, i, core_effective_area, turn)
    
    return amplitude, gain

# %%
def format_time(seconds):
    """將記錄下來測量時間的秒數轉為分:秒"""
    minutes = int(seconds // 60)
    remaining_seconds = int(seconds % 60)
    return f"{minutes}:{remaining_seconds}"

# %%
def every_measurement_time(i, start_time, measurement_start_time, measurement_times, accumulated_times):
    """計算每次測量的結束時間及其花費時間"""
    measurement_end_time = time.time()
    measurement_duration = measurement_end_time - measurement_start_time
    measurement_times.append(measurement_duration)

    accumulated_time = measurement_end_time - start_time
    accumulated_times.append(accumulated_time)

    formatted_measurement_duration = format_time(measurement_duration)
    formatted_accumulated_time = format_time(accumulated_time)

    print(f"[第{i}次測量]花費時間: {formatted_measurement_duration}")
    print(f"程式執行累計時間: {formatted_accumulated_time}")

    return measurement_end_time

# %%
def main():
    
    # =========================Parmeters===============================
    #=====MSO64B parameter=====
    """
    channel:{CH1 | CH2 | CH3 | CH4 }[page:2-541]
    measure type:{AMPLITUDE | FREQUENCY | MAXIMUM | MEAN | MINIMUM | PERIOD | PHASE 
    | PK2PK | RMS } [page:2-717]
    math_num:{MATH1 | MATH2 | MATH3 | MATH4 | ...}[page:2-672]
    math_function:{first letter should be capital then calculate}[page:2-677]
    gating_type:{NONE | SCREEN | CURSor | LOGic | SEARch | TIMe }[page:2-754]
    """

    #針對display的通道新增測量項
    measurements = [
        {'measurement': 'MEAS6','channel': 'CH1'},
        {'measurement': 'MEAS7','channel': 'CH2'},
        {'measurement': 'MEAS8','channel': 'CH3'}
    ]    
    
    #設定欲增加計算及公式
    mso_maths = [
        {'math_num': 'MATH1', 'math_function': 'Ch1-Meas6'},
        {'math_num': 'MATH2', 'math_function': 'Ch2-Meas7'},
        {'math_num': 'MATH3', 'math_function': 'Ch3-Meas8'},
        {'math_num': 'MATH4', 'math_function': 'Math1/10'},
        {'math_num': 'MATH5', 'math_function': 'Intg(Math2)'}
    ]

    math_labels = [
        {'math_num' : 'MATH4', 'label_name': 'A'},
        {'math_num' : 'MATH5', 'label_name': 'T'},
    ]
    
    #設定powerfunction內容 done
    powers = [
        {'Power_num': '1','Voltage_Source': 'MATH2', 'Current_Source': 'MATH4'},
        {'Power_num': '2','Voltage_Source': 'MATH3', 'Current_Source': 'MATH4'}
    ]

    #將特定通道停止顯示(display off)，可控制channel&math
    off_displays = [
        {'channel': 'NONE','math': 'MATH1'},
        {'channel': 'NONE','math': 'MATH2'},
        {'channel': 'NONE','math': 'MATH3'},
        {'channel': 'NONE','math': 'MATH6'},
        {'channel': 'NONE','math': 'MATH7'},
        {'channel': 'NONE','math': 'MATH8'},
        {'channel': 'NONE','math': 'MATH9'}
    ]

    #=====HIOKI_8450 parameter=====
    """
    shape:{CH1_1 | CH1_2} 
    mode:{VOLTAGE | TC} 
    rtd type:{K、J、E、T、N、R、S、C}
    """
    #設置資料存取通道
    data_channels = {
                    'channel': 'CH1_1','state': 'ON', 'mode': 'TC', 'rtd_type': 'J',
                    'channel': 'CH1_2','state': 'OFF', 'mode': 'TC', 'rtd_type': 'K'
                   }
    #=====AFG_31101 parameter=====
    """
    shape:{SINusoid|SQUare|PULSe|RAMP|PRNoise|DC|SINC|GAUSsian|LORentz|ERISe|EDECay|HAVersine
     |EMEMory[1]|EMEMory2|EFILe} 
    amplitude:
        magnitude:output amplitude
        <units>::=[VPP | VRMS | DBM]
    frequency:
        magnitude:output frequency
        <units>::=[Hz | kHz | MHz]
    output_state:{ON|OFF}
    """
    #設置輸入源訊號參數
    shape = 'SINusoid'
    frequency = {'magnitude': '1000','unit': 'KHz'}
    amplitude = {'magnitude': '300E-3','unit': 'VPP'}
    output_state = "ON"
    amplitude_limit = 0.5

    #=======RF_150A_100D parameter======
    """
    Gain : 0~100
    Power state : { ON | OFF }
    """
    #設置射頻功率放大器參數
    gain = 15
    power_state = 'ON'
    
    #====================Instrument Connect Test===========================
    #=====MSO64B connection===
    MSO_instrument_address = 'USB0::0x0699::0x0530::C048992::INSTR'
    mso = MSO_64B(MSO_instrument_address)

    #=====HIOKI8450 connection===
    HIOKI_instrument_address = 'ASRL3::INSTR'
    hio = HIOKI_8450(HIOKI_instrument_address)
    
    #=====AFG_31101 connection=====
    AFG_instrument_address = 'USB0::0x0699::0x0359::C016504::INSTR'
    afg = AFG_31101(AFG_instrument_address)

    #=====RF_150A_100D connection=====
    RF_instrument_address = 'USB0::0x0547::0x1B58::0358752::INSTR'
    rf = RF_150A100D(RF_instrument_address)
    #若有其他儀器串接下去...
    
    #============================Auto Test================================= 
    # 初始化時間追蹤列表
    start_time = time.time()
    measurement_times = []
    accumulated_times = []
    
    # TO DO: 這邊給你寫For迴圈自動測量的區域
    
    #=====MSO64B control===== #若示波器已設置完成，可省略這段
    mso.result_table()#新增measurement result table的介面
    
    #===新增測量項目及功率測量項==    
    # for measurement in measurements:
    #     meas = measurement['measurement']
    #     source = measurement['channel']
    #     mso.add_measurement(meas,source)  

    # set_cursor_range(afg, mso)
    
    # 回傳math部分需要的公式
    # for mso_math in mso_maths:
    #     math_num = mso_math['math_num']
    #     math_function = mso_math['math_function']
    #     mso.math_add(math_num, math_function)

    # mso.set_math_autoscale()

    # for math_label in math_labels:
    #     math_num = math_label['math_num']
    #     label_name = math_label['label_name']
    #     mso.set_math_label(math_num,label_name)
        
    # mso.set_gating_type() #調整measurement的gating type
    # mso.measure_delta_B() #執行測量Bmax&Bmin
    
    # for power in powers:
    #     num = power['Power_num']
    #     voltage = power['Voltage_Source']
    #     current = power['Current_Source']
    #     mso.power_function(num,voltage, current)

    # for off_display in off_displays:
    #     off_channel = off_display['channel']
    #     off_math = off_display['math']
    #     mso.off_display(off_channel,off_math)

    #=====HIOKI 8450 control=====
    for data_channel in data_channels:
        channel = data_channels['channel']
        state = data_channels['state']
        mode = data_channels['mode']
        rtd_type = data_channels['rtd_type']
        hio.set_channel(channel, state)
        hio.set_measure_mode(channel, mode)
        hio.set_rtd_type(channel, rtd_type)

    #=====RF_150A_100D control=====
    gain_set = calculate_gain_set(gain)  # 計算增益設置值
    rf.set_gain(gain, gain_set)

    check_power_state(rf, power_state) #判斷放大power狀態，是開或關
    
    #=====AFG_31101 control=====
    afg.set_waveform(shape) #設置訊號類
    afg.set_frequency(frequency['magnitude'],frequency['unit']) #設置訊號頻率
    afg.set_amplitude(amplitude['magnitude'],amplitude['unit']) #設置訊號振幅

    check_output_state(afg, output_state) #判斷輸出狀態，是開或關
    check_amp_limit(afg, amplitude_limit, amplitude)  # 檢查振幅是否超過限制
    
    #===Autoset horizon & vertical scale===
    mso.clear()
    wait_for_population(mso, threshold=2) #先等待pop到10再抓數值
    set_horizon_scale(afg, mso)

    mso.clear()
    wait_for_population(mso, threshold=2)
    set_vertical_scale(mso)
        
    #=====start measure & save data to Excel by pandas======
    #=====core parameter=====
    #記錄待測鐵心知各樣參數
    core_type = 'ML95S'
    core_He = 5 #unit:mm
    core_OD = 14 #unit:mm
    core_ID = 7 #unit:mm
    turn = 3 #unit:turn
    core_effective_length, core_effective_area, core_effective_volume = calculate_core_parameters(core_He, core_OD, core_ID)
    
    #===開始量測===
    # 設定測量順序、目標 delta B 值及desekw Vref的角度

    # 使用者設定最小磁通密度、最大磁通密度和步長
    start_deltaB = 0.02  # 例如，使用者設定的最小磁通密度
    end_deltaB = 0.2    # 例如，使用者設定的最大磁通密度
    step = 0.03         # 例如，設定步長
    expect_deltaB = np.arange(start_deltaB, end_deltaB + step, step).tolist()
    expect_deltaB = [point for point in expect_deltaB if point <= end_deltaB] # 確保測量點不會超過 end_deltaB
    sequences = list(range(1, len(expect_deltaB) + 1))
    deskew_vref = 1
    
    # 將這個值的字典先重製歸零
    vin_amplitude = {}
    power_gain ={}
    max_B = {}
    min_B = {}
    delta_B ={}
    Pcore_true_power = {}
    PL_true_power = {}
    max_B_deskew = {}
    min_B_deskew = {}
    delta_B_deskew ={}
    Pcore_true_power_deskew = {}
    PL_true_power_deskew = {}
    k_factor = {}
    Pcore = {}
    Pcore_cv = {}
    temperature = {}

    #===開始測量===
    for i in sequences:
        print(f"[第{i}次測量]")

        # 計算每次測量開始的時間
        measurement_start_time = time.time()
    
        #===自動調整激勵源===
        target_deltaB = expect_deltaB[i-1] #從expect deltaB抓出當下對應預期要達到的deltaB
        wait_for_population(mso, threshold=5) #讓最測量的最一開始先等待一下再抓delta B
        amplitude, gain = adjust_rf_afg_1(mso, rf, afg, i, core_effective_area, turn, target_deltaB, gain, amplitude, amplitude_limit)
    
        vin_amplitude[i] = amplitude['magnitude']
        power_gain[i] = gain

        #===開始抓值===
        mso.set_deskew_zero() #將channel1(Vref)的Deskew歸零
    
        wait_for_population(mso) #先等待pop到一定次數再抓數值
        
        acquire_measurement(mso, i, core_effective_area, turn, max_B, min_B, delta_B, Pcore_true_power, PL_true_power)
        temperature[i] = hio.query_data()

        print("對Vref Deskew")
        set_vref_deskew(afg, mso, deskew_vref) #設定Vref deskew
    
        mso.clear()
        wait_for_population(mso) #先等待pop到一定次數再抓數值
    
        acquire_measurement(mso, i, core_effective_area, turn, max_B_deskew, min_B_deskew, delta_B_deskew, Pcore_true_power_deskew, PL_true_power_deskew, deskew=True)
    
        # 計算 k_factor, Pcore, Pcore_cv
        k_factor[i], Pcore[i], Pcore_cv[i] = calculate_final_power_loss(i, Pcore_true_power, PL_true_power, Pcore_true_power_deskew, PL_true_power_deskew, core_effective_volume)

        # 計算每次測量的結束時間及其花費時間
        measurement_end_time = every_measurement_time(i, start_time, measurement_start_time, measurement_times, accumulated_times)

    #=====測量完畢，關閉儀器====
    print("已經測量完畢")
    gain_set = calculate_gain_set(gain=0)  # 計算增益設置值
    rf.set_gain(gain, gain_set) #先將功率放大器增益調為零
    time.sleep(0.5)
    afg.output_off() #資料儲存完畢，關閉AFG
    rf.power_off() #資料儲存完畢，關閉RF
    
    #=====將所有資料丟到data最後建立成DataFrame=====
    data = {
        ("core parameter","Type"): [core_type] * len(sequences),
        ("core parameter","Le(mm)"): [core_effective_length] * len(sequences),
        ("core parameter","Ae(mm^2)"): [core_effective_area] * len(sequences),
        ("core parameter","Ve(mm^3)"): [core_effective_volume] * len(sequences),
        ("core parameter","Turns"): [turn] * len(sequences),
        ("Test environment (R=10)", "Sequence"): sequences,
        ("Test environment (R=10)", "Function"): [shape] * len(sequences),
        ("Test environment (R=10)", "freq(kHz)"): [frequency['magnitude']] * len(sequences),
        ("Test environment (R=10)", "deltaB(T)"): expect_deltaB,
        ("Test environment (R=10)", "Vin(Vpp)"): [vin_amplitude[seq] for seq in sequences], #每次調整都要重新記錄
        ("Test environment (R=10)", "Gain"): [power_gain[seq] for seq in sequences], #每次調整都要記錄
        #("flux density (DS=0)", "Max(T)"): [v for seq, v in max_B['MEAS9']],
        #("flux density (DS=0)", "Min(T)"): [v for seq, v in min_B['MEAS10']],
        ("flux density (DS=0)", "delta B(T)"): [delta_B[seq] for seq in sequences],
        ("DS=0", "Pcore(W)"): [v for seq, v in Pcore_true_power['1']],
        ("DS=0", "Pair(W)"): [v for seq, v in PL_true_power['2']],
        #("flux density (DS=1)", "Max(T)"): [v for seq, v in max_B_deskew['MEAS9']],
        #("flux density (DS=1)", "Min(T)"): [v for seq, v in min_B_deskew['MEAS10']],
        ("flux density (DS=1)", "delta B(T)"): [delta_B_deskew[seq] for seq in sequences],
        ("DS=1", "Pcore(W)"): [v for seq, v in Pcore_true_power_deskew['1']],
        ("DS=1", "Pair(W)"): [v for seq, v in PL_true_power_deskew['2']],
        ("Final calculate","K"):[k_factor[seq] for seq in sequences],
        ("Final calculate","Real Pcore(W)"):[Pcore[seq] for seq in sequences],
        ("Final calculate","Real Pcv(kW/m^3)"):[Pcore_cv[seq] for seq in sequences],
        ("Final calculate", "Spend time(sec)"): [format_time(duration) for duration in measurement_times],  # 每次測試花費的時間
        ("Final calculate", "Accumulated time(sec)"): [format_time(accumulated_time) for accumulated_time in accumulated_times],  # 累計時間
        ("Final calculate", "Temperature(degree C)"): [temperature[seq] for seq in sequences],  # 記錄溫度
    }

    # 建立MultiIndex
    index = pd.MultiIndex.from_tuples(data.keys())

    #建立DataFrame
    df = pd.DataFrame(data) #用一代號表示整個二維資料
    df.columns = index

    #顯示DataFrame
    print(df) #列出來

    #儲存為Excel文件
    df.to_csv('(1MHz)ML95s_SIN_20-200mT(0926_1).csv', index=False) #將資料弄成一個CSV檔
    
    # ============================ Close Instrument =================================
    afg.close_instrument()
    mso.close_instrument()
    rf.close_instrument()
    
if __name__ == "__main__":
    main()
# Out:
# Connected to MSO64B.
# TEKTRONIX,MSO64B,C048992,CF:91.1CT FV:1.44.3.433
#
# Connected to HIOKI8450.
# HIOKI,LR8450,220139566,V2.21
#
# Connected to AFG_31101.
# TEKTRONIX,AFG31101,C016504,SCPI:99.0 FV:1.6.1
#
# Connected to RF_150A100D.
# AR-RF/MICROWAVE-INST,150A100D,1.0
#
# add measurent result table
# the frequency of excitaton is 1000000.0 Hz
# set cursor range be -2e-06 to 2e-06
# set CH1_2 OFF
# set mode of CH1_2 be TC
# set the sensor kind for the CH1_2 be K
# set CH1_2 OFF
# set mode of CH1_2 be TC
# set the sensor kind for the CH1_2 be K
# set CH1_2 OFF
# set mode of CH1_2 be TC
# set the sensor kind for the CH1_2 be K
# set CH1_2 OFF
# set mode of CH1_2 be TC
# set the sensor kind for the CH1_2 be K
# set power gain be 15
# turn RF150A100D power on
# set signal form be SINusoid
# set signal frequency be 1000KHz
# set signal amplitude be 300E-3VPP
# turn AFG31101 output on
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 9
# Poplution採樣數量已超過 2
# the frequency of signal is 1000000.0Hz
# set Horizontal Scale to 4e-07s/div
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 3
# Poplution採樣數量已超過 2
# CH1 no clipping
# amplitude of CH1 is 1.1963033135536
# set CH1 vertical scale be 0.18404666362363079
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 2.1052346536036
# set CH2 vertical scale be 0.32388225440055385
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 1.212036052576
# set CH3 vertical scale be 0.1864670850116923
# vertical state of CH3 is good
# 有效路徑長度 (le): 30.486205264250426 mm
# 有效截面積 (Ae): 16.81585548713705 mm^2
# 有效體積 (Ve): 512.651622074832 mm^3
# [第1次測量]
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 11
# Poplution採樣數量已超過 5
# The maximum B value is 5.405424872151343e-07 T
# The minimum B value is -4.392908579120558e-07 T
# The delta of B is 0.019422806962882816 T
# CH1 deskew set to 0
# Current population: 18
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 10
# Current population: 20
# Current population: 30
# Poplution採樣數量已超過 25
# The maximum B value is 5.377105480874889e-07 T
# The minimum B value is -4.511351221481164e-07 T
# The delta of B is 0.019601454333619893 T
# The true power of 1 is 0.0041889309687541 W
# The true power of 2 is 0.00115814000586 W
# 對Vref Deskew
# CH1 deskew set to 2.777777777777778e-09
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 2
# Current population: 11
# Current population: 22
# Current population: 32
# Poplution採樣數量已超過 25
# The maximum B value is 5.660426154463494e-07 T
# The minimum B value is -4.629927161658998e-07 T
# The delta of B is 0.02039811637691957 T
# The true power of 1 is 0.0062108423368524 W
# The true power of 2 is 0.0015654009136915 W
# k factor:0.20142371928723438
# Core Real power loss:0.003955654101318439
# Every volume of Core Real power loss:7.7160666834699505
# [第1次測量]花費時間: 0:38
# 程式執行累計時間: 0:58
# [第2次測量]
# Current population: 36
# Poplution採樣數量已超過 5
# The maximum B value is 5.656704047396488e-07 T
# The minimum B value is -4.632685204342124e-07 T
# The delta of B is 0.020396205354344044 T
# Gain now:15
# delta B 大於155 mT
# 實際 delta B: 0.020396205354344044 與預期 delta B: 0.05 差了 0.02960379464565596T
# delta B 誤差大於 0.0205
# AFG 振幅已增加 9V
# 增益增加 9
# set signal amplitude be 309.0E-3VPP
# set power gain be 24
# CH1 no clipping
# amplitude of CH1 is 1.230147856021
# set CH1 vertical scale be 0.18925351631092308
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 8.3077022334835
# set CH2 vertical scale be 1.2781080359205386
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 1.5503103663457
# set CH3 vertical scale be 0.23850928713010772
# vertical state of CH3 is good
# The maximum B value is 7.345865356001013e-07 T
# The minimum B value is -5.99055681504979e-07 T
# The delta of B is 0.026436205166114862 T
# Gain now:24
# delta B 大於155 mT
# 實際 delta B: 0.026436205166114862 與預期 delta B: 0.05 差了 0.02356379483388514T
# delta B 誤差大於 0.0205
# AFG 振幅已增加 9V
# 增益增加 9
# set signal amplitude be 318.0E-3VPP
# set power gain be 33
# CH1 is clipping
# set CH1 vertical scale be 0.229254
# CH1 is clipping
# set CH1 vertical scale be 0.269254
# CH1 is clipping
# set CH1 vertical scale be 0.309254
# CH1 no clipping
# amplitude of CH1 is 2.0066394366951
# set CH1 vertical scale be 0.30871375949155383
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 11.0796916804899
# set CH2 vertical scale be 1.7045679508445999
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 2.0746832722
# set CH3 vertical scale be 0.3191820418769231
# vertical state of CH3 is good
# The maximum B value is 9.70072051131865e-07 T
# The minimum B value is -7.943858690850902e-07 T
# The delta of B is 0.03497607603265941 T
# Gain now:33
# delta B 大於155 mT
# 實際 delta B: 0.03497607603265941 與預期 delta B: 0.05 差了 0.015023923967340591T
# delta B 誤差介於 0.015 ~ 0.0205
# AFG 振幅已增加 6V
# 增益增加 7
# set signal amplitude be 324.0E-3VPP
# set power gain be 40
# CH1 is clipping
# set CH1 vertical scale be 0.34871399999999997
# CH1 no clipping
# amplitude of CH1 is 2.5216819635473
# set CH1 vertical scale be 0.3879510713149692
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 13.9919348040065
# set CH2 vertical scale be 2.1526053544625383
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 2.6011931187162
# set CH3 vertical scale be 0.4001835567255692
# vertical state of CH3 is good
# The maximum B value is 1.2327056992945e-06 T
# The minimum B value is -9.982819619835936e-07 T
# The delta of B is 0.044223890620861614 T
# Gain now:40
# delta B 大於155 mT
# 實際 delta B: 0.044223890620861614 與預期 delta B: 0.05 差了 0.005776109379138389T
# delta B 誤差介於 0.005 ~ 0.008
# AFG 振幅已增加 4V
# 增益增加 3
# set signal amplitude be 328.0E-3VPP
# set power gain be 43
# CH1 no clipping
# amplitude of CH1 is 2.658813222424
# set CH1 vertical scale be 0.40904818806523074
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 15.6166432431377
# set CH2 vertical scale be 2.4025604989442617
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 2.8688010236937
# set CH3 vertical scale be 0.44135400364518457
# vertical state of CH3 is good
# The maximum B value is 1.37413678658e-06 T
# The minimum B value is -1.1266675983279e-06 T
# The delta of B is 0.04957234927914392 T
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 3
# Current population: 13
# Current population: 22
# Current population: 32
# Poplution採樣數量已超過 25
# The maximum B value is 1.3561001424023e-06 T
# The minimum B value is -1.13763076115e-06 T
# The delta of B is 0.04943213475836994 T
# The true power of 1 is 0.035132650886598 W
# The true power of 2 is 0.0069736140476365 W
# 對Vref Deskew
# CH1 deskew set to 2.777777777777778e-09
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 10
# Current population: 20
# Current population: 30
# Poplution採樣數量已超過 25
# The maximum B value is 1.3763641391051e-06 T
# The minimum B value is -1.1138428135382e-06 T
# The delta of B is 0.04936228102396443 T
# The true power of 1 is 0.0446482437039058 W
# The true power of 2 is 0.0086838909196154 W
# k factor:0.1797341379370603
# Core Real power loss:0.03387925437744028
# Every volume of Core Real power loss:66.0863107002808
# [第2次測量]花費時間: 0:39
# 程式執行累計時間: 1:38
# [第3次測量]
# Current population: 33
# Poplution採樣數量已超過 5
# The maximum B value is 1.3759155308435e-06 T
# The minimum B value is -1.1137761930513e-06 T
# The delta of B is 0.049352067870295384 T
# Gain now:43
# delta B 大於155 mT
# 實際 delta B: 0.049352067870295384 與預期 delta B: 0.08 差了 0.030647932129704618T
# delta B 誤差大於 0.0205
# AFG 振幅已增加 9V
# 增益增加 9
# set signal amplitude be 337.0E-3VPP
# set power gain be 52
# CH1 is clipping
# set CH1 vertical scale be 0.449048
# CH1 is clipping
# set CH1 vertical scale be 0.489048
# CH1 is clipping
# set CH1 vertical scale be 0.529048
# CH1 no clipping
# amplitude of CH1 is 3.8600936108508
# set CH1 vertical scale be 0.5938605555155078
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 22.1094028288288
# set CH2 vertical scale be 3.4014465890505843
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 3.9628041211233
# set CH3 vertical scale be 0.6096621724805077
# vertical state of CH3 is good
# The maximum B value is 1.9620069906523e-06 T
# The minimum B value is -1.5625809055564e-06 T
# The delta of B is 0.06986636112377714 T
# Gain now:52
# delta B 小於50 mT
# 實際 delta B: 0.06986636112377714 與預期 delta B: 0.08 差了 0.010133638876222859T
# delta B 誤差介於 0.008 ~ 0.015
# AFG 振幅已增加 1V
# 增益增加 1
# set signal amplitude be 338.0E-3VPP
# set power gain be 53
# CH1 no clipping
# amplitude of CH1 is 3.9450103749306
# set CH1 vertical scale be 0.6069246730662461
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 22.9830207921238
# set CH2 vertical scale be 3.535849352634431
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 4.14480449976
# set CH3 vertical scale be 0.6376622307323078
# vertical state of CH3 is good
# The maximum B value is 2.0602396944014e-06 T
# The minimum B value is -1.6074319546533e-06 T
# The delta of B is 0.07270264764624894 T
# Gain now:53
# delta B 小於50 mT
# 實際 delta B: 0.07270264764624894 與預期 delta B: 0.08 差了 0.007297352353751063T
# delta B 誤差介於 0.005 ~ 0.008
# AFG 振幅已增加 1V
# 增益增加 1
# set signal amplitude be 339.0E-3VPP
# set power gain be 54
# CH1 no clipping
# amplitude of CH1 is 4.0968354494416
# set CH1 vertical scale be 0.6302823768371693
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 23.9589744314791
# set CH2 vertical scale be 3.6859960663813998
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 4.317380451661
# set CH3 vertical scale be 0.6642123771786154
# vertical state of CH3 is good
# The maximum B value is 2.1408288830571e-06 T
# The minimum B value is -1.6745641460147e-06 T
# The delta of B is 0.07563086381957211 T
# Gain now:54
# delta B 小於50 mT
# 實際 delta B: 0.07563086381957211 與預期 delta B: 0.08 差了 0.0043691361804278905T
# delta B 誤差介於 0.003 ~ 0.005
# AFG 振幅已增加 0V
# 增益增加 1
# set signal amplitude be 339.0E-3VPP
# set power gain be 55
# CH1 no clipping
# amplitude of CH1 is 4.2352143823339
# set CH1 vertical scale be 0.6515714434359846
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 24.8794871621059
# set CH2 vertical scale be 3.8276134095547536
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 4.4801830764565
# set CH3 vertical scale be 0.6892589348394615
# vertical state of CH3 is good
# The maximum B value is 2.22097742153e-06 T
# The minimum B value is -1.7399369198756e-06 T
# The delta of B is 0.0785154690154464 T
# Gain now:55
# delta B 小於50 mT
# 實際 delta B: 0.0785154690154464 與預期 delta B: 0.08 差了 0.001484530984553603T
# delta B 誤差介於 0.001 ~ 0.003
# AFG 振幅已增加 0V
# 增益增加 1
# set signal amplitude be 339.0E-3VPP
# set power gain be 56
# CH1 no clipping
# amplitude of CH1 is 4.3862215581519
# set CH1 vertical scale be 0.6748033166387538
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 25.8157805655208
# set CH2 vertical scale be 3.9716585485416616
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 4.6165105128228
# set CH3 vertical scale be 0.710232386588123
# vertical state of CH3 is good
# The maximum B value is 2.3185041300167e-06 T
# The minimum B value is -1.7859820218291e-06 T
# The delta of B is 0.081361430089704 T
# Gain now:56
# delta B 小於50 mT
# 實際 delta B: 0.081361430089704 與預期 delta B: 0.08 差了 -0.001361430089704005T
# 實際deltaB大於預期deltaB 0.001
# AFG 振幅已減少 5V
# 增益減少 1
# set signal amplitude be 334.0E-3VPP
# set power gain be 55
# CH1 no clipping
# amplitude of CH1 is 4.3402773590038
# set CH1 vertical scale be 0.667734978308277
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 24.3165250898109
# set CH2 vertical scale be 3.7410038599709075
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 4.4041962207432
# set CH3 vertical scale be 0.6775686493451077
# vertical state of CH3 is good
# The maximum B value is 2.19165008275e-06 T
# The minimum B value is -1.7108097836172e-06 T
# The delta of B is 0.07735675157596171 T
# Gain now:55
# delta B 小於50 mT
# 實際 delta B: 0.07735675157596171 與預期 delta B: 0.08 差了 0.0026432484240382914T
# delta B 誤差介於 0.001 ~ 0.003
# AFG 振幅已增加 0V
# 增益增加 1
# set signal amplitude be 334.0E-3VPP
# set power gain be 56
# CH1 no clipping
# amplitude of CH1 is 4.3090244189893
# set CH1 vertical scale be 0.6629268336906615
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 25.4008062978604
# set CH2 vertical scale be 3.9078163535169845
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 4.5158360893265
# set CH3 vertical scale be 0.6947440137425385
# vertical state of CH3 is good
# The maximum B value is 2.2710812572768e-06 T
# The minimum B value is -1.7732872947818e-06 T
# The delta of B is 0.08016974525723175 T
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 3
# Current population: 12
# Current population: 22
# Current population: 32
# Poplution採樣數量已超過 25
# The maximum B value is 2.2376702872862e-06 T
# The minimum B value is -1.80183849352e-06 T
# The delta of B is 0.0800734121416172 T
# The true power of 1 is 0.1193004037767731 W
# The true power of 2 is 0.0177395333826063 W
# 對Vref Deskew
# CH1 deskew set to 2.777777777777778e-09
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 4
# Current population: 14
# Current population: 24
# Current population: 34
# Poplution採樣數量已超過 25
# The maximum B value is 2.2727144823875e-06 T
# The minimum B value is -1.76367370841e-06 T
# The delta of B is 0.08001155405355487 T
# The true power of 1 is 0.1428650857082216 W
# The true power of 2 is 0.0219751124897843 W
# k factor:0.17974268099606158
# Core Real power loss:0.11611185248696432
# Every volume of Core Real power loss:226.49270476708924
# [第3次測量]花費時間: 0:51
# 程式執行累計時間: 2:29
# [第4次測量]
# Current population: 38
# Poplution採樣數量已超過 5
# The maximum B value is 2.2732913294021e-06 T
# The minimum B value is -1.7635700260143e-06 T
# The delta of B is 0.08002093338841858 T
# Gain now:56
# delta B 小於50 mT
# 實際 delta B: 0.08002093338841858 與預期 delta B: 0.11000000000000001 差了 0.029979066611581437T
# delta B 誤差大於 0.0205
# AFG 振幅已增加 2V
# 增益增加 2
# set signal amplitude be 336.0E-3VPP
# set power gain be 58
# CH1 no clipping
# amplitude of CH1 is 4.4176357867061
# set CH1 vertical scale be 0.6796362748778615
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 27.5257376259159
# set CH2 vertical scale be 4.234728865525524
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 4.89006760975
# set CH3 vertical scale be 0.7523180938076923
# vertical state of CH3 is good
# The maximum B value is 2.4711446258152e-06 T
# The minimum B value is -1.9238329969085e-06 T
# The delta of B is 0.08711971520143691 T
# Gain now:58
# delta B 小於50 mT
# 實際 delta B: 0.08711971520143691 與預期 delta B: 0.11000000000000001 差了 0.022880284798563105T
# delta B 誤差大於 0.0205
# AFG 振幅已增加 2V
# 增益增加 2
# set signal amplitude be 338.0E-3VPP
# set power gain be 60
# CH1 no clipping
# amplitude of CH1 is 4.9279560641779
# set CH1 vertical scale be 0.7581470867966
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 29.83432549439
# set CH2 vertical scale be 4.589896229906154
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 5.3219979728541
# set CH3 vertical scale be 0.8187689189006307
# vertical state of CH3 is good
# The maximum B value is 2.7175669856661e-06 T
# The minimum B value is -2.0537750060612e-06 T
# The delta of B is 0.0945802211366735 T
# Gain now:60
# delta B 小於50 mT
# 實際 delta B: 0.0945802211366735 與預期 delta B: 0.11000000000000001 差了 0.015419778863326516T
# delta B 誤差介於 0.015 ~ 0.0205
# AFG 振幅已增加 1V
# 增益增加 2
# set signal amplitude be 339.0E-3VPP
# set power gain be 62
# CH1 no clipping
# amplitude of CH1 is 5.3007405159372
# set CH1 vertical scale be 0.8154985409134153
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 32.3436250822773
# set CH2 vertical scale be 4.975942320350354
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 5.6828988283742
# set CH3 vertical scale be 0.8742921274421847
# vertical state of CH3 is good
# The maximum B value is 2.9774191716569e-06 T
# The minimum B value is -2.2195022211235e-06 T
# The delta of B is 0.10301629508245319 T
# Gain now:62
# delta B 小於50 mT
# 實際 delta B: 0.10301629508245319 與預期 delta B: 0.11000000000000001 差了 0.0069837049175468235T
# delta B 誤差介於 0.005 ~ 0.008
# AFG 振幅已增加 1V
# 增益增加 1
# set signal amplitude be 340.0E-3VPP
# set power gain be 63
# CH1 no clipping
# amplitude of CH1 is 5.6286528979378
# set CH1 vertical scale be 0.8659465996827385
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 33.8998158618856
# set CH2 vertical scale be 5.215356286443939
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 5.9399017782282
# set CH3 vertical scale be 0.9138310428043385
# vertical state of CH3 is good
# The maximum B value is 3.1048832624947e-06 T
# The minimum B value is -2.3095246888261e-06 T
# The delta of B is 0.1073274358132308 T
# Gain now:63
# delta B 小於50 mT
# 實際 delta B: 0.1073274358132308 與預期 delta B: 0.11000000000000001 差了 0.0026725641867692135T
# delta B 誤差介於 0.001 ~ 0.003
# AFG 振幅已增加 0V
# 增益增加 1
# set signal amplitude be 340.0E-3VPP
# set power gain be 64
# CH1 no clipping
# amplitude of CH1 is 5.8214680749085
# set CH1 vertical scale be 0.8956104730628461
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 35.2131307936318
# set CH2 vertical scale be 5.4174047374818155
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 6.2000346083108
# set CH3 vertical scale be 0.9538514782016616
# vertical state of CH3 is good
# The maximum B value is 3.2698828817956e-06 T
# The minimum B value is -2.4108549041557e-06 T
# The delta of B is 0.11260677539910009 T
# Gain now:64
# delta B 小於50 mT
# 實際 delta B: 0.11260677539910009 與預期 delta B: 0.11000000000000001 差了 -0.002606775399100078T
# 實際deltaB大於預期deltaB 0.001
# AFG 振幅已減少 5V
# 增益減少 1
# set signal amplitude be 335.0E-3VPP
# set power gain be 63
# CH1 no clipping
# amplitude of CH1 is 5.7748169648836
# set CH1 vertical scale be 0.8884333792128616
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 33.5858774395646
# set CH2 vertical scale be 5.167058067625323
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 5.8408335558559
# set CH3 vertical scale be 0.8985897778239846
# vertical state of CH3 is good
# The maximum B value is 3.0714390959474e-06 T
# The minimum B value is -2.2815668216936e-06 T
# The delta of B is 0.10611029021064226 T
# Gain now:63
# delta B 小於50 mT
# 實際 delta B: 0.10611029021064226 與預期 delta B: 0.11000000000000001 差了 0.003889709789357751T
# delta B 誤差介於 0.003 ~ 0.005
# AFG 振幅已增加 0V
# 增益增加 1
# set signal amplitude be 335.0E-3VPP
# set power gain be 64
# CH1 no clipping
# amplitude of CH1 is 5.7533701596766
# set CH1 vertical scale be 0.8851338707194769
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 34.8734713893769
# set CH2 vertical scale be 5.365149444519523
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 6.0712684661411
# set CH3 vertical scale be 0.9340413024832461
# vertical state of CH3 is good
# The maximum B value is 3.2217162697634e-06 T
# The minimum B value is -2.37320909946e-06 T
# The delta of B is 0.11090575347183744 T
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 2
# Current population: 11
# Current population: 22
# Current population: 31
# Poplution採樣數量已超過 25
# The maximum B value is 3.1648419280828e-06 T
# The minimum B value is -2.4197402126447e-06 T
# The delta of B is 0.11070072418655345 T
# The true power of 1 is 0.2817643769358399 W
# The true power of 2 is 0.0307681308063134 W
# 對Vref Deskew
# CH1 deskew set to 2.777777777777778e-09
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 10
# Current population: 19
# Current population: 29
# Poplution採樣數量已超過 25
# The maximum B value is 3.2185919280892e-06 T
# The minimum B value is -2.3679151581746e-06 T
# The delta of B is 0.11073888153826184 T
# The true power of 1 is 0.3256453217093583 W
# The true power of 2 is 0.038404933915152 W
# k factor:0.1740346099714634
# Core Real power loss:0.27640965729141215
# Every volume of Core Real power loss:539.1764024323413
# [第4次測量]花費時間: 0:50
# 程式執行累計時間: 3:20
# [第5次測量]
# Current population: 33
# Poplution採樣數量已超過 5
# The maximum B value is 3.21851280205e-06 T
# The minimum B value is -2.3683528525e-06 T
# The delta of B is 0.11074598928024726 T
# Gain now:64
# delta B 小於50 mT
# 實際 delta B: 0.11074598928024726 與預期 delta B: 0.14 差了 0.029254010719752754T
# delta B 誤差大於 0.0205
# AFG 振幅已增加 2V
# 增益增加 2
# set signal amplitude be 337.0E-3VPP
# set power gain be 66
# CH1 no clipping
# amplitude of CH1 is 5.8905268990991
# set CH1 vertical scale be 0.9062349075537077
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 38.1183070236651
# set CH2 vertical scale be 5.864354926717708
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 6.53945922613
# set CH3 vertical scale be 1.0060706501738461
# vertical state of CH3 is good
# The maximum B value is 3.5461787319946e-06 T
# The minimum B value is -2.5572694539733e-06 T
# The delta of B is 0.12098597839474794 T
# Gain now:66
# delta B 小於50 mT
# 實際 delta B: 0.12098597839474794 與預期 delta B: 0.14 差了 0.019014021605252077T
# delta B 誤差介於 0.015 ~ 0.0205
# AFG 振幅已增加 1V
# 增益增加 2
# set signal amplitude be 338.0E-3VPP
# set power gain be 68
# CH1 no clipping
# amplitude of CH1 is 6.5462254318459
# set CH1 vertical scale be 1.0071116048993694
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 41.7668652731419
# set CH2 vertical scale be 6.425671580483369
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 7.0997174454809
# set CH3 vertical scale be 1.092264222381677
# vertical state of CH3 is good
# The maximum B value is 3.9063966141839e-06 T
# The minimum B value is -2.7758519536292e-06 T
# The delta of B is 0.13245928468966983 T
# Gain now:68
# delta B 小於50 mT
# 實際 delta B: 0.13245928468966983 與預期 delta B: 0.14 差了 0.007540715310330182T
# delta B 誤差介於 0.005 ~ 0.008
# AFG 振幅已增加 1V
# 增益增加 1
# set signal amplitude be 339.0E-3VPP
# set power gain be 69
# CH1 no clipping
# amplitude of CH1 is 7.0007170610473
# set CH1 vertical scale be 1.077033394007277
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 43.8813940837688
# set CH2 vertical scale be 6.7509837051952
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 7.3909043981982
# set CH3 vertical scale be 1.1370622151074152
# vertical state of CH3 is good
# The maximum B value is 4.1025982682186e-06 T
# The minimum B value is -2.9194361559348e-06 T
# The delta of B is 0.13919471079987106 T
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 10
# Current population: 20
# Current population: 29
# Poplution採樣數量已超過 25
# The maximum B value is 4.02759633289e-06 T
# The minimum B value is -2.9682125841646e-06 T
# The delta of B is 0.1386748540666655 T
# The true power of 1 is 0.5154194816543052 W
# The true power of 2 is 0.0455318287467311 W
# 對Vref Deskew
# CH1 deskew set to 2.777777777777778e-09
# clear acquistions, measurements, and waveforms
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 2
# Current population: 12
# Current population: 22
# Current population: 32
# Poplution採樣數量已超過 25
# The maximum B value is 4.08839832744e-06 T
# The minimum B value is -2.9112795800756e-06 T
# The delta of B is 0.1387515473688877 T
# The true power of 1 is 0.5812164232245128 W
# The true power of 2 is 0.056843952159262 W
# k factor:0.17192476036990975
# Core Real power loss:0.5075914329078197
# Every volume of Core Real power loss:990.1293803645204
# [第5次測量]花費時間: 0:35
# 程式執行累計時間: 3:55
# [第6次測量]
# Current population: 36
# Poplution採樣數量已超過 5
# The maximum B value is 4.0877753235691e-06 T
# The minimum B value is -2.9118361908331e-06 T
# The delta of B is 0.1387502312872993 T
# Gain now:69
# delta B 小於50 mT
# 實際 delta B: 0.1387502312872993 與預期 delta B: 0.17 差了 0.031249768712700715T
# delta B 誤差大於 0.0205
# AFG 振幅已增加 2V
# 增益增加 2
# set signal amplitude be 341.0E-3VPP
# set power gain be 71
# CH1 no clipping
# amplitude of CH1 is 7.2218283506944
# set CH1 vertical scale be 1.111050515491446
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 48.2291327515616
# set CH2 vertical scale be 7.419866577163323
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 8.0135740931166
# set CH3 vertical scale be 1.2328575527871695
# vertical state of CH3 is good
# The maximum B value is 4.5294154915609e-06 T
# The minimum B value is -3.1837719234318e-06 T
# The delta of B is 0.15289513362141557 T
# Gain now:71
# delta B 小於50 mT
# 實際 delta B: 0.15289513362141557 與預期 delta B: 0.17 差了 0.017104866378584438T
# delta B 誤差介於 0.015 ~ 0.0205
# AFG 振幅已增加 1V
# 增益增加 2
# set signal amplitude be 342.0E-3VPP
# set power gain be 73
# CH1 no clipping
# amplitude of CH1 is 8.0966792021015
# set CH1 vertical scale be 1.2456429541694616
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 53.176484081783
# set CH2 vertical scale be 8.18099755104354
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 8.7060291581031
# set CH3 vertical scale be 1.3393891012466308
# vertical state of CH3 is good
# The maximum B value is 5.0602448027348e-06 T
# The minimum B value is -3.4401555240038e-06 T
# The delta of B is 0.16849971015432053 T
# Gain now:73
# delta B 小於50 mT
# 實際 delta B: 0.16849971015432053 與預期 delta B: 0.17 差了 0.0015002898456794866T
# delta B 誤差介於 0.001 ~ 0.003
# AFG 振幅已增加 0V
# 增益增加 1
# set signal amplitude be 342.0E-3VPP
# set power gain be 74
# CH1 no clipping
# amplitude of CH1 is 8.6265044451342
# set CH1 vertical scale be 1.3271545300206462
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 55.8453341473808
# set CH2 vertical scale be 8.591589868827814
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 9.0503624602829
# set CH3 vertical scale be 1.3923634554281383
# vertical state of CH3 is good
# The maximum B value is 5.33002503289e-06 T
# The minimum B value is -3.5959242268291e-06 T
# The delta of B is 0.1769351801448505 T
# Gain now:74
# delta B 小於50 mT
# 實際 delta B: 0.1769351801448505 與預期 delta B: 0.17 差了 -0.006935180144850478T
# 實際deltaB大於預期deltaB 0.001
# AFG 振幅已減少 8V
# 增益減少 1
# set signal amplitude be 334.0E-3VPP
# set power gain be 73
# CH1 no clipping
# amplitude of CH1 is 8.556351740266
# set CH1 vertical scale be 1.3163618061947693
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 51.8721264151355
# set CH2 vertical scale be 7.980327140790076
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 8.4776561376689
# set CH3 vertical scale be 1.3042547904105999
# vertical state of CH3 is good
# The maximum B value is 4.9394739107811e-06 T
# The minimum B value is -3.3568569506315e-06 T
# The delta of B is 0.16445453058194018 T
# Gain now:73
# delta B 小於50 mT
# 實際 delta B: 0.16445453058194018 與預期 delta B: 0.17 差了 0.005545469418059834T
# delta B 誤差介於 0.005 ~ 0.008
# AFG 振幅已增加 1V
# 增益增加 1
# set signal amplitude be 335.0E-3VPP
# set power gain be 74
# CH1 no clipping
# amplitude of CH1 is 8.4742352023624
# set CH1 vertical scale be 1.3037284926711386
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 54.6874037804772
# set CH2 vertical scale be 8.413446735458031
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 8.8786277871622
# set CH3 vertical scale be 1.3659427364864922
# vertical state of CH3 is good
# The maximum B value is 5.2381128625711e-06 T
# The minimum B value is -3.5291361655254e-06 T
# The delta of B is 0.17378933500792015 T
# Gain now:74
# delta B 小於50 mT
# 實際 delta B: 0.17378933500792015 與預期 delta B: 0.17 差了 -0.0037893350079201416T
# 實際deltaB大於預期deltaB 0.001
# AFG 振幅已減少 8V
# 增益減少 1
# set signal amplitude be 327.0E-3VPP
# set power gain be 73
# CH1 no clipping
# amplitude of CH1 is 8.3962028514865
# set CH1 vertical scale be 1.2917235156133076
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 50.8551446082501
# set CH2 vertical scale be 7.823868401269246
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 8.2566923821877
# set CH3 vertical scale be 1.2702603664904153
# vertical state of CH3 is good
# The maximum B value is 4.8357519517594e-06 T
# The minimum B value is -3.267509782745e-06 T
# The delta of B is 0.16062740589683008 T
# Gain now:73
# delta B 小於50 mT
# 實際 delta B: 0.16062740589683008 與預期 delta B: 0.17 差了 0.009372594103169929T
# delta B 誤差介於 0.008 ~ 0.015
# AFG 振幅已增加 1V
# 增益增加 1
# set signal amplitude be 328.0E-3VPP
# set power gain be 74
# CH1 no clipping
# amplitude of CH1 is 8.2717496775357
# set CH1 vertical scale be 1.2725768734670309
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 53.6127226227628
# set CH2 vertical scale be 8.248111172732738
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 8.7254631456081
# set CH3 vertical scale be 1.3423789454781692
# vertical state of CH3 is good
# The maximum B value is 5.1034839998465e-06 T
# The minimum B value is -3.458917944954e-06 T
# The delta of B is 0.1697287410553319 T
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 11
# Current population: 21
# Current population: 31
# Poplution採樣數量已超過 25
# The maximum B value is 5.0207459025842e-06 T
# The minimum B value is -3.5340497106517e-06 T
# The delta of B is 0.16957796407840048 T
# The true power of 1 is 0.8676404600012139 W
# The true power of 2 is 0.0640690822015642 W
# 對Vref Deskew
# CH1 deskew set to 2.777777777777778e-09
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 2
# Current population: 12
# Current population: 23
# Current population: 33
# Poplution採樣數量已超過 25
# The maximum B value is 5.0991216085094e-06 T
# The minimum B value is -3.4617623896338e-06 T
# The delta of B is 0.16969865146402405 T
# The true power of 1 is 0.9651830360571159 W
# The true power of 2 is 0.0798972144358862 W
# k factor:0.1622689585853345
# Core Real power loss:0.8572440367548478
# Every volume of Core Real power loss:1672.1765812138904
# [第6次測量]花費時間: 0:50
# 程式執行累計時間: 4:46
# [第7次測量]
# Current population: 36
# Poplution採樣數量已超過 5
# The maximum B value is 5.1000843086513e-06 T
# The minimum B value is -3.4628351386345e-06 T
# The delta of B is 0.16973899928028902 T
# Gain now:74
# delta B 小於50 mT
# 實際 delta B: 0.16973899928028902 與預期 delta B: 0.2 差了 0.030261000719710995T
# delta B 誤差大於 0.0205
# AFG 振幅已增加 2V
# 增益增加 2
# set signal amplitude be 330.0E-3VPP
# set power gain be 76
# CH1 no clipping
# amplitude of CH1 is 8.5627756596206
# set CH1 vertical scale be 1.3173501014800924
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 60.3178774061568
# set CH2 vertical scale be 9.279673447101047
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 9.5593022373186
# set CH3 vertical scale be 1.4706618826643998
# vertical state of CH3 is good
# The maximum B value is 5.7994379858428e-06 T
# The minimum B value is -3.8227735785767e-06 T
# The delta of B is 0.19073688265577324 T
# Gain now:76
# delta B 小於50 mT
# 實際 delta B: 0.19073688265577324 與預期 delta B: 0.2 差了 0.009263117344226773T
# delta B 誤差介於 0.008 ~ 0.015
# AFG 振幅已增加 1V
# 增益增加 1
# set signal amplitude be 331.0E-3VPP
# set power gain be 77
# CH1 no clipping
# amplitude of CH1 is 9.6328880173533
# set CH1 vertical scale be 1.4819827719005079
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 64.2830812693085
# set CH2 vertical scale be 9.889704810662845
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 10.168265545884
# set CH3 vertical scale be 1.5643485455206152
# vertical state of CH3 is good
# The maximum B value is 6.2752869780525e-06 T
# The minimum B value is -4.0271279431181e-06 T
# The delta of B is 0.20422025567975066 T
# Gain now:77
# delta B 小於50 mT
# 實際 delta B: 0.20422025567975066 與預期 delta B: 0.2 差了 -0.004220255679750651T
# 實際deltaB大於預期deltaB 0.001
# AFG 振幅已減少 8V
# 增益減少 1
# set signal amplitude be 323.0E-3VPP
# set power gain be 76
# CH1 no clipping
# amplitude of CH1 is 9.5071402198871
# set CH1 vertical scale be 1.4626369569057078
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 58.8161867256819
# set CH2 vertical scale be 9.04864411164337
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 9.3318864297813
# set CH3 vertical scale be 1.4356748353509692
# vertical state of CH3 is good
# The maximum B value is 5.6758763093967e-06 T
# The minimum B value is -3.7587933547911e-06 T
# The delta of B is 0.18701932176261982 T
# Gain now:76
# delta B 小於50 mT
# 實際 delta B: 0.18701932176261982 與預期 delta B: 0.2 差了 0.012980678237380194T
# delta B 誤差介於 0.008 ~ 0.015
# AFG 振幅已增加 1V
# 增益增加 1
# set signal amplitude be 324.0E-3VPP
# set power gain be 77
# CH1 no clipping
# amplitude of CH1 is 9.4106676757273
# set CH1 vertical scale be 1.4477950270349693
# vertical state of CH1 is good
# CH2 no clipping
# amplitude of CH2 is 63.0128003524324
# set CH2 vertical scale be 9.694276977297292
# vertical state of CH2 is good
# CH3 no clipping
# amplitude of CH3 is 9.899569239161
# set CH3 vertical scale be 1.5230106521786153
# vertical state of CH3 is good
# The maximum B value is 6.10953748037e-06 T
# The minimum B value is -3.9783935790183e-06 T
# The delta of B is 0.1999686360907985 T
# CH1 deskew set to 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 2
# Current population: 11
# Current population: 22
# Current population: 32
# Poplution採樣數量已超過 25
# The maximum B value is 5.9997014432156e-06 T
# The minimum B value is -4.0472418731952e-06 T
# The delta of B is 0.19915615402570522 T
# The true power of 1 is 1.3400357293471 W
# The true power of 2 is 0.0821461741137354 W
# 對Vref Deskew
# CH1 deskew set to 2.777777777777778e-09
# clear acquistions, measurements, and waveforms
# Current population: 0
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 1
# Current population: 5
# Current population: 14
# Current population: 23
# Current population: 34
# Poplution採樣數量已超過 25
# The maximum B value is 6.0739976106561e-06 T
# The minimum B value is -3.9547494452563e-06 T
# The delta of B is 0.1987954575288322 T
# The true power of 1 is 1.4681093799712 W
# The true power of 2 is 0.1035631992412192 W
# k factor:0.16722428870512493
# Core Real power loss:1.3262988938110831
# Every volume of Core Real power loss:2587.134882053456
# [第7次測量]花費時間: 0:39
# 程式執行累計時間: 5:25
# 已經測量完畢
# set power gain be 77
# turn AFG31101 output off
# turn RF150A100D power off
#   core parameter                                          \
#             Type     Le(mm)   Ae(mm^2)    Ve(mm^3) Turns
# 0          ML95S  30.486205  16.815855  512.651622     3
# 1          ML95S  30.486205  16.815855  512.651622     3
# 2          ML95S  30.486205  16.815855  512.651622     3
# 3          ML95S  30.486205  16.815855  512.651622     3
# 4          ML95S  30.486205  16.815855  512.651622     3
# 5          ML95S  30.486205  16.815855  512.651622     3
# 6          ML95S  30.486205  16.815855  512.651622     3
#
#   Test environment (R=10)                                          ...  \
#                  Sequence  Function freq(kHz) deltaB(T)  Vin(Vpp)  ...
# 0                       1  SINusoid      1000      0.02    300E-3  ...
# 1                       2  SINusoid      1000      0.05  328.0E-3  ...
# 2                       3  SINusoid      1000      0.08  334.0E-3  ...
# 3                       4  SINusoid      1000      0.11  335.0E-3  ...
# 4                       5  SINusoid      1000      0.14  339.0E-3  ...
# 5                       6  SINusoid      1000      0.17  328.0E-3  ...
# 6                       7  SINusoid      1000      0.20  324.0E-3  ...
#
#        DS=0 flux density (DS=1)      DS=1           Final calculate  \
#     Pair(W)          delta B(T)  Pcore(W)   Pair(W)               K
# 0  0.001158            0.020398  0.006211  0.001565        0.201424
# 1  0.006974            0.049362  0.044648  0.008684        0.179734
# 2  0.017740            0.080012  0.142865  0.021975        0.179743
# 3  0.030768            0.110739  0.325645  0.038405        0.174035
# 4  0.045532            0.138752  0.581216  0.056844        0.171925
# 5  0.064069            0.169699  0.965183  0.079897        0.162269
# 6  0.082146            0.198795  1.468109  0.103563        0.167224
#
#                                                                         \
#   Real Pcore(W) Real Pcv(kW/m^3) Spend time(sec) Accumulated time(sec)
# 0      0.003956         7.716067            0:38                  0:58
# 1      0.033879        66.086311            0:39                  1:38
# 2      0.116112       226.492705            0:51                  2:29
# 3      0.276410       539.176402            0:50                  3:20
# 4      0.507591       990.129380            0:35                  3:55
# 5      0.857244      1672.176581            0:50                  4:46
# 6      1.326299      2587.134882            0:39                  5:25
#
#
#   Temperature(degree C)
# 0                 26.84
# 1                 27.04
# 2                 27.73
# 3                 29.51
# 4                 31.53
# 5                 37.06
# 6                 35.64
#
# [7 rows x 23 columns]
# AFG_31101 connection closed.
# MSO64B connection closed.
# RF_150A100D connection closed.
